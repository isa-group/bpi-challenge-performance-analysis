# %%
import pandas as pd
import datetime
from os import listdir
import os, os.path
from os.path import isfile, join
import numpy as np
import csv
import re
import pandas as pd
import pm4py
from pm4py.objects.conversion.log import converter as log_converter
from pm4py.objects.log.importer.xes import importer as xes_importer
from pm4py.objects.log.exporter.xes import exporter as xes_exporter
from pm4py.objects.log.util import dataframe_utils

# %%
datos_raw = pd.read_excel("./grouped table of annotations.xlsx")#table with annotations
#datos_raw=datos_raw.drop(['Unnamed: 0'], axis='columns')
glosario = pd.read_excel("./OperationCoding.xlsx")#operation code that relates operation with variants
glosario['Operations'] = glosario['Operations'].fillna(method='pad')#name of the operations
glosario['Variants'] =  glosario['Variants'].str.split().str.join(' ')#name of the variants
glosario['Operations'] =  glosario['Operations'].str.split().str.join(' ')

columns=['case:id','case:concept:name','concept:name','Variant','time:timestamp','Question','Report','Year', 'Category']
#columna es el case_ID
cont = 0
df_prueba= pd.DataFrame(columns=columns)
ct=datetime.datetime.now()
for columna in datos_raw.columns:
    print("-----------------------------------------------------------------------")
    print("Case:id")
    print(columna)
    acciones_analisis=datos_raw[columna].dropna()
    for accion in acciones_analisis:
        
        accion = re.sub('[\xa0]', ' ', accion)
        print(' *************************** ', accion)
        string_dividido=accion.split(' ')
        accion = ' '.join(string_dividido)
        for fila in range(len(glosario)):
                     
            if(accion == glosario['Variants'][fila]):
                #print('si', accion)
                accionGeneral=glosario['Operations'][fila]
                accionEspecifica=accion
                columnaSeparada=columna.split()
                category=datos_raw.loc[0][columna]
                report=columnaSeparada[0]
                pregunta=columnaSeparada[1]
                año=columnaSeparada[3]
                ct=ct+datetime.timedelta(hours=1)
                print("Fecha:") 
                print(ct)
                new_row={'case:id':columna, 'case:concept:name':columna, 'concept:name':accionGeneral,'Variant':accionEspecifica,'time:timestamp':str(ct),'Question':pregunta,'Report':report,'Year':año, 'Category':category} 
                #print(cont, new_row['case:concept:name'])
                cont = cont +1
                df_prueba = df_prueba.append(new_row, ignore_index=True)
                
            elif(accion == glosario['Operations'][fila]):
                #print('no', accion)
                accionGeneral=accion
                accionEspecifica=accion
                columnaSeparada=columna.split()
                category=datos_raw.loc[0][columna]
                pregunta=columnaSeparada[1]
                report=columnaSeparada[0]
                año=columnaSeparada[3]
                ct=ct+ datetime.timedelta(hours=1)
                print("Fecha:") 
                print(ct)
                new_row={'case:id':columna, 'case:concept:name':columna, 'concept:name':accionGeneral,'Variant':accionEspecifica,'time:timestamp':str(ct),'Question':pregunta,'Report':report,'Year':año, 'Category':category} 
                #print(cont, new_row['case:concept:name'])
                cont = cont +1
                df_prueba = df_prueba.append(new_row, ignore_index=True)
            
                
            
df_prueba
# Out:
# -----------------------------------------------------------------------
# Case:id
# A2 P4 BPI 2020
#  ***************************  Student
#  ***************************  Filter activities by sub-processes
# Fecha:
# 2022-03-11 19:24:15.966942
#  ***************************  Group activities by sub-processes
# Fecha:
# 2022-03-11 20:24:15.966942
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2022-03-11 21:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A7 P4 BPI 2020
#  ***************************  Academic
#  ***************************  Group activities by role
# Fecha:
# 2022-03-11 22:24:15.966942
#  ***************************  Calculate throughput
# Fecha:
# 2022-03-11 23:24:15.966942
#  ***************************  Group activities by time
# Fecha:
# 2022-03-12 00:24:15.966942
#  ***************************  Calculate number of activities
# Fecha:
# 2022-03-12 01:24:15.966942
#  ***************************  Represent scatterplot of cycle time and an attribute
# Fecha:
# 2022-03-12 02:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A10 P4 BPI 2020
#  ***************************  Academic
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-12 03:24:15.966942
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-03-12 04:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A12 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-03-12 05:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A13 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-12 06:24:15.966942
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-03-12 07:24:15.966942
#  ***************************  Group activities by sub-processes
# Fecha:
# 2022-03-12 08:24:15.966942
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# Fecha:
# 2022-03-12 09:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A18 P4 BPI 2020
#  ***************************  Academic
#  ***************************  Represent process map with frequency
# Fecha:
# 2022-03-12 10:24:15.966942
#  ***************************  Calculate cycle time of only a subset of pairs of events for a subset of traces
# Fecha:
# 2022-03-12 11:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A25 P4 BPI 2020
#  ***************************  Student
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-03-12 12:24:15.966942
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2022-03-12 13:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-12 14:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A26 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Filter variants depending on frequency
# Fecha:
# 2022-03-12 15:24:15.966942
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-03-12 16:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A28 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2022-03-12 17:24:15.966942
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2022-03-12 18:24:15.966942
#  ***************************  Represent heat maps of cycle time and an attribute
# Fecha:
# 2022-03-12 19:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-12 20:24:15.966942
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2022-03-12 21:24:15.966942
#  ***************************  Represent heat maps of cycle time and an attribute
# Fecha:
# 2022-03-12 22:24:15.966942
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2022-03-12 23:24:15.966942
#  ***************************  Represent heat maps of cycle time and an attribute
# Fecha:
# 2022-03-13 00:24:15.966942
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2022-03-13 01:24:15.966942
#  ***************************  Represent heat maps of cycle time and an attribute
# Fecha:
# 2022-03-13 02:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A35 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-13 03:24:15.966942
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2022-03-13 04:24:15.966942
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2022-03-13 05:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-03-13 06:24:15.966942
#  ***************************  Calculate number of activities
# Fecha:
# 2022-03-13 07:24:15.966942
#  ***************************  Calculate average of activities per trace
# Fecha:
# 2022-03-13 08:24:15.966942
#  ***************************  Group traces by roles
# Fecha:
# 2022-03-13 09:24:15.966942
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-03-13 10:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A37 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-03-13 11:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A1 P5 BPI 2020
#  ***************************  Academic
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-13 12:24:15.966942
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2022-03-13 13:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-13 14:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A2 P5 BPI 2020
#  ***************************  Student
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-03-13 15:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-13 16:24:15.966942
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-13 17:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A7 P5 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-03-13 18:24:15.966942
#  ***************************  Filter activities by cycle time
# Fecha:
# 2022-03-13 19:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-13 20:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A10 P5 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-03-13 21:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-13 22:24:15.966942
#  ***************************  Calculate number of activities
# Fecha:
# 2022-03-13 23:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A12 P5 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate processing time
# Fecha:
# 2022-03-14 00:24:15.966942
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-14 01:24:15.966942
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-14 02:24:15.966942
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2022-03-14 03:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-14 04:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A13 P5 BPI 2020
#  ***************************  Professional
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-14 05:24:15.966942
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-03-14 06:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-14 07:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A18 P5 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate cycle time of only a subset of pairs of events for a subset of traces
# Fecha:
# 2022-03-14 08:24:15.966942
#  ***************************  Find sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-14 09:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A25 P5 BPI 2020
#  ***************************  Student
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-03-14 10:24:15.966942
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2022-03-14 11:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-14 12:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A26 P5 BPI 2020
#  ***************************  Professional
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-14 13:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-14 14:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A28 P5 BPI 2020
#  ***************************  Professional
#  ***************************  Find sub-processes with incorrect orders with respect to the happy path as bottlenecks
# Fecha:
# 2022-03-14 15:24:15.966942
#  ***************************  Calculate number of activities
# Fecha:
# 2022-03-14 16:24:15.966942
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2022-03-14 17:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A35 P5 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2022-03-14 18:24:15.966942
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2022-03-14 19:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-14 20:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A37 P5 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-03-14 21:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-14 22:24:15.966942
#  ***************************  Find sub-processes with incorrect orders with respect to the happy path as bottlenecks
# Fecha:
# 2022-03-14 23:24:15.966942
#  ***************************  Calculate frequency of attributes
# Fecha:
# 2022-03-15 00:24:15.966942
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-03-15 01:24:15.966942
#  ***************************  Calculate number of activities
# Fecha:
# 2022-03-15 02:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A1 P6 BPI 2020
#  ***************************  Academic
#  ***************************  Filter traces depending on the order of activities
# Fecha:
# 2022-03-15 03:24:15.966942
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2022-03-15 04:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A2 P6 BPI 2020
#  ***************************  Student
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-03-15 05:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-15 06:24:15.966942
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-15 07:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A7 P6 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-03-15 08:24:15.966942
#  ***************************  Filter activities by cycle time
# Fecha:
# 2022-03-15 09:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-15 10:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A10 P6 BPI 2020
#  ***************************  Academic
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-15 11:24:15.966942
#  ***************************  Calculate number of activities
# Fecha:
# 2022-03-15 12:24:15.966942
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2022-03-15 13:24:15.966942
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-15 14:24:15.966942
#  ***************************  Calculate number of activities
# Fecha:
# 2022-03-15 15:24:15.966942
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2022-03-15 16:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A12 P6 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-03-15 17:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-15 18:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A13 P6 BPI 2020
#  ***************************  Professional
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2022-03-15 19:24:15.966942
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-15 20:24:15.966942
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# Fecha:
# 2022-03-15 21:24:15.966942
#  ***************************  Calculate frequency of variants
# Fecha:
# 2022-03-15 22:24:15.966942
#  ***************************  Calculate intervals of time of the traces
# Fecha:
# 2022-03-15 23:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-16 00:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A25 P6 BPI 2020
#  ***************************  Student
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-03-16 01:24:15.966942
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-03-16 02:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-16 03:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A26 P6 BPI 2020
#  ***************************  Professional
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-16 04:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-16 05:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A28 P6 BPI 2020
#  ***************************  Professional
#  ***************************  Find sub-processes with incorrect orders with respect to the happy path as bottlenecks
# Fecha:
# 2022-03-16 06:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A35 P6 BPI 2020
#  ***************************  Professional
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-16 07:24:15.966942
#  ***************************  Find sub-processes with incorrect orders with respect to the happy path as bottlenecks
# Fecha:
# 2022-03-16 08:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A37 P6 BPI 2020
#  ***************************  Professional
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-16 09:24:15.966942
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2022-03-16 10:24:15.966942
#  ***************************  Calculate number of variants
# Fecha:
# 2022-03-16 11:24:15.966942
#  ***************************  Calculate number of different organizational units
# Fecha:
# 2022-03-16 12:24:15.966942
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2022-03-16 13:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-16 14:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A2 P5 BPI 2015
#  ***************************  Student
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2022-03-16 15:24:15.966942
#  ***************************  Filter events by cycle time
# Fecha:
# 2022-03-16 16:24:15.966942
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-03-16 17:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-16 18:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A3 P5 BPI 2015
#  ***************************  Professional
#  ***************************  Group activities by sub-processes
# Fecha:
# 2022-03-16 19:24:15.966942
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2022-03-16 20:24:15.966942
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-16 21:24:15.966942
#  ***************************  Filter activities by frequency
# Fecha:
# 2022-03-16 22:24:15.966942
#  ***************************  Represent bar charts of traces
# Fecha:
# 2022-03-16 23:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-17 00:24:15.966942
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-17 01:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A4 P5 BPI 2015
#  ***************************  Academic
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2022-03-17 02:24:15.966942
#  ***************************  Find organizational units as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-17 03:24:15.966942
#  ***************************  Identify impact of bottlenecks by organizational unit
# Fecha:
# 2022-03-17 04:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-17 05:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A7 P5 BPI 2015
#  ***************************  Academic
#  ***************************  Filter traces by attributes
# Fecha:
# 2022-03-17 06:24:15.966942
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2022-03-17 07:24:15.966942
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-03-17 08:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-17 09:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-17 10:24:15.966942
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-17 11:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A8 P5 BPI 2015
#  ***************************  Professional
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2022-03-17 12:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-17 13:24:15.966942
#  ***************************  Group traces depending on attributes
# Fecha:
# 2022-03-17 14:24:15.966942
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2022-03-17 15:24:15.966942
#  ***************************  Group traces by cycle time
# Fecha:
# 2022-03-17 16:24:15.966942
#  ***************************  Group traces by organizational units
# Fecha:
# 2022-03-17 17:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-17 18:24:15.966942
#  ***************************  Analyze cycle time depending on the events
# Fecha:
# 2022-03-17 19:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-03-17 20:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-17 21:24:15.966942
#  ***************************  Filter activities by frequency
# Fecha:
# 2022-03-17 22:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-17 23:24:15.966942
#  ***************************  Calculate frequency of activities
# Fecha:
# 2022-03-18 00:24:15.966942
#  ***************************  Calculate cycle time of only a subset of pairs of events for each subset of traces
# Fecha:
# 2022-03-18 01:24:15.966942
#  ***************************  Find organizational units as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-18 02:24:15.966942
#  ***************************  Identify resource associated with bottlenecks
# Fecha:
# 2022-03-18 03:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A9 P5 BPI 2015
#  ***************************  Student
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-18 04:24:15.966942
#  ***************************  Calculate cycle time for all pairs of events for a subset of traces
# Fecha:
# 2022-03-18 05:24:15.966942
#  ***************************  Group traces by cycle time
# Fecha:
# 2022-03-18 06:24:15.966942
#  ***************************  Apply decision trees
# Fecha:
# 2022-03-18 07:24:15.966942
#  ***************************  Group organizational units
# Fecha:
# 2022-03-18 08:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-03-18 09:24:15.966942
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2022-03-18 10:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-18 11:24:15.966942
#  ***************************  Find organizational units as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-18 12:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A1 P1-P2 BPI 2020
#  ***************************  Academic
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-18 13:24:15.966942
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2022-03-18 14:24:15.966942
#  ***************************  Calculate throughput
# Fecha:
# 2022-03-18 15:24:15.966942
#  ***************************  Filter traces by attributes
# Fecha:
# 2022-03-18 16:24:15.966942
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2022-03-18 17:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-18 18:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A2 P1-P2 BPI 2020
#  ***************************  Student
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2022-03-18 19:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-18 20:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A7 P1-P2 BPI 2020
#  ***************************  Academic
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-18 21:24:15.966942
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-03-18 22:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-03-18 23:24:15.966942
#  ***************************  Calculate throughput
# Fecha:
# 2022-03-19 00:24:15.966942
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2022-03-19 01:24:15.966942
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2022-03-19 02:24:15.966942
#  ***************************  Calculate throughput
# Fecha:
# 2022-03-19 03:24:15.966942
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2022-03-19 04:24:15.966942
#  ***************************  Calculate throughput
# Fecha:
# 2022-03-19 05:24:15.966942
#  ***************************  Comparative of throughput
# Fecha:
# 2022-03-19 06:24:15.966942
#  ***************************  Represent scatterplot of cycle time and an attribute
# Fecha:
# 2022-03-19 07:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A10 P1-P2 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2022-03-19 08:24:15.966942
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-03-19 09:24:15.966942
#  ***************************  Represent boxplots of cycle time
# Fecha:
# 2022-03-19 10:24:15.966942
#  ***************************  Represent density diagram of cycle time
# Fecha:
# 2022-03-19 11:24:15.966942
#  ***************************  Filter traces by cycle time
# Fecha:
# 2022-03-19 12:24:15.966942
#  ***************************  Represent boxplots of cycle time
# Fecha:
# 2022-03-19 13:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-19 14:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A12 P1-P2 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate processing time
# Fecha:
# 2022-03-19 15:24:15.966942
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-19 16:24:15.966942
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-19 17:24:15.966942
#  ***************************  Calculate throughput
# Fecha:
# 2022-03-19 18:24:15.966942
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2022-03-19 19:24:15.966942
#  ***************************  Calculate throughput
# Fecha:
# 2022-03-19 20:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A13 P1-P2 BPI 2020
#  ***************************  Professional
#  ***************************  Represent bar charts of traces
# Fecha:
# 2022-03-19 21:24:15.966942
#  ***************************  Calculate throughput
# Fecha:
# 2022-03-19 22:24:15.966942
#  ***************************  Represent bar charts of traces
# Fecha:
# 2022-03-19 23:24:15.966942
#  ***************************  Group traces by year
# Fecha:
# 2022-03-20 00:24:15.966942
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-20 01:24:15.966942
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2022-03-20 02:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-03-20 03:24:15.966942
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-03-20 04:24:15.966942
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# Fecha:
# 2022-03-20 05:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-20 06:24:15.966942
#  ***************************  Identify specific subprocesses
# Fecha:
# 2022-03-20 07:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A18 P1-P2 BPI 2020
#  ***************************  Academic
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-20 08:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-03-20 09:24:15.966942
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2022-03-20 10:24:15.966942
#  ***************************  Represent boxplots of cycle time
# Fecha:
# 2022-03-20 11:24:15.966942
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2022-03-20 12:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A25 P1-P2 BPI 2020
#  ***************************  Student
#  ***************************  Filter traces by attributes
# Fecha:
# 2022-03-20 13:24:15.966942
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2022-03-20 14:24:15.966942
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-03-20 15:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-20 16:24:15.966942
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2022-03-20 17:24:15.966942
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-03-20 18:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-20 19:24:15.966942
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2022-03-20 20:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A26 P1-P2 BPI 2020
#  ***************************  Professional
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-20 21:24:15.966942
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-20 22:24:15.966942
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2022-03-20 23:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-21 00:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A28 P1-P2 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2022-03-21 01:24:15.966942
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2022-03-21 02:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-21 03:24:15.966942
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-03-21 04:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-21 05:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A35 P1-P2 BPI 2020
#  ***************************  Professional
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-21 06:24:15.966942
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-03-21 07:24:15.966942
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2022-03-21 08:24:15.966942
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-03-21 09:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-21 10:24:15.966942
#  ***************************  Group traces by year
# Fecha:
# 2022-03-21 11:24:15.966942
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-03-21 12:24:15.966942
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2022-03-21 13:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-03-21 14:24:15.966942
#  ***************************  Calculate number of activities
# Fecha:
# 2022-03-21 15:24:15.966942
#  ***************************  Calculate average of activities per trace
# Fecha:
# 2022-03-21 16:24:15.966942
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-03-21 17:24:15.966942
#  ***************************  Calculate Statistics of attributes
# Fecha:
# 2022-03-21 18:24:15.966942
#  ***************************  Group traces depending on attributes
# Fecha:
# 2022-03-21 19:24:15.966942
#  ***************************  Represent histograms of attributes
# Fecha:
# 2022-03-21 20:24:15.966942
#  ***************************  Represent bar charts of traces
# Fecha:
# 2022-03-21 21:24:15.966942
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-03-21 22:24:15.966942
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-21 23:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-22 00:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A37 P1-P2 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2022-03-22 01:24:15.966942
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2022-03-22 02:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-03-22 03:24:15.966942
#  ***************************  Calculate number of events
# Fecha:
# 2022-03-22 04:24:15.966942
#  ***************************  Calculate number of variants
# Fecha:
# 2022-03-22 05:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-03-22 06:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A1 P1 BPI 2017
#  ***************************  Student
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2022-03-22 07:24:15.966942
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2022-03-22 08:24:15.966942
#  ***************************  Filter events by attributes
# Fecha:
# 2022-03-22 09:24:15.966942
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# Fecha:
# 2022-03-22 10:24:15.966942
#  ***************************  Calculate frequency of events
# Fecha:
# 2022-03-22 11:24:15.966942
#  ***************************  Filter events by activities
# Fecha:
# 2022-03-22 12:24:15.966942
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# Fecha:
# 2022-03-22 13:24:15.966942
#  ***************************  Calculate frequency of events
# Fecha:
# 2022-03-22 14:24:15.966942
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-03-22 15:24:15.966942
#  ***************************  Find sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-22 16:24:15.966942
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-03-22 17:24:15.966942
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2022-03-22 18:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A2 P1 BPI 2017
#  ***************************  Student
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-22 19:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-22 20:24:15.966942
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-22 21:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-22 22:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A5 P1 BPI 2017
#  ***************************  Student
#  ***************************  Filter events by activities
# Fecha:
# 2022-03-22 23:24:15.966942
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2022-03-23 00:24:15.966942
#  ***************************  Calculate processing time
# Fecha:
# 2022-03-23 01:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-23 02:24:15.966942
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-23 03:24:15.966942
#  ***************************  Filter events by activities
# Fecha:
# 2022-03-23 04:24:15.966942
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2022-03-23 05:24:15.966942
#  ***************************  Calculate processing time
# Fecha:
# 2022-03-23 06:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-23 07:24:15.966942
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-23 08:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A6 P1 BPI 2017
#  ***************************  Student
#  ***************************  Discover process maps
# Fecha:
# 2022-03-23 09:24:15.966942
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-23 10:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-23 11:24:15.966942
#  ***************************  Calculate frequency of events
# Fecha:
# 2022-03-23 12:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-23 13:24:15.966942
#  ***************************  Calculate frequency of activities
# Fecha:
# 2022-03-23 14:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-03-23 15:24:15.966942
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# Fecha:
# 2022-03-23 16:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-23 17:24:15.966942
#  ***************************  Calculate processing time
# Fecha:
# 2022-03-23 18:24:15.966942
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-03-23 19:24:15.966942
#  ***************************  Group traces by cycle time
# Fecha:
# 2022-03-23 20:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-03-23 21:24:15.966942
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-03-23 22:24:15.966942
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-23 23:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A7 P1 BPI 2017
#  ***************************  Student
#  ***************************  Calculate number of activities
# Fecha:
# 2022-03-24 00:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-24 01:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-24 02:24:15.966942
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2022-03-24 03:24:15.966942
#  ***************************  Group traces by waiting
# Fecha:
# 2022-03-24 04:24:15.966942
#  ***************************  Calculate percentage of events
# Fecha:
# 2022-03-24 05:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-24 06:24:15.966942
#  ***************************  Identify resources by activities
# Fecha:
# 2022-03-24 07:24:15.966942
#  ***************************  Calculate frequency of resources
# Fecha:
# 2022-03-24 08:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-24 09:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A8 P1 BPI 2017
#  ***************************  Student
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-24 10:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-24 11:24:15.966942
#  ***************************  Represent bar charts of waiting time
# Fecha:
# 2022-03-24 12:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-24 13:24:15.966942
#  ***************************  Represent bar charts of waiting time
# Fecha:
# 2022-03-24 14:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-24 15:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-24 16:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A9 P1 BPI 2017
#  ***************************  Student
#  ***************************  Calculate processing time
# Fecha:
# 2022-03-24 17:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-24 18:24:15.966942
#  ***************************  Compare waiting time with processing time
# Fecha:
# 2022-03-24 19:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-24 20:24:15.966942
#  ***************************  Group activities by role
# Fecha:
# 2022-03-24 21:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-24 22:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-24 23:24:15.966942
#  ***************************  Represent histograms of waiting time
# Fecha:
# 2022-03-25 00:24:15.966942
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2022-03-25 01:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A10 P1 BPI 2017
#  ***************************  Student
#  ***************************  Filter traces by attributes
# Fecha:
# 2022-03-25 02:24:15.966942
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-25 03:24:15.966942
#  ***************************  Calculate cycle time for all pairs of events for a subset of traces
# Fecha:
# 2022-03-25 04:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-25 05:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-25 06:24:15.966942
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2022-03-25 07:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A11 P1 BPI 2017
#  ***************************  Student
#  ***************************  Group traces by activities
# Fecha:
# 2022-03-25 08:24:15.966942
#  ***************************  Calculate number of events
# Fecha:
# 2022-03-25 09:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-03-25 10:24:15.966942
#  ***************************  Calculate number of activities
# Fecha:
# 2022-03-25 11:24:15.966942
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2022-03-25 12:24:15.966942
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-25 13:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-25 14:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-25 15:24:15.966942
#  ***************************  Filter traces by cycle time
# Fecha:
# 2022-03-25 16:24:15.966942
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-03-25 17:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-25 18:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A13 P1 BPI 2017
#  ***************************  Student
#  ***************************  Represent process map with frequency
# Fecha:
# 2022-03-25 19:24:15.966942
#  ***************************  Represent histograms of waiting time
# Fecha:
# 2022-03-25 20:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-25 21:24:15.966942
#  ***************************  Find sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-25 22:24:15.966942
#  ***************************  Filter traces by activities
# Fecha:
# 2022-03-25 23:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-03-26 00:24:15.966942
#  ***************************  Represent process map with frequency
# Fecha:
# 2022-03-26 01:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A14 P1 BPI 2017
#  ***************************  Student
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2022-03-26 02:24:15.966942
#  ***************************  Group traces by activities
# Fecha:
# 2022-03-26 03:24:15.966942
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-03-26 04:24:15.966942
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2022-03-26 05:24:15.966942
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2022-03-26 06:24:15.966942
#  ***************************  Find sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-26 07:24:15.966942
#  ***************************  Group traces depending on attributes
# Fecha:
# 2022-03-26 08:24:15.966942
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-03-26 09:24:15.966942
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2022-03-26 10:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A15 P1 BPI 2017
#  ***************************  Professional
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-26 11:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-03-26 12:24:15.966942
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2022-03-26 13:24:15.966942
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-03-26 14:24:15.966942
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2022-03-26 15:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A16 P1 BPI 2017
#  ***************************  Professional
#  ***************************  Represent process map with cycle time
# Fecha:
# 2022-03-26 16:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-26 17:24:15.966942
#  ***************************  Group traces by activities
# Fecha:
# 2022-03-26 18:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-03-26 19:24:15.966942
#  ***************************  Calculate waiting time
# Fecha:
# 2022-03-26 20:24:15.966942
#  ***************************  Group traces by activities
# Fecha:
# 2022-03-26 21:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-03-26 22:24:15.966942
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# Fecha:
# 2022-03-26 23:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A17 P1 BPI 2017
#  ***************************  Professional
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2022-03-27 00:24:15.966942
# ...
# Fecha:
# 2022-04-15 18:24:15.966942
#  ***************************  Group events by attributes
# Fecha:
# 2022-04-15 19:24:15.966942
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2022-04-15 20:24:15.966942
#  ***************************  Group traces depending on attributes
# Fecha:
# 2022-04-15 21:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-04-15 22:24:15.966942
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2022-04-15 23:24:15.966942
#  ***************************  Identify attributes by cycle time
# Fecha:
# 2022-04-16 00:24:15.966942
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2022-04-16 01:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A30 P1-P2 BPI 2020
#  ***************************  Academic
#  ***************************  Filter traces by activities
# Fecha:
# 2022-04-16 02:24:15.966942
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-04-16 03:24:15.966942
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2022-04-16 04:24:15.966942
#  ***************************  Filter traces by activities
# Fecha:
# 2022-04-16 05:24:15.966942
#  ***************************  Represent temporal series of traces
# Fecha:
# 2022-04-16 06:24:15.966942
#  ***************************  Represent temporal series of traces
# Fecha:
# 2022-04-16 07:24:15.966942
#  ***************************  Group traces by month
# Fecha:
# 2022-04-16 08:24:15.966942
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2022-04-16 09:24:15.966942
#  ***************************  Identify values of attributes
# Fecha:
# 2022-04-16 10:24:15.966942
#  ***************************  Group traces by month
# Fecha:
# 2022-04-16 11:24:15.966942
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2022-04-16 12:24:15.966942
#  ***************************  Identify values of attributes
# Fecha:
# 2022-04-16 13:24:15.966942
#  ***************************  Identify values of attributes
# Fecha:
# 2022-04-16 14:24:15.966942
#  ***************************  Identify values of attributes
# Fecha:
# 2022-04-16 15:24:15.966942
#  ***************************  Calculate number of events
# Fecha:
# 2022-04-16 16:24:15.966942
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2022-04-16 17:24:15.966942
#  ***************************  Identify values of attributes
# Fecha:
# 2022-04-16 18:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A31 P1-P2 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2022-04-16 19:24:15.966942
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2022-04-16 20:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-04-16 21:24:15.966942
#  ***************************  Compare cycle time
# Fecha:
# 2022-04-16 22:24:15.966942
#  ***************************  Calculate throughput
# Fecha:
# 2022-04-16 23:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A34 P1-P2 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2022-04-17 00:24:15.966942
#  ***************************  Filter traces by subprocesses
# Fecha:
# 2022-04-17 01:24:15.966942
#  ***************************  Group traces by sub-processes
# Fecha:
# 2022-04-17 02:24:15.966942
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2022-04-17 03:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A27 P5 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-04-17 04:24:15.966942
#  ***************************  Calculate frequency of activities
# Fecha:
# 2022-04-17 05:24:15.966942
#  ***************************  Filter events by activities
# Fecha:
# 2022-04-17 06:24:15.966942
#  ***************************  Filter activities by cycle time
# Fecha:
# 2022-04-17 07:24:15.966942
#  ***************************  Filter activities by frequency
# Fecha:
# 2022-04-17 08:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria and statistical measures
# Fecha:
# 2022-04-17 09:24:15.966942
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-04-17 10:24:15.966942
#  ***************************  Calculate frequency of activities
# Fecha:
# 2022-04-17 11:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria and statistical measures
# Fecha:
# 2022-04-17 12:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A27 P1-P2 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate frequency of activities
# Fecha:
# 2022-04-17 13:24:15.966942
#  ***************************  Represent bart charts of activities
# Fecha:
# 2022-04-17 14:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A19 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Filter traces by frequency
# Fecha:
# 2022-04-17 15:24:15.966942
#  ***************************  Group traces by activities
# Fecha:
# 2022-04-17 16:24:15.966942
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-04-17 17:24:15.966942
#  ***************************  Identify activities with cycle time
# Fecha:
# 2022-04-17 18:24:15.966942
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2022-04-17 19:24:15.966942
#  ***************************  Identify transitions by cycle time
# Fecha:
# 2022-04-17 20:24:15.966942
#  ***************************  Group traces by activities
# Fecha:
# 2022-04-17 21:24:15.966942
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-04-17 22:24:15.966942
#  ***************************  Filter traces by frequency
# Fecha:
# 2022-04-17 23:24:15.966942
#  ***************************  Group traces by activities
# Fecha:
# 2022-04-18 00:24:15.966942
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-04-18 01:24:15.966942
#  ***************************  Group traces by activities
# Fecha:
# 2022-04-18 02:24:15.966942
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-04-18 03:24:15.966942
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2022-04-18 04:24:15.966942
#  ***************************  Identify roles by organizational units
# Fecha:
# 2022-04-18 05:24:15.966942
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2022-04-18 06:24:15.966942
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-04-18 07:24:15.966942
#  ***************************  Identify activities with traces
# Fecha:
# 2022-04-18 08:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A27 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Group activities by role
# Fecha:
# 2022-04-18 09:24:15.966942
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-04-18 10:24:15.966942
#  ***************************  Calculate number of events
# Fecha:
# 2022-04-18 11:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A31 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2022-04-18 12:24:15.966942
#  ***************************  Identify activities with cycle time
# Fecha:
# 2022-04-18 13:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A19 P5 BPI 2020
#  ***************************  Professional
#  ***************************  Filter traces by frequency
# Fecha:
# 2022-04-18 14:24:15.966942
#  ***************************  Group traces by activities
# Fecha:
# 2022-04-18 15:24:15.966942
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-04-18 16:24:15.966942
#  ***************************  Identify activities with cycle time
# Fecha:
# 2022-04-18 17:24:15.966942
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2022-04-18 18:24:15.966942
#  ***************************  Identify transitions by cycle time
# Fecha:
# 2022-04-18 19:24:15.966942
#  ***************************  Group traces by activities
# Fecha:
# 2022-04-18 20:24:15.966942
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-04-18 21:24:15.966942
#  ***************************  Filter traces by frequency
# Fecha:
# 2022-04-18 22:24:15.966942
#  ***************************  Group traces by activities
# Fecha:
# 2022-04-18 23:24:15.966942
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-04-19 00:24:15.966942
#  ***************************  Group traces by activities
# Fecha:
# 2022-04-19 01:24:15.966942
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-04-19 02:24:15.966942
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2022-04-19 03:24:15.966942
#  ***************************  Identify roles by organizational units
# Fecha:
# 2022-04-19 04:24:15.966942
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2022-04-19 05:24:15.966942
#  ***************************  Identify transitions by cycle time
# Fecha:
# 2022-04-19 06:24:15.966942
#  ***************************  Identify activities with traces
# Fecha:
# 2022-04-19 07:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A30 P5 BPI 2020
#  ***************************  Academic
#  ***************************  Filter activities by frequency
# Fecha:
# 2022-04-19 08:24:15.966942
#  ***************************  Calculate cycle time for all pairs of events for a subset of traces
# Fecha:
# 2022-04-19 09:24:15.966942
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2022-04-19 10:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-04-19 11:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-04-19 12:24:15.966942
#  ***************************  Represent bar charts of traces
# Fecha:
# 2022-04-19 13:24:15.966942
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-04-19 14:24:15.966942
#  ***************************  Filter traces by activities
# Fecha:
# 2022-04-19 15:24:15.966942
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-04-19 16:24:15.966942
#  ***************************  Filter traces by activities
# Fecha:
# 2022-04-19 17:24:15.966942
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-04-19 18:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A34 P5 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2022-04-19 19:24:15.966942
#  ***************************  Calculate frequency of activities
# Fecha:
# 2022-04-19 20:24:15.966942
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2022-04-19 21:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria and statistical measures
# Fecha:
# 2022-04-19 22:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A30 P6 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-04-19 23:24:15.966942
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-04-20 00:24:15.966942
#  ***************************  Identify transitions by cycle time
# Fecha:
# 2022-04-20 01:24:15.966942
# -----------------------------------------------------------------------
# Case:id
# A19 P1-P2 BPI 2020
#  ***************************  Professional
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2022-04-20 02:24:15.966942
#  ***************************  Group traces by year
# Fecha:
# 2022-04-20 03:24:15.966942
#  ***************************  Calculate number of traces
# Fecha:
# 2022-04-20 04:24:15.966942
#  ***************************  Represent temporal series of traces
# Fecha:
# 2022-04-20 05:24:15.966942
#  ***************************  Filter events by activities
# Fecha:
# 2022-04-20 06:24:15.966942
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-04-20 07:24:15.966942
#  ***************************  Group traces by year
# Fecha:
# 2022-04-20 08:24:15.966942
#  ***************************  Group traces by activities
# Fecha:
# 2022-04-20 09:24:15.966942
#  ***************************  Calculate Statistics of activities
# Fecha:
# 2022-04-20 10:24:15.966942
#  ***************************  Calculate throughput
# Fecha:
# 2022-04-20 11:24:15.966942
#  ***************************  Represent temporal series of throughput
# Fecha:
# 2022-04-20 12:24:15.966942
#  ***************************  Comparative of throughput
# Fecha:
# 2022-04-20 13:24:15.966942
#                 case:id   case:concept:name               concept:name  \
# 0        A2 P4 BPI 2020      A2 P4 BPI 2020          Filter activities
# 1        A2 P4 BPI 2020      A2 P4 BPI 2020           Group activities
# 2        A2 P4 BPI 2020      A2 P4 BPI 2020       Calculate cycle time
# 3        A7 P4 BPI 2020      A7 P4 BPI 2020           Group activities
# 4        A7 P4 BPI 2020      A7 P4 BPI 2020       Calculate throughput
# ..                  ...                 ...                        ...
# 950  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020               Group traces
# 951  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020       Calculate statistics
# 952  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020       Calculate throughput
# 953  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020  Represent temporal series
# 954  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020  Comparative of throughput
#
#                                                Variant  \
# 0                   Filter activities by sub-processes
# 1                    Group activities by sub-processes
# 2    Calculate cycle time for all pairs of events f...
# 3                             Group activities by role
# 4                                 Calculate throughput
# ..                                                 ...
# 950                         Group traces by activities
# 951                 Calculate Statistics of activities
# 952                               Calculate throughput
# 953            Represent temporal series of throughput
# 954                          Comparative of throughput
#
#                  time:timestamp Question Report  Year      Category
# 0    2022-03-11 19:24:15.966942       P4     A2  2020       Student
# 1    2022-03-11 20:24:15.966942       P4     A2  2020       Student
# 2    2022-03-11 21:24:15.966942       P4     A2  2020       Student
# 3    2022-03-11 22:24:15.966942       P4     A7  2020      Academic
# 4    2022-03-11 23:24:15.966942       P4     A7  2020      Academic
# ..                          ...      ...    ...   ...           ...
# 950  2022-04-20 09:24:15.966942    P1-P2    A19  2020  Professional
# 951  2022-04-20 10:24:15.966942    P1-P2    A19  2020  Professional
# 952  2022-04-20 11:24:15.966942    P1-P2    A19  2020  Professional
# 953  2022-04-20 12:24:15.966942    P1-P2    A19  2020  Professional
# 954  2022-04-20 13:24:15.966942    P1-P2    A19  2020  Professional
#
# [955 rows x 9 columns]

# %%
#df_prueba=df_prueba.rename({'Specific operation':'Variant'},axis='columns')
df_prueba
# Out:
#                 case:id   case:concept:name               concept:name  \
# 0        A2 P4 BPI 2020      A2 P4 BPI 2020          Filter activities
# 1        A2 P4 BPI 2020      A2 P4 BPI 2020           Group activities
# 2        A2 P4 BPI 2020      A2 P4 BPI 2020       Calculate cycle time
# 3        A7 P4 BPI 2020      A7 P4 BPI 2020           Group activities
# 4        A7 P4 BPI 2020      A7 P4 BPI 2020       Calculate throughput
# ..                  ...                 ...                        ...
# 950  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020               Group traces
# 951  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020       Calculate statistics
# 952  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020       Calculate throughput
# 953  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020  Represent temporal series
# 954  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020  Comparative of throughput
#
#                                                Variant  \
# 0                   Filter activities by sub-processes
# 1                    Group activities by sub-processes
# 2    Calculate cycle time for all pairs of events f...
# 3                             Group activities by role
# 4                                 Calculate throughput
# ..                                                 ...
# 950                         Group traces by activities
# 951                 Calculate Statistics of activities
# 952                               Calculate throughput
# 953            Represent temporal series of throughput
# 954                          Comparative of throughput
#
#                  time:timestamp Question Report  Year      Category
# 0    2022-03-11 19:24:15.966942       P4     A2  2020       Student
# 1    2022-03-11 20:24:15.966942       P4     A2  2020       Student
# 2    2022-03-11 21:24:15.966942       P4     A2  2020       Student
# 3    2022-03-11 22:24:15.966942       P4     A7  2020      Academic
# 4    2022-03-11 23:24:15.966942       P4     A7  2020      Academic
# ..                          ...      ...    ...   ...           ...
# 950  2022-04-20 09:24:15.966942    P1-P2    A19  2020  Professional
# 951  2022-04-20 10:24:15.966942    P1-P2    A19  2020  Professional
# 952  2022-04-20 11:24:15.966942    P1-P2    A19  2020  Professional
# 953  2022-04-20 12:24:15.966942    P1-P2    A19  2020  Professional
# 954  2022-04-20 13:24:15.966942    P1-P2    A19  2020  Professional
#
# [955 rows x 9 columns]

# %%
# type(df_prueba.iloc[2]['time:timestamp'])

# %%
# for i in range(len(df_prueba)):   
#     df_prueba.iloc[i]['time:timestamp'] = datetime.datetime.strptime(df_prueba.iloc[i]['time:timestamp'], '%Y-%m-%d %H:%M:%S.%f')

# %%
# type(df_prueba.iloc[2]['time:timestamp'])

# %%
df_categorias_autores=df_prueba

# %%
cycleTimeOperations=["Calculate cycle time","Find bottlenecks","Compare cycle time", "Calculate waiting time",
                     "Calculate throughput","Calculate processing time", "Compare waiting time with processing time", 
                     "Analyze cycle time depending on the events",
                     "Calculate intervals of time of the traces",
                     'Comparative of throughput','Compare processing time',]

# %%
manipulationOperations=[
    "Filter traces","Group traces", "Group activities","Preprocess the traces of the logs", "Filter activities",
    "Filter events","Preprocess the events of the logs", "Group organizational units", "Group events by time",
    "Filter variants depending on frequency", 'Group events by attributes','Group sub-processes', 'Filter sub-processes'
]

# %%
statisticOperations=[
    "Calculate number of elements", "Calculate percentages","Calculate frequency", "Calculate statistics",
    "Calculate average of activities per trace"
]

# %%
representationOperations=[
    "Represent process map", "Represent histograms", "Represent bar charts", "Represent scatter plot",
    "Represent heat maps of cycle time and an attribute", "Represent circular charts of attributes of the traces","Represent box plots of cycle time", 
    "Represent temporal series of sub-processes", "Represent density diagram of cycle time","Discover and Replay a Log on Petri Net",
    "Represent temporal series", 'Represent boxplots of cycle time','Represent correlation graph of variables',
    'Represent heatmaps', 'Represent lineal distribution of an attribute by traces', 'Represent linear tendency of cycle time with respect an attribute',
    'Represent scatterplot of cycle time and an attribute'
]

# %%
identificationOperations=[
    "Identify roles", "Identify resources", "Identify values of attributes", "Identify dates", 
    "Identify specific sub-processes", "Identify impact of bottlenecks by organizational unit",
    "Identify activity with biggest backlog","Identify attributes", 'Identify activities',
    'Identify attributes','Identify organizational units', 'Identify specific subprocesses',
    'Identify traces by cycle time','Identify transitions by cycle time',
]

# %%
otherOperations=[
    "Assign resource to each activity", "Apply machine learning techniques", "Apply decision trees",
    "Discover happy path of the process",'Discover process maps','Calculate dates of the development of activities of resources'
]

# %%
listTypesOperations=[]
listOthers=[]
for index, row in df_categorias_autores.iterrows():
    if row['concept:name'] in cycleTimeOperations:
        listTypesOperations.append("Analyze Time")
    elif row['concept:name'] in manipulationOperations:
        listTypesOperations.append("Manipulation")
    elif row['concept:name'] in statisticOperations:
        listTypesOperations.append("Calculate statistics")
    elif row['concept:name'] in representationOperations:
        listTypesOperations.append("Representation")
    elif row['concept:name'] in identificationOperations:
        listTypesOperations.append("Identification")
    else:
        listTypesOperations.append("Others")

# %%
df_categorias_autores['Type']=listTypesOperations

# %%
df_categorias_autores
# Out:
#                 case:id   case:concept:name               concept:name  \
# 0        A2 P4 BPI 2020      A2 P4 BPI 2020          Filter activities
# 1        A2 P4 BPI 2020      A2 P4 BPI 2020           Group activities
# 2        A2 P4 BPI 2020      A2 P4 BPI 2020       Calculate cycle time
# 3        A7 P4 BPI 2020      A7 P4 BPI 2020           Group activities
# 4        A7 P4 BPI 2020      A7 P4 BPI 2020       Calculate throughput
# ..                  ...                 ...                        ...
# 950  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020               Group traces
# 951  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020       Calculate statistics
# 952  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020       Calculate throughput
# 953  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020  Represent temporal series
# 954  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020  Comparative of throughput
#
#                                                Variant  \
# 0                   Filter activities by sub-processes
# 1                    Group activities by sub-processes
# 2    Calculate cycle time for all pairs of events f...
# 3                             Group activities by role
# 4                                 Calculate throughput
# ..                                                 ...
# 950                         Group traces by activities
# 951                 Calculate Statistics of activities
# 952                               Calculate throughput
# 953            Represent temporal series of throughput
# 954                          Comparative of throughput
#
#                  time:timestamp Question Report  Year      Category  \
# 0    2022-03-11 19:24:15.966942       P4     A2  2020       Student
# 1    2022-03-11 20:24:15.966942       P4     A2  2020       Student
# 2    2022-03-11 21:24:15.966942       P4     A2  2020       Student
# 3    2022-03-11 22:24:15.966942       P4     A7  2020      Academic
# 4    2022-03-11 23:24:15.966942       P4     A7  2020      Academic
# ..                          ...      ...    ...   ...           ...
# 950  2022-04-20 09:24:15.966942    P1-P2    A19  2020  Professional
# 951  2022-04-20 10:24:15.966942    P1-P2    A19  2020  Professional
# 952  2022-04-20 11:24:15.966942    P1-P2    A19  2020  Professional
# 953  2022-04-20 12:24:15.966942    P1-P2    A19  2020  Professional
# 954  2022-04-20 13:24:15.966942    P1-P2    A19  2020  Professional
#
#                      Type
# 0            Manipulation
# 1            Manipulation
# 2            Analyze Time
# 3            Manipulation
# 4            Analyze Time
# ..                    ...
# 950          Manipulation
# 951  Calculate statistics
# 952          Analyze Time
# 953        Representation
# 954          Analyze Time
#
# [955 rows x 10 columns]

# %%
reports = pd.read_excel("./Reports BPI Challenge.xlsx")
reports['BPI Challenge'] = reports['BPI Challenge'].fillna(method='pad')

reports['BPI Challenge'] = reports['BPI Challenge'].astype(int)
reports["BPI Challenge"]=reports["BPI Challenge"].apply(str)

reports["Unnamed: 1"]=reports["Unnamed: 1"].apply(str)
reports['Tupla'] = reports['Unnamed: 1'] + reports["BPI Challenge"]

df_categorias_autores["Year"]=df_categorias_autores["Year"].apply(str)
df_categorias_autores['Tupla'] = df_categorias_autores['Report'] + df_categorias_autores["Year"]

sLength = len(df_categorias_autores['Tupla'])
df_categorias_autores['Organization'] = pd.Series(np.random.randn(sLength), index=df_categorias_autores.index)

# df_categorias_autores['prueba']= ""
df_categorias_autores.drop(['Organization'], axis=1)

df_categorias_autores['Organization'] = ""
for d in range(len(df_categorias_autores)):
    for r in range(len(reports)):
        if(df_categorias_autores.loc[d]['Tupla'] == reports.loc[r]['Tupla']):
#             print('si')
#             print(reports.iloc[r]['Universidad/Organización'])
#             lista.append(reports.loc[r]['Universidad/Organización'])
              string = reports.loc[r]['University/Organization']
              df_categorias_autores.iloc[d]['Organization'] = string
#         ''.join(filter(str.isalnum, string))
    
#               df_categorias_autores.iloc[d]['Organization'] = 'hola'
    
df_categorias_autores.drop(['Tupla'], axis=1)
# Out:
#                 case:id   case:concept:name               concept:name  \
# 0        A2 P4 BPI 2020      A2 P4 BPI 2020          Filter activities
# 1        A2 P4 BPI 2020      A2 P4 BPI 2020           Group activities
# 2        A2 P4 BPI 2020      A2 P4 BPI 2020       Calculate cycle time
# 3        A7 P4 BPI 2020      A7 P4 BPI 2020           Group activities
# 4        A7 P4 BPI 2020      A7 P4 BPI 2020       Calculate throughput
# ..                  ...                 ...                        ...
# 950  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020               Group traces
# 951  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020       Calculate statistics
# 952  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020       Calculate throughput
# 953  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020  Represent temporal series
# 954  A19 P1-P2 BPI 2020  A19 P1-P2 BPI 2020  Comparative of throughput
#
#                                                Variant  \
# 0                   Filter activities by sub-processes
# 1                    Group activities by sub-processes
# 2    Calculate cycle time for all pairs of events f...
# 3                             Group activities by role
# 4                                 Calculate throughput
# ..                                                 ...
# 950                         Group traces by activities
# 951                 Calculate Statistics of activities
# 952                               Calculate throughput
# 953            Represent temporal series of throughput
# 954                          Comparative of throughput
#
#                  time:timestamp Question Report  Year      Category  \
# 0    2022-03-11 19:24:15.966942       P4     A2  2020       Student
# 1    2022-03-11 20:24:15.966942       P4     A2  2020       Student
# 2    2022-03-11 21:24:15.966942       P4     A2  2020       Student
# 3    2022-03-11 22:24:15.966942       P4     A7  2020      Academic
# 4    2022-03-11 23:24:15.966942       P4     A7  2020      Academic
# ..                          ...      ...    ...   ...           ...
# 950  2022-04-20 09:24:15.966942    P1-P2    A19  2020  Professional
# 951  2022-04-20 10:24:15.966942    P1-P2    A19  2020  Professional
# 952  2022-04-20 11:24:15.966942    P1-P2    A19  2020  Professional
# 953  2022-04-20 12:24:15.966942    P1-P2    A19  2020  Professional
# 954  2022-04-20 13:24:15.966942    P1-P2    A19  2020  Professional
#
#                      Type                                       Organization
# 0            Manipulation             Faculty of Science, Utrecht University
# 1            Manipulation             Faculty of Science, Utrecht University
# 2            Analyze Time             Faculty of Science, Utrecht University
# 3            Manipulation  German Research Center for Artificial Intellig...
# 4            Analyze Time  German Research Center for Artificial Intellig...
# ..                    ...                                                ...
# 950          Manipulation                                           Sberbank
# 951  Calculate statistics                                           Sberbank
# 952          Analyze Time                                           Sberbank
# 953        Representation                                           Sberbank
# 954          Analyze Time                                           Sberbank
#
# [955 rows x 11 columns]

# %%
df_categorias_autores.to_csv("Log of analysis of time aspects.csv")
log = log_converter.apply(df_categorias_autores)
xes_exporter.apply(log, './Log of analysis of time aspects.xes')
# Out:
# HBox(children=(IntProgress(value=0, description='exporting log, completed traces :: ', max=110, style=Progress…
