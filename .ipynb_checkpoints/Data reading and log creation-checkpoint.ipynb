# %%
import pandas as pd
import datetime
from os import listdir
import os, os.path
from os.path import isfile, join
import numpy as np
import csv
import re
import pandas as pd
import pm4py
from pm4py.objects.conversion.log import converter as log_converter
from pm4py.objects.log.importer.xes import importer as xes_importer
from pm4py.objects.log.exporter.xes import exporter as xes_exporter
from pm4py.objects.log.util import dataframe_utils

# %%
datos_raw = pd.read_excel("./grouped table of annotations.xlsx")#table with annotations
#datos_raw=datos_raw.drop(['Unnamed: 0'], axis='columns')
glosario = pd.read_excel("./OperationCoding.xlsx")#operation code that relates operation with variants
glosario['Operations'] = glosario['Operations'].fillna(method='pad')#name of the operations
glosario['Variants'] =  glosario['Variants'].str.split().str.join(' ')#name of the variants
glosario['Operations'] =  glosario['Operations'].str.split().str.join(' ')

columns=['case:id','case:concept:name','concept:name','Variant','time:timestamp','Question','Report','Year', 'Category']
#columna es el case_ID
cont = 0
df_prueba= pd.DataFrame(columns=columns)
ct=datetime.datetime.now()
for columna in datos_raw.columns:
    print("-----------------------------------------------------------------------")
    print("Case:id")
    print(columna)
    acciones_analisis=datos_raw[columna].dropna()
    for accion in acciones_analisis:
        
        accion = re.sub('[\xa0]', ' ', accion)
        print(' *************************** ', accion)
        string_dividido=accion.split(' ')
        accion = ' '.join(string_dividido)
        for fila in range(len(glosario)):
                     
            if(accion == glosario['Variants'][fila]):
                #print('si', accion)
                accionGeneral=glosario['Operations'][fila]
                accionEspecifica=accion
                columnaSeparada=columna.split()
                category=datos_raw.loc[0][columna]
                report=columnaSeparada[0]
                pregunta=columnaSeparada[1]
                año=columnaSeparada[3]
                ct=ct+datetime.timedelta(hours=1)
                print("Fecha:") 
                print(ct)
                new_row={'case:id':columna, 'case:concept:name':columna, 'concept:name':accionGeneral,'Variant':accionEspecifica,'time:timestamp':str(ct),'Question':pregunta,'Report':report,'Year':año, 'Category':category} 
                #print(cont, new_row['case:concept:name'])
                cont = cont +1
                df_prueba = df_prueba.append(new_row, ignore_index=True)
                
            elif(accion == glosario['Operations'][fila]):
                #print('no', accion)
                accionGeneral=accion
                accionEspecifica=accion
                columnaSeparada=columna.split()
                category=datos_raw.loc[0][columna]
                pregunta=columnaSeparada[1]
                report=columnaSeparada[0]
                año=columnaSeparada[3]
                ct=ct+ datetime.timedelta(hours=1)
                print("Fecha:") 
                print(ct)
                new_row={'case:id':columna, 'case:concept:name':columna, 'concept:name':accionGeneral,'Variant':accionEspecifica,'time:timestamp':str(ct),'Question':pregunta,'Report':report,'Year':año, 'Category':category} 
                #print(cont, new_row['case:concept:name'])
                cont = cont +1
                df_prueba = df_prueba.append(new_row, ignore_index=True)
            
                
            
df_prueba
# Out:
# -----------------------------------------------------------------------
# Case:id
# A1 P2 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-11-30 12:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-11-30 13:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A2 P2 BPI 2020
#  ***************************  Student
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-11-30 14:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-11-30 15:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A7 P2 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate throughput
# Fecha:
# 2021-11-30 16:54:15.489743
#  ***************************  Comparative of throughput
# Fecha:
# 2021-11-30 17:54:15.489743
#  ***************************  Comparative of throughput
# Fecha:
# 2021-11-30 18:54:15.489743
#  ***************************  Represent scatterplot
# Fecha:
# 2021-11-30 19:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A10 P2 BPI 2020
#  ***************************  Academic
#  ***************************  Represent boxplots of cycle time
# Fecha:
# 2021-11-30 20:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-11-30 21:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A12 P2 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate throughput
# Fecha:
# 2021-11-30 22:54:15.489743
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-11-30 23:54:15.489743
#  ***************************  Calculate throughput
# Fecha:
# 2021-12-01 00:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A13 P2 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# Fecha:
# 2021-12-01 01:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-01 02:54:15.489743
#  ***************************  Identify specific subprocesses
# Fecha:
# 2021-12-01 03:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A18 P2 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-12-01 04:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A25 P2 BPI 2020
#  ***************************  Student
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-12-01 05:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-01 06:54:15.489743
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-12-01 07:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A26 P2 BPI 2020
#  ***************************  Professional
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-12-01 08:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-01 09:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A28 P2 BPI 2020
#  ***************************  Professional
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-12-01 10:54:15.489743
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-12-01 11:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-01 12:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A35 P2 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-12-01 13:54:15.489743
#  ***************************  Calculate number of traces
# Fecha:
# 2021-12-01 14:54:15.489743
#  ***************************  Calculate number of activities
# Fecha:
# 2021-12-01 15:54:15.489743
#  ***************************  Calculate average of activities per trace
# Fecha:
# 2021-12-01 16:54:15.489743
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-12-01 17:54:15.489743
#  ***************************  Calculate Statistics of attributes
# Fecha:
# 2021-12-01 18:54:15.489743
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-12-01 19:54:15.489743
#  ***************************  Represent histograms of attributes
# Fecha:
# 2021-12-01 20:54:15.489743
#  ***************************  Represent bar charts of traces
# Fecha:
# 2021-12-01 21:54:15.489743
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-12-01 22:54:15.489743
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-01 23:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-02 00:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A37 P2 BPI 2020
#  ***************************  Professional
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-12-02 01:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-02 02:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A2 P4 BPI 2020
#  ***************************  Student
#  ***************************  Filter activities by sub-processes
# Fecha:
# 2021-12-02 03:54:15.489743
#  ***************************  Group activities by sub-processes
# Fecha:
# 2021-12-02 04:54:15.489743
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-12-02 05:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A7 P4 BPI 2020
#  ***************************  Academic
#  ***************************  Group activities by role
# Fecha:
# 2021-12-02 06:54:15.489743
#  ***************************  Calculate throughput
# Fecha:
# 2021-12-02 07:54:15.489743
#  ***************************  Group activities by time
# Fecha:
# 2021-12-02 08:54:15.489743
#  ***************************  Calculate number of activities
# Fecha:
# 2021-12-02 09:54:15.489743
#  ***************************  Represent scatterplot
# Fecha:
# 2021-12-02 10:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A10 P4 BPI 2020
#  ***************************  Academic
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-02 11:54:15.489743
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-12-02 12:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A12 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-12-02 13:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A13 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-02 14:54:15.489743
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-12-02 15:54:15.489743
#  ***************************  Group activities by sub-processes
# Fecha:
# 2021-12-02 16:54:15.489743
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# Fecha:
# 2021-12-02 17:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A18 P4 BPI 2020
#  ***************************  Academic
#  ***************************  Represent process map with frequency
# Fecha:
# 2021-12-02 18:54:15.489743
#  ***************************  Calculate cycle time of only a subset of pairs of events for a subset of traces
# Fecha:
# 2021-12-02 19:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A25 P4 BPI 2020
#  ***************************  Student
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-12-02 20:54:15.489743
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-12-02 21:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-02 22:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A26 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Filter variants depending on frequency
# Fecha:
# 2021-12-02 23:54:15.489743
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-12-03 00:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A28 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-12-03 01:54:15.489743
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-12-03 02:54:15.489743
#  ***************************  Represent heatmaps
# Fecha:
# 2021-12-03 03:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-03 04:54:15.489743
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-12-03 05:54:15.489743
#  ***************************  Represent heatmaps
# Fecha:
# 2021-12-03 06:54:15.489743
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-12-03 07:54:15.489743
#  ***************************  Represent heatmaps
# Fecha:
# 2021-12-03 08:54:15.489743
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-12-03 09:54:15.489743
#  ***************************  Represent heatmaps
# Fecha:
# 2021-12-03 10:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A35 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-03 11:54:15.489743
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-12-03 12:54:15.489743
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-12-03 13:54:15.489743
#  ***************************  Calculate number of traces
# Fecha:
# 2021-12-03 14:54:15.489743
#  ***************************  Calculate number of activities
# Fecha:
# 2021-12-03 15:54:15.489743
#  ***************************  Calculate average of activities per trace
# Fecha:
# 2021-12-03 16:54:15.489743
#  ***************************  Group traces by roles
# Fecha:
# 2021-12-03 17:54:15.489743
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-12-03 18:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A37 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-12-03 19:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A1 P5 BPI 2020
#  ***************************  Academic
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-12-03 20:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-03 21:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A2 P5 BPI 2020
#  ***************************  Student
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-12-03 22:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-03 23:54:15.489743
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-04 00:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A7 P5 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-12-04 01:54:15.489743
#  ***************************  Filter activities by cycle time
# Fecha:
# 2021-12-04 02:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-04 03:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A10 P5 BPI 2020
#  ***************************  Academic
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-12-04 04:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-04 05:54:15.489743
#  ***************************  Calculate number of activities
# Fecha:
# 2021-12-04 06:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A12 P5 BPI 2020
#  ***************************  Professional
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-12-04 07:54:15.489743
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-12-04 08:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-04 09:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A13 P5 BPI 2020
#  ***************************  Professional
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-04 10:54:15.489743
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-12-04 11:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-04 12:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A18 P5 BPI 2020
#  ***************************  Academic
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-12-04 13:54:15.489743
#  ***************************  Find sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-04 14:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A25 P5 BPI 2020
#  ***************************  Student
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-12-04 15:54:15.489743
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-12-04 16:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-04 17:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A26 P5 BPI 2020
#  ***************************  Professional
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-04 18:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-04 19:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A28 P5 BPI 2020
#  ***************************  Professional
#  ***************************  Find sub-processes with incorrect orders with respect to the happy path as bottlenecks
# Fecha:
# 2021-12-04 20:54:15.489743
#  ***************************  Calculate number of activities
# Fecha:
# 2021-12-04 21:54:15.489743
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-12-04 22:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A35 P5 BPI 2020
#  ***************************  Professional
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-12-04 23:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-05 00:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A37 P5 BPI 2020
#  ***************************  Professional
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-12-05 01:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-05 02:54:15.489743
#  ***************************  Find sub-processes with incorrect orders with respect to the happy path as bottlenecks
# Fecha:
# 2021-12-05 03:54:15.489743
#  ***************************  Calculate frequency of attributes
# Fecha:
# 2021-12-05 04:54:15.489743
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-12-05 05:54:15.489743
#  ***************************  Calculate number of activities
# Fecha:
# 2021-12-05 06:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A1 P6 BPI 2020
#  ***************************  Academic
#  ***************************  Filter traces depending on the order of activities
# Fecha:
# 2021-12-05 07:54:15.489743
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-12-05 08:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A2 P6 BPI 2020
#  ***************************  Student
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-12-05 09:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-05 10:54:15.489743
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-05 11:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A7 P6 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-12-05 12:54:15.489743
#  ***************************  Filter activities by cycle time
# Fecha:
# 2021-12-05 13:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-05 14:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A10 P6 BPI 2020
#  ***************************  Academic
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-05 15:54:15.489743
#  ***************************  Calculate number of activities
# Fecha:
# 2021-12-05 16:54:15.489743
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-12-05 17:54:15.489743
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-05 18:54:15.489743
#  ***************************  Calculate number of activities
# Fecha:
# 2021-12-05 19:54:15.489743
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-12-05 20:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A12 P6 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-12-05 21:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-05 22:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A13 P6 BPI 2020
#  ***************************  Professional
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-12-05 23:54:15.489743
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-06 00:54:15.489743
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# Fecha:
# 2021-12-06 01:54:15.489743
#  ***************************  Calculate frequency of variants
# Fecha:
# 2021-12-06 02:54:15.489743
#  ***************************  Calculate intervals of time of the traces
# Fecha:
# 2021-12-06 03:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-06 04:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A25 P6 BPI 2020
#  ***************************  Student
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-12-06 05:54:15.489743
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-12-06 06:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-06 07:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A26 P6 BPI 2020
#  ***************************  Professional
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-12-06 08:54:15.489743
#  ***************************  Get process map from the previous question
# Fecha:
# 2021-12-06 09:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-06 10:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A28 P6 BPI 2020
#  ***************************  Professional
#  ***************************  Find sub-processes with incorrect orders with respect to the happy path as bottlenecks
# Fecha:
# 2021-12-06 11:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A35 P6 BPI 2020
#  ***************************  Professional
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-06 12:54:15.489743
#  ***************************  Find sub-processes with incorrect orders with respect to the happy path as bottlenecks
# Fecha:
# 2021-12-06 13:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A37 P6 BPI 2020
#  ***************************  Professional
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-06 14:54:15.489743
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-12-06 15:54:15.489743
#  ***************************  Calculate number of variants
# Fecha:
# 2021-12-06 16:54:15.489743
#  ***************************  Calculate number of different organizational units
# Fecha:
# 2021-12-06 17:54:15.489743
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-12-06 18:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-06 19:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A2 P5 BPI 2015
#  ***************************  Student
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-12-06 20:54:15.489743
#  ***************************  Filter events by cycle time
# Fecha:
# 2021-12-06 21:54:15.489743
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-12-06 22:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-06 23:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A3 P5 BPI 2015
#  ***************************  Professional
#  ***************************  Group activities by sub-processes
# Fecha:
# 2021-12-07 00:54:15.489743
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-12-07 01:54:15.489743
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-07 02:54:15.489743
#  ***************************  Filter activities by frequency
# Fecha:
# 2021-12-07 03:54:15.489743
#  ***************************  Represent bar charts of traces
# Fecha:
# 2021-12-07 04:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-07 05:54:15.489743
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-07 06:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A4 P5 BPI 2015
#  ***************************  Academic
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-12-07 07:54:15.489743
#  ***************************  Find organizational units as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-07 08:54:15.489743
#  ***************************  Identify impact of bottlenecks by organizational unit
# Fecha:
# 2021-12-07 09:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-07 10:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A7 P5 BPI 2015
#  ***************************  Academic
#  ***************************  Filter traces by attributes
# Fecha:
# 2021-12-07 11:54:15.489743
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-12-07 12:54:15.489743
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-12-07 13:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-07 14:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-07 15:54:15.489743
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-07 16:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A8 P5 BPI 2015
#  ***************************  Professional
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-12-07 17:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-07 18:54:15.489743
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-12-07 19:54:15.489743
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-12-07 20:54:15.489743
#  ***************************  Group traces by cycle time
# Fecha:
# 2021-12-07 21:54:15.489743
#  ***************************  Group traces by organizational units
# Fecha:
# 2021-12-07 22:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-07 23:54:15.489743
#  ***************************  Analyze cycle time depending on the events
# Fecha:
# 2021-12-08 00:54:15.489743
#  ***************************  Calculate number of traces
# Fecha:
# 2021-12-08 01:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-08 02:54:15.489743
#  ***************************  Filter activities by frequency
# Fecha:
# 2021-12-08 03:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-08 04:54:15.489743
#  ***************************  Calculate frequency of activities
# Fecha:
# 2021-12-08 05:54:15.489743
#  ***************************  Calculate cycle time of only a subset of pairs of events for each subset of traces
# Fecha:
# 2021-12-08 06:54:15.489743
#  ***************************  Find organizational units as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-08 07:54:15.489743
#  ***************************  Identify resource associated with bottlenecks
# Fecha:
# 2021-12-08 08:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A9 P5 BPI 2015
#  ***************************  Student
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-08 09:54:15.489743
#  ***************************  Calculate cycle time for all pairs of events for a subset of traces
# Fecha:
# 2021-12-08 10:54:15.489743
#  ***************************  Group traces by cycle time
# Fecha:
# 2021-12-08 11:54:15.489743
#  ***************************  Apply decision trees
# Fecha:
# 2021-12-08 12:54:15.489743
#  ***************************  Group organizational units
# Fecha:
# 2021-12-08 13:54:15.489743
#  ***************************  Calculate number of traces
# Fecha:
# 2021-12-08 14:54:15.489743
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-12-08 15:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-08 16:54:15.489743
#  ***************************  Find organizational units as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-08 17:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A1 P1 BPI 2020
#  ***************************  Academic
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-08 18:54:15.489743
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-12-08 19:54:15.489743
#  ***************************  Calculate throughput
# Fecha:
# 2021-12-08 20:54:15.489743
#  ***************************  Filter traces by attributes
# Fecha:
# 2021-12-08 21:54:15.489743
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-12-08 22:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A2 P1 BPI 2020
#  ***************************  Student
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-12-08 23:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A7 P1 BPI 2020
#  ***************************  Academic
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-09 00:54:15.489743
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-12-09 01:54:15.489743
#  ***************************  Calculate number of traces
# Fecha:
# 2021-12-09 02:54:15.489743
#  ***************************  Calculate throughput
# Fecha:
# 2021-12-09 03:54:15.489743
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-12-09 04:54:15.489743
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-12-09 05:54:15.489743
#  ***************************  Calculate throughput
# Fecha:
# 2021-12-09 06:54:15.489743
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-12-09 07:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A10 P1 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-12-09 08:54:15.489743
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-12-09 09:54:15.489743
#  ***************************  Represent boxplots of cycle time
# Fecha:
# 2021-12-09 10:54:15.489743
#  ***************************  Represent density of cycle time
# Fecha:
# 2021-12-09 11:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A12 P1 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate processing time
# Fecha:
# 2021-12-09 12:54:15.489743
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-09 13:54:15.489743
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-09 14:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A13 P1 BPI 2020
#  ***************************  Professional
#  ***************************  Represent bar charts of traces
# Fecha:
# 2021-12-09 15:54:15.489743
#  ***************************  Calculate throughput
# Fecha:
# 2021-12-09 16:54:15.489743
#  ***************************  Represent bar charts of traces
# Fecha:
# 2021-12-09 17:54:15.489743
#  ***************************  Group traces by year
# Fecha:
# 2021-12-09 18:54:15.489743
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-09 19:54:15.489743
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-12-09 20:54:15.489743
#  ***************************  Calculate number of traces
# Fecha:
# 2021-12-09 21:54:15.489743
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-12-09 22:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A18 P1 BPI 2020
#  ***************************  Academic
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-09 23:54:15.489743
#  ***************************  Calculate number of traces
# Fecha:
# 2021-12-10 00:54:15.489743
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-12-10 01:54:15.489743
#  ***************************  Represent boxplots of cycle time
# Fecha:
# 2021-12-10 02:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A25 P1 BPI 2020
#  ***************************  Student
#  ***************************  Filter traces by attributes
# Fecha:
# 2021-12-10 03:54:15.489743
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-12-10 04:54:15.489743
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-12-10 05:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-10 06:54:15.489743
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-12-10 07:54:15.489743
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-12-10 08:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A26 P1 BPI 2020
#  ***************************  Professional
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-10 09:54:15.489743
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-10 10:54:15.489743
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-12-10 11:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A28 P1 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-12-10 12:54:15.489743
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-12-10 13:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-10 14:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A35 P1 BPI 2020
#  ***************************  Professional
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-10 15:54:15.489743
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-12-10 16:54:15.489743
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-12-10 17:54:15.489743
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-12-10 18:54:15.489743
#  ***************************  Compare cycle time
# Fecha:
# 2021-12-10 19:54:15.489743
#  ***************************  Group traces by year
# Fecha:
# 2021-12-10 20:54:15.489743
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-12-10 21:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A37 P1 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-12-10 22:54:15.489743
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-12-10 23:54:15.489743
#  ***************************  Calculate number of traces
# Fecha:
# 2021-12-11 00:54:15.489743
#  ***************************  Calculate number of events
# Fecha:
# 2021-12-11 01:54:15.489743
#  ***************************  Calculate number of variants
# Fecha:
# 2021-12-11 02:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A1 P1 BPI 2017
#  ***************************  Student
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-12-11 03:54:15.489743
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-12-11 04:54:15.489743
#  ***************************  Filter events by attributes
# Fecha:
# 2021-12-11 05:54:15.489743
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# Fecha:
# 2021-12-11 06:54:15.489743
#  ***************************  Calculate frequency of events
# Fecha:
# 2021-12-11 07:54:15.489743
#  ***************************  Filter events by activities
# Fecha:
# 2021-12-11 08:54:15.489743
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# Fecha:
# 2021-12-11 09:54:15.489743
#  ***************************  Calculate frequency of events
# Fecha:
# 2021-12-11 10:54:15.489743
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-12-11 11:54:15.489743
#  ***************************  Find sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-11 12:54:15.489743
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-12-11 13:54:15.489743
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-12-11 14:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A2 P1 BPI 2017
#  ***************************  Student
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-11 15:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-11 16:54:15.489743
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-11 17:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-11 18:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A5 P1 BPI 2017
#  ***************************  Student
#  ***************************  Filter events by activities
# Fecha:
# 2021-12-11 19:54:15.489743
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-12-11 20:54:15.489743
#  ***************************  Calculate processing time
# Fecha:
# 2021-12-11 21:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-11 22:54:15.489743
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-11 23:54:15.489743
#  ***************************  Filter events by activities
# Fecha:
# 2021-12-12 00:54:15.489743
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-12-12 01:54:15.489743
#  ***************************  Calculate processing time
# Fecha:
# 2021-12-12 02:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-12 03:54:15.489743
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-12 04:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A6 P1 BPI 2017
#  ***************************  Student
#  ***************************  Discover process maps
# Fecha:
# 2021-12-12 05:54:15.489743
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-12 06:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-12 07:54:15.489743
#  ***************************  Calculate frequency of events
# Fecha:
# 2021-12-12 08:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-12 09:54:15.489743
#  ***************************  Calculate frequency of activities
# Fecha:
# 2021-12-12 10:54:15.489743
#  ***************************  Calculate number of traces
# Fecha:
# 2021-12-12 11:54:15.489743
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# Fecha:
# 2021-12-12 12:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-12 13:54:15.489743
#  ***************************  Calculate processing time
# Fecha:
# 2021-12-12 14:54:15.489743
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-12-12 15:54:15.489743
#  ***************************  Group traces by cycle time
# Fecha:
# 2021-12-12 16:54:15.489743
#  ***************************  Calculate number of traces
# Fecha:
# 2021-12-12 17:54:15.489743
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-12-12 18:54:15.489743
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-12 19:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A7 P1 BPI 2017
#  ***************************  Student
#  ***************************  Calculate number of activities
# Fecha:
# 2021-12-12 20:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-12 21:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-12 22:54:15.489743
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2021-12-12 23:54:15.489743
#  ***************************  Group traces by waiting
# Fecha:
# 2021-12-13 00:54:15.489743
#  ***************************  Calculate percentage of events
# Fecha:
# 2021-12-13 01:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-13 02:54:15.489743
#  ***************************  Identify resources by activities
# Fecha:
# 2021-12-13 03:54:15.489743
#  ***************************  Calculate frequency of resources
# Fecha:
# 2021-12-13 04:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-13 05:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A8 P1 BPI 2017
#  ***************************  Student
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-13 06:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-13 07:54:15.489743
#  ***************************  Represent bar charts of waiting time
# Fecha:
# 2021-12-13 08:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-13 09:54:15.489743
#  ***************************  Represent bar charts of waiting time
# Fecha:
# 2021-12-13 10:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-13 11:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-13 12:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A9 P1 BPI 2017
#  ***************************  Student
#  ***************************  Calculate processing time
# Fecha:
# 2021-12-13 13:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-13 14:54:15.489743
#  ***************************  Compare waiting time with processing time
# Fecha:
# 2021-12-13 15:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-13 16:54:15.489743
#  ***************************  Group activities by role
# Fecha:
# 2021-12-13 17:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-13 18:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-13 19:54:15.489743
#  ***************************  Represent histograms of waiting time
# Fecha:
# 2021-12-13 20:54:15.489743
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2021-12-13 21:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A10 P1 BPI 2017
#  ***************************  Student
#  ***************************  Filter traces by attributes
# Fecha:
# 2021-12-13 22:54:15.489743
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-13 23:54:15.489743
#  ***************************  Calculate cycle time for all pairs of events for a subset of traces
# Fecha:
# 2021-12-14 00:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-14 01:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-14 02:54:15.489743
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2021-12-14 03:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A11 P1 BPI 2017
#  ***************************  Student
#  ***************************  Group traces by activities
# Fecha:
# 2021-12-14 04:54:15.489743
#  ***************************  Calculate number of events
# Fecha:
# 2021-12-14 05:54:15.489743
#  ***************************  Calculate number of traces
# Fecha:
# 2021-12-14 06:54:15.489743
#  ***************************  Calculate number of activities
# Fecha:
# 2021-12-14 07:54:15.489743
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-12-14 08:54:15.489743
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-14 09:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-14 10:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-14 11:54:15.489743
#  ***************************  Filter traces by cycle time
# Fecha:
# 2021-12-14 12:54:15.489743
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-12-14 13:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-14 14:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A13 P1 BPI 2017
#  ***************************  Student
#  ***************************  Represent process map with frequency
# Fecha:
# 2021-12-14 15:54:15.489743
#  ***************************  Represent histograms of waiting time
# Fecha:
# 2021-12-14 16:54:15.489743
#  ***************************  Calculate waiting time
# Fecha:
# 2021-12-14 17:54:15.489743
#  ***************************  Find sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-14 18:54:15.489743
#  ***************************  Filter traces by activities
# Fecha:
# 2021-12-14 19:54:15.489743
#  ***************************  Calculate number of traces
# Fecha:
# 2021-12-14 20:54:15.489743
#  ***************************  Represent process map with frequency
# Fecha:
# 2021-12-14 21:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A14 P1 BPI 2017
#  ***************************  Student
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-12-14 22:54:15.489743
#  ***************************  Group traces by activities
# Fecha:
# 2021-12-14 23:54:15.489743
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-12-15 00:54:15.489743
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-12-15 01:54:15.489743
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-12-15 02:54:15.489743
#  ***************************  Find sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-12-15 03:54:15.489743
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-12-15 04:54:15.489743
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-12-15 05:54:15.489743
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-12-15 06:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A15 P1 BPI 2017
#  ***************************  Professional
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-12-15 07:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# ...
# 2022-01-04 04:54:15.489743
#  ***************************  Group traces depending on attributes
# Fecha:
# 2022-01-04 05:54:15.489743
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2022-01-04 06:54:15.489743
#  ***************************  Group traces depending on attributes
# Fecha:
# 2022-01-04 07:54:15.489743
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2022-01-04 08:54:15.489743
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2022-01-04 09:54:15.489743
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2022-01-04 10:54:15.489743
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2022-01-04 11:54:15.489743
#  ***************************  Group traces depending on attributes
# Fecha:
# 2022-01-04 12:54:15.489743
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# Fecha:
# 2022-01-04 13:54:15.489743
#  ***************************  Group traces depending on attributes
# Fecha:
# 2022-01-04 14:54:15.489743
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2022-01-04 15:54:15.489743
#  ***************************  Group events by attributes
# Fecha:
# 2022-01-04 16:54:15.489743
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2022-01-04 17:54:15.489743
#  ***************************  Group traces depending on attributes
# Fecha:
# 2022-01-04 18:54:15.489743
#  ***************************  Calculate number of traces
# Fecha:
# 2022-01-04 19:54:15.489743
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2022-01-04 20:54:15.489743
#  ***************************  Identify attributes by cycle time
# Fecha:
# 2022-01-04 21:54:15.489743
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2022-01-04 22:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A30 P1 BPI 2020
#  ***************************  Academic
#  ***************************  Filter traces by activities
# Fecha:
# 2022-01-04 23:54:15.489743
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-01-05 00:54:15.489743
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2022-01-05 01:54:15.489743
#  ***************************  Filter traces by activities
# Fecha:
# 2022-01-05 02:54:15.489743
#  ***************************  Represent temporal series of traces
# Fecha:
# 2022-01-05 03:54:15.489743
#  ***************************  Represent temporal series of traces
# Fecha:
# 2022-01-05 04:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A31 P1 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2022-01-05 05:54:15.489743
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2022-01-05 06:54:15.489743
#  ***************************  Calculate number of traces
# Fecha:
# 2022-01-05 07:54:15.489743
#  ***************************  Calculate throughput
# Fecha:
# 2022-01-05 08:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A34 P1 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2022-01-05 09:54:15.489743
#  ***************************  Filter traces by subprocesses
# Fecha:
# 2022-01-05 10:54:15.489743
#  ***************************  Group traces by sub-processes
# Fecha:
# 2022-01-05 11:54:15.489743
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2022-01-05 12:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A27 P2 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate frequency of activities
# Fecha:
# 2022-01-05 13:54:15.489743
#  ***************************  Represent bart charts of activities
# Fecha:
# 2022-01-05 14:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A30 P2 BPI 2020
#  ***************************  Academic
#  ***************************  Group traces by month
# Fecha:
# 2022-01-05 15:54:15.489743
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2022-01-05 16:54:15.489743
#  ***************************  Identify values of attributes
# Fecha:
# 2022-01-05 17:54:15.489743
#  ***************************  Group traces by month
# Fecha:
# 2022-01-05 18:54:15.489743
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2022-01-05 19:54:15.489743
#  ***************************  Identify values of attributes
# Fecha:
# 2022-01-05 20:54:15.489743
#  ***************************  Identify values of attributes
# Fecha:
# 2022-01-05 21:54:15.489743
#  ***************************  Identify values of attributes
# Fecha:
# 2022-01-05 22:54:15.489743
#  ***************************  Calculate number of events
# Fecha:
# 2022-01-05 23:54:15.489743
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2022-01-06 00:54:15.489743
#  ***************************  Identify values of attributes
# Fecha:
# 2022-01-06 01:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A31 P2 BPI 2020
#  ***************************  Professional
#  ***************************  Compare cycle time
# Fecha:
# 2022-01-06 02:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A19 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Filter traces by frequency
# Fecha:
# 2022-01-06 03:54:15.489743
#  ***************************  Group traces by activities
# Fecha:
# 2022-01-06 04:54:15.489743
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-01-06 05:54:15.489743
#  ***************************  Identify activities with cycle time
# Fecha:
# 2022-01-06 06:54:15.489743
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2022-01-06 07:54:15.489743
#  ***************************  Identify transitions by cycle time
# Fecha:
# 2022-01-06 08:54:15.489743
#  ***************************  Group traces by activities
# Fecha:
# 2022-01-06 09:54:15.489743
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-01-06 10:54:15.489743
#  ***************************  Filter traces by frequency
# Fecha:
# 2022-01-06 11:54:15.489743
#  ***************************  Group traces by activities
# Fecha:
# 2022-01-06 12:54:15.489743
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-01-06 13:54:15.489743
#  ***************************  Group traces by activities
# Fecha:
# 2022-01-06 14:54:15.489743
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-01-06 15:54:15.489743
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2022-01-06 16:54:15.489743
#  ***************************  Identify roles by organizational units
# Fecha:
# 2022-01-06 17:54:15.489743
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2022-01-06 18:54:15.489743
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-01-06 19:54:15.489743
#  ***************************  Identify activities with traces
# Fecha:
# 2022-01-06 20:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A27 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Group activities by role
# Fecha:
# 2022-01-06 21:54:15.489743
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-01-06 22:54:15.489743
#  ***************************  Calculate number of events
# Fecha:
# 2022-01-06 23:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A31 P4 BPI 2020
#  ***************************  Professional
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2022-01-07 00:54:15.489743
#  ***************************  Identify activities with cycle time
# Fecha:
# 2022-01-07 01:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A19 P5 BPI 2020
#  ***************************  Professional
#  ***************************  Filter traces by frequency
# Fecha:
# 2022-01-07 02:54:15.489743
#  ***************************  Group traces by activities
# Fecha:
# 2022-01-07 03:54:15.489743
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-01-07 04:54:15.489743
#  ***************************  Identify activities with cycle time
# Fecha:
# 2022-01-07 05:54:15.489743
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2022-01-07 06:54:15.489743
#  ***************************  Identify transitions by cycle time
# Fecha:
# 2022-01-07 07:54:15.489743
#  ***************************  Group traces by activities
# Fecha:
# 2022-01-07 08:54:15.489743
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-01-07 09:54:15.489743
#  ***************************  Filter traces by frequency
# Fecha:
# 2022-01-07 10:54:15.489743
#  ***************************  Group traces by activities
# Fecha:
# 2022-01-07 11:54:15.489743
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-01-07 12:54:15.489743
#  ***************************  Group traces by activities
# Fecha:
# 2022-01-07 13:54:15.489743
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-01-07 14:54:15.489743
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2022-01-07 15:54:15.489743
#  ***************************  Identify roles by organizational units
# Fecha:
# 2022-01-07 16:54:15.489743
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2022-01-07 17:54:15.489743
#  ***************************  Identify transitions by cycle time
# Fecha:
# 2022-01-07 18:54:15.489743
#  ***************************  Identify activities with traces
# Fecha:
# 2022-01-07 19:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A30 P5 BPI 2020
#  ***************************  Academic
#  ***************************  Filter activities by frequency
# Fecha:
# 2022-01-07 20:54:15.489743
#  ***************************  Calculate cycle time for all pairs of events for a subset of traces
# Fecha:
# 2022-01-07 21:54:15.489743
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2022-01-07 22:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-01-07 23:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-01-08 00:54:15.489743
#  ***************************  Represent bar charts of traces
# Fecha:
# 2022-01-08 01:54:15.489743
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2022-01-08 02:54:15.489743
#  ***************************  Filter traces by activities
# Fecha:
# 2022-01-08 03:54:15.489743
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-01-08 04:54:15.489743
#  ***************************  Filter traces by activities
# Fecha:
# 2022-01-08 05:54:15.489743
#  ***************************  Calculate percentage of traces
# Fecha:
# 2022-01-08 06:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A34 P5 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate frequency of activities
# Fecha:
# 2022-01-08 07:54:15.489743
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2022-01-08 08:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria and statistical measures
# Fecha:
# 2022-01-08 09:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A30 P6 BPI 2020
#  ***************************  Academic
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2022-01-08 10:54:15.489743
#  ***************************  Find activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2022-01-08 11:54:15.489743
#  ***************************  Identify transitions by cycle time
# Fecha:
# 2022-01-08 12:54:15.489743
# -----------------------------------------------------------------------
# Case:id
# A19 P1 BPI 2020
#  ***************************  Professional
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2022-01-08 13:54:15.489743
#  ***************************  Group traces by year
# Fecha:
# 2022-01-08 14:54:15.489743
#  ***************************  Calculate number of traces
# Fecha:
# 2022-01-08 15:54:15.489743
#  ***************************  Represent temporal series of traces
# Fecha:
# 2022-01-08 16:54:15.489743
#  ***************************  Filter events by activities
# Fecha:
# 2022-01-08 17:54:15.489743
#  ***************************  Represent temporal series of activities
# Fecha:
# 2022-01-08 18:54:15.489743
#  ***************************  Group traces by year
# Fecha:
# 2022-01-08 19:54:15.489743
#  ***************************  Group traces by activities
# Fecha:
# 2022-01-08 20:54:15.489743
#  ***************************  Calculate Statistics of activities
# Fecha:
# 2022-01-08 21:54:15.489743
#  ***************************  Calculate throughput
# Fecha:
# 2022-01-08 22:54:15.489743
#  ***************************  Represent temporal series of throughput
# Fecha:
# 2022-01-08 23:54:15.489743
#              case:id case:concept:name               concept:name  \
# 0     A1 P2 BPI 2020    A1 P2 BPI 2020       Calculate cycle time
# 1     A1 P2 BPI 2020    A1 P2 BPI 2020         Compare cycle time
# 2     A2 P2 BPI 2020    A2 P2 BPI 2020       Calculate cycle time
# 3     A2 P2 BPI 2020    A2 P2 BPI 2020         Compare cycle time
# 4     A7 P2 BPI 2020    A7 P2 BPI 2020       Calculate throughput
# ..               ...               ...                        ...
# 943  A19 P1 BPI 2020   A19 P1 BPI 2020               Group traces
# 944  A19 P1 BPI 2020   A19 P1 BPI 2020               Group traces
# 945  A19 P1 BPI 2020   A19 P1 BPI 2020       Calculate statistics
# 946  A19 P1 BPI 2020   A19 P1 BPI 2020       Calculate throughput
# 947  A19 P1 BPI 2020   A19 P1 BPI 2020  Represent temporal series
#
#                                                Variant  \
# 0    Calculate cycle time of the whole process for ...
# 1                                   Compare cycle time
# 2            Get cycle time from the previous question
# 3                                   Compare cycle time
# 4                                 Calculate throughput
# ..                                                 ...
# 943                               Group traces by year
# 944                         Group traces by activities
# 945                 Calculate Statistics of activities
# 946                               Calculate throughput
# 947            Represent temporal series of throughput
#
#                  time:timestamp Question Report  Year      Category
# 0    2021-11-30 12:54:15.489743       P2     A1  2020      Academic
# 1    2021-11-30 13:54:15.489743       P2     A1  2020      Academic
# 2    2021-11-30 14:54:15.489743       P2     A2  2020       Student
# 3    2021-11-30 15:54:15.489743       P2     A2  2020       Student
# 4    2021-11-30 16:54:15.489743       P2     A7  2020      Academic
# ..                          ...      ...    ...   ...           ...
# 943  2022-01-08 19:54:15.489743       P1    A19  2020  Professional
# 944  2022-01-08 20:54:15.489743       P1    A19  2020  Professional
# 945  2022-01-08 21:54:15.489743       P1    A19  2020  Professional
# 946  2022-01-08 22:54:15.489743       P1    A19  2020  Professional
# 947  2022-01-08 23:54:15.489743       P1    A19  2020  Professional
#
# [948 rows x 9 columns]

# %%
#df_prueba=df_prueba.rename({'Specific operation':'Variant'},axis='columns')
df_prueba
# Out:
#              case:id case:concept:name               concept:name  \
# 0     A1 P2 BPI 2020    A1 P2 BPI 2020       Calculate cycle time
# 1     A1 P2 BPI 2020    A1 P2 BPI 2020         Compare cycle time
# 2     A2 P2 BPI 2020    A2 P2 BPI 2020       Calculate cycle time
# 3     A2 P2 BPI 2020    A2 P2 BPI 2020         Compare cycle time
# 4     A7 P2 BPI 2020    A7 P2 BPI 2020       Calculate throughput
# ..               ...               ...                        ...
# 943  A19 P1 BPI 2020   A19 P1 BPI 2020               Group traces
# 944  A19 P1 BPI 2020   A19 P1 BPI 2020               Group traces
# 945  A19 P1 BPI 2020   A19 P1 BPI 2020       Calculate statistics
# 946  A19 P1 BPI 2020   A19 P1 BPI 2020       Calculate throughput
# 947  A19 P1 BPI 2020   A19 P1 BPI 2020  Represent temporal series
#
#                                                Variant  \
# 0    Calculate cycle time of the whole process for ...
# 1                                   Compare cycle time
# 2            Get cycle time from the previous question
# 3                                   Compare cycle time
# 4                                 Calculate throughput
# ..                                                 ...
# 943                               Group traces by year
# 944                         Group traces by activities
# 945                 Calculate Statistics of activities
# 946                               Calculate throughput
# 947            Represent temporal series of throughput
#
#                  time:timestamp Question Report  Year      Category
# 0    2021-11-30 12:54:15.489743       P2     A1  2020      Academic
# 1    2021-11-30 13:54:15.489743       P2     A1  2020      Academic
# 2    2021-11-30 14:54:15.489743       P2     A2  2020       Student
# 3    2021-11-30 15:54:15.489743       P2     A2  2020       Student
# 4    2021-11-30 16:54:15.489743       P2     A7  2020      Academic
# ..                          ...      ...    ...   ...           ...
# 943  2022-01-08 19:54:15.489743       P1    A19  2020  Professional
# 944  2022-01-08 20:54:15.489743       P1    A19  2020  Professional
# 945  2022-01-08 21:54:15.489743       P1    A19  2020  Professional
# 946  2022-01-08 22:54:15.489743       P1    A19  2020  Professional
# 947  2022-01-08 23:54:15.489743       P1    A19  2020  Professional
#
# [948 rows x 9 columns]

# %%
# type(df_prueba.iloc[2]['time:timestamp'])
# Out:
# str

# %%
# for i in range(len(df_prueba)):   
#     df_prueba.iloc[i]['time:timestamp'] = datetime.datetime.strptime(df_prueba.iloc[i]['time:timestamp'], '%Y-%m-%d %H:%M:%S.%f')

# %%
# type(df_prueba.iloc[2]['time:timestamp'])

# %%
df_categorias_autores=df_prueba

# %%
cycleTimeOperations=["Calculate cycle time","Find bottlenecks","Compare cycle time", "Calculate waiting time",
                     "Calculate throughput","Calculate processing time", "Compare waiting time with processing time", 
                     "Analyze cycle time depending on the events",
                     "Calculate intervals of time of the traces",
                     'Comparative of throughput','Compare processing time',]

# %%
manipulationOperations=[
    "Filter traces","Group traces", "Group activities","Preprocess the traces of the logs", "Filter activities",
    "Filter events","Preprocess the events of the logs", "Group organizational units", "Group events by time",
    "Filter variants depending on frequency", 'Group events by attributes','Group sub-processes', 'Filter sub-processes'
]

# %%
statisticOperations=[
    "Calculate number of elements", "Calculate percentages","Calculate frequency", "Calculate statistics",
    "Calculate average of activities per trace"
]

# %%
representationOperations=[
    "Represent process map", "Represent histograms", "Represent bar charts", "Represent scatter plot",
    "Represent heat maps of cycle time and an attribute", "Represent circular charts of attributes of the traces","Represent box plots of cycle time", 
    "Represent temporal series of sub-processes", "Represent density diagram of cycle time","Discover and Replay a Log on Petri Net",
    "Represent temporal series", 'Represent boxplots of cycle time','Represent correlation graph of variables',
    'Represent heatmaps', 'Represent lineal distribution of an attribute by traces', 'Represent linear tendency of cycle time with respect an attribute',
    'Represent scatterplot of cycle time and an attribute'
]

# %%
identificationOperations=[
    "Identify roles", "Identify resources", "Identify values of attributes", "Identify dates", 
    "Identify specific sub-processes", "Identify impact of bottlenecks by organizational unit",
    "Identify activity with biggest backlog","Identify attributes", 'Identify activities',
    'Identify attributes','Identify organizational units', 'Identify specific subprocesses',
    'Identify traces by cycle time','Identify transitions by cycle time',
]

# %%
otherOperations=[
    "Assign resource to each activity", "Apply machine learning techniques", "Apply decision trees",
    "Discover happy path of the process",'Discover process maps','Calculate dates of the development of activities of resources'
]

# %%
listTypesOperations=[]
listOthers=[]
for index, row in df_categorias_autores.iterrows():
    if row['concept:name'] in cycleTimeOperations:
        listTypesOperations.append("Analyze Time")
    elif row['concept:name'] in manipulationOperations:
        listTypesOperations.append("Manipulation")
    elif row['concept:name'] in statisticOperations:
        listTypesOperations.append("Calculate statistics")
    elif row['concept:name'] in representationOperations:
        listTypesOperations.append("Representation")
    elif row['concept:name'] in identificationOperations:
        listTypesOperations.append("Identification")
    else:
        listTypesOperations.append("Others")

# %%
df_categorias_autores['Type']=listTypesOperations

# %%
df_categorias_autores
# Out:
#              case:id case:concept:name               concept:name  \
# 0     A1 P2 BPI 2020    A1 P2 BPI 2020       Calculate cycle time
# 1     A1 P2 BPI 2020    A1 P2 BPI 2020         Compare cycle time
# 2     A2 P2 BPI 2020    A2 P2 BPI 2020       Calculate cycle time
# 3     A2 P2 BPI 2020    A2 P2 BPI 2020         Compare cycle time
# 4     A7 P2 BPI 2020    A7 P2 BPI 2020       Calculate throughput
# ..               ...               ...                        ...
# 943  A19 P1 BPI 2020   A19 P1 BPI 2020               Group traces
# 944  A19 P1 BPI 2020   A19 P1 BPI 2020               Group traces
# 945  A19 P1 BPI 2020   A19 P1 BPI 2020       Calculate statistics
# 946  A19 P1 BPI 2020   A19 P1 BPI 2020       Calculate throughput
# 947  A19 P1 BPI 2020   A19 P1 BPI 2020  Represent temporal series
#
#                                                Variant  \
# 0    Calculate cycle time of the whole process for ...
# 1                                   Compare cycle time
# 2            Get cycle time from the previous question
# 3                                   Compare cycle time
# 4                                 Calculate throughput
# ..                                                 ...
# 943                               Group traces by year
# 944                         Group traces by activities
# 945                 Calculate Statistics of activities
# 946                               Calculate throughput
# 947            Represent temporal series of throughput
#
#                  time:timestamp Question Report  Year      Category  \
# 0    2021-11-30 12:54:15.489743       P2     A1  2020      Academic
# 1    2021-11-30 13:54:15.489743       P2     A1  2020      Academic
# 2    2021-11-30 14:54:15.489743       P2     A2  2020       Student
# 3    2021-11-30 15:54:15.489743       P2     A2  2020       Student
# 4    2021-11-30 16:54:15.489743       P2     A7  2020      Academic
# ..                          ...      ...    ...   ...           ...
# 943  2022-01-08 19:54:15.489743       P1    A19  2020  Professional
# 944  2022-01-08 20:54:15.489743       P1    A19  2020  Professional
# 945  2022-01-08 21:54:15.489743       P1    A19  2020  Professional
# 946  2022-01-08 22:54:15.489743       P1    A19  2020  Professional
# 947  2022-01-08 23:54:15.489743       P1    A19  2020  Professional
#
#                      Type
# 0            Analyze Time
# 1            Analyze Time
# 2            Analyze Time
# 3            Analyze Time
# 4            Analyze Time
# ..                    ...
# 943          Manipulation
# 944          Manipulation
# 945  Calculate statistics
# 946          Analyze Time
# 947        Representation
#
# [948 rows x 10 columns]

# %%
reports = pd.read_excel("./Reports BPI Challenge.xlsx")
reports['BPI Challenge'] = reports['BPI Challenge'].fillna(method='pad')

reports['BPI Challenge'] = reports['BPI Challenge'].astype(int)
reports["BPI Challenge"]=reports["BPI Challenge"].apply(str)

reports["Unnamed: 1"]=reports["Unnamed: 1"].apply(str)
reports['Tupla'] = reports['Unnamed: 1'] + reports["BPI Challenge"]

df_categorias_autores["Year"]=df_categorias_autores["Year"].apply(str)
df_categorias_autores['Tupla'] = df_categorias_autores['Report'] + df_categorias_autores["Year"]

sLength = len(df_categorias_autores['Tupla'])
df_categorias_autores['Organization'] = pd.Series(np.random.randn(sLength), index=df_categorias_autores.index)

# df_categorias_autores['prueba']= ""
df_categorias_autores.drop(['Organization'], axis=1)

df_categorias_autores['Organization'] = ""
for d in range(len(df_categorias_autores)):
    for r in range(len(reports)):
        if(df_categorias_autores.loc[d]['Tupla'] == reports.loc[r]['Tupla']):
#             print('si')
#             print(reports.iloc[r]['Universidad/Organización'])
#             lista.append(reports.loc[r]['Universidad/Organización'])
              string = reports.loc[r]['University/Organization']
              df_categorias_autores.iloc[d]['Organization'] = string
#         ''.join(filter(str.isalnum, string))
    
#               df_categorias_autores.iloc[d]['Organization'] = 'hola'
    
df_categorias_autores.drop(['Tupla'], axis=1)
# Out:
#              case:id case:concept:name               concept:name  \
# 0     A1 P2 BPI 2020    A1 P2 BPI 2020       Calculate cycle time
# 1     A1 P2 BPI 2020    A1 P2 BPI 2020         Compare cycle time
# 2     A2 P2 BPI 2020    A2 P2 BPI 2020       Calculate cycle time
# 3     A2 P2 BPI 2020    A2 P2 BPI 2020         Compare cycle time
# 4     A7 P2 BPI 2020    A7 P2 BPI 2020       Calculate throughput
# ..               ...               ...                        ...
# 943  A19 P1 BPI 2020   A19 P1 BPI 2020               Group traces
# 944  A19 P1 BPI 2020   A19 P1 BPI 2020               Group traces
# 945  A19 P1 BPI 2020   A19 P1 BPI 2020       Calculate statistics
# 946  A19 P1 BPI 2020   A19 P1 BPI 2020       Calculate throughput
# 947  A19 P1 BPI 2020   A19 P1 BPI 2020  Represent temporal series
#
#                                                Variant  \
# 0    Calculate cycle time of the whole process for ...
# 1                                   Compare cycle time
# 2            Get cycle time from the previous question
# 3                                   Compare cycle time
# 4                                 Calculate throughput
# ..                                                 ...
# 943                               Group traces by year
# 944                         Group traces by activities
# 945                 Calculate Statistics of activities
# 946                               Calculate throughput
# 947            Represent temporal series of throughput
#
#                  time:timestamp Question Report  Year      Category  \
# 0    2021-11-30 12:54:15.489743       P2     A1  2020      Academic
# 1    2021-11-30 13:54:15.489743       P2     A1  2020      Academic
# 2    2021-11-30 14:54:15.489743       P2     A2  2020       Student
# 3    2021-11-30 15:54:15.489743       P2     A2  2020       Student
# 4    2021-11-30 16:54:15.489743       P2     A7  2020      Academic
# ..                          ...      ...    ...   ...           ...
# 943  2022-01-08 19:54:15.489743       P1    A19  2020  Professional
# 944  2022-01-08 20:54:15.489743       P1    A19  2020  Professional
# 945  2022-01-08 21:54:15.489743       P1    A19  2020  Professional
# 946  2022-01-08 22:54:15.489743       P1    A19  2020  Professional
# 947  2022-01-08 23:54:15.489743       P1    A19  2020  Professional
#
#                      Type                                       Organization
# 0            Analyze Time                     Technische Universität, Berlin
# 1            Analyze Time                     Technische Universität, Berlin
# 2            Analyze Time             Faculty of Science, Utrecht University
# 3            Analyze Time             Faculty of Science, Utrecht University
# 4            Analyze Time  German Research Center for Artificial Intellig...
# ..                    ...                                                ...
# 943          Manipulation                                           Sberbank
# 944          Manipulation                                           Sberbank
# 945  Calculate statistics                                           Sberbank
# 946          Analyze Time                                           Sberbank
# 947        Representation                                           Sberbank
#
# [948 rows x 11 columns]

# %%
df_categorias_autores.to_csv("Log of analysis of time aspects.csv")
log = log_converter.apply(df_categorias_autores)
xes_exporter.apply(log, './Log of analysis of time aspects.xes')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='exporting log, completed traces :: ', max=126.0, style=Pr…
