# %%
import pandas as pd
import datetime
from os import listdir
import os, os.path
from os.path import isfile, join
import numpy as np
import csv
import re
import pandas as pd
import pm4py
from pm4py.objects.conversion.log import converter as log_converter
from pm4py.objects.log.importer.xes import importer as xes_importer
from pm4py.objects.log.exporter.xes import exporter as xes_exporter
from pm4py.objects.log.util import dataframe_utils

# %%
datos_raw = pd.read_excel("./grouped table of annotations.xlsx")
datos_raw=datos_raw.drop(['Unnamed: 0'], axis='columns')
glosario = pd.read_excel("./OperationCoding (solo cycle time).xlsx")
glosario['General operations'] = glosario['General operations'].fillna(method='pad')
glosario['Specific operations'] =  glosario['Specific operations'].str.split().str.join(' ')
glosario['General operations'] =  glosario['General operations'].str.split().str.join(' ')

columns=['case:id','case:concept:name','concept:name','Specific operation','time:timestamp','Question','Year']
#columna es el case_ID
cont = 0
df_prueba= pd.DataFrame(columns=columns)
ct=datetime.datetime.now()
for columna in datos_raw.columns:
    print("-----------------------------------------------------------------------")
    print("Case:id")
    print(columna)
    acciones_analisis=datos_raw[columna].dropna()
    for accion in acciones_analisis:
        
        accion = re.sub('[\xa0]', ' ', accion)
        print(' *************************** ', accion)
        string_dividido=accion.split(' ')
        accion = ' '.join(string_dividido)
        for fila in range(len(glosario)):
                     
            if(accion == glosario['Specific operations'][fila]):
                #print('si', accion)
                accionGeneral=glosario['General operations'][fila]
                accionEspecifica=accion
                columnaSeparada=columna.split()
                pregunta=columnaSeparada[1]
                año=columnaSeparada[3]
                ct=ct+datetime.timedelta(hours=1)
                print("Fecha:") 
                print(ct)
                new_row={'case:id':columna, 'case:concept:name':columna, 'concept:name':accionGeneral,'Specific operation':accionEspecifica,'time:timestamp':str(ct),'Question':pregunta,'Year':año} 
                #print(cont, new_row['case:concept:name'])
                cont = cont +1
                df_prueba = df_prueba.append(new_row, ignore_index=True)
                
            elif(accion == glosario['General operations'][fila]):
                #print('no', accion)
                accionGeneral=accion
                accionEspecifica=" "
                columnaSeparada=columna.split()
                pregunta=columnaSeparada[1]
                año=columnaSeparada[3]
                ct=ct+ datetime.timedelta(hours=1)
                print("Fecha:") 
                print(ct)
                new_row={'case:id':columna, 'case:concept:name':columna, 'concept:name':accionGeneral,'Specific operation':accionEspecifica,'time:timestamp':str(ct),'Question':pregunta,'Year':año} 
                #print(cont, new_row['case:concept:name'])
                cont = cont +1
                df_prueba = df_prueba.append(new_row, ignore_index=True)
            
                
            
df_prueba
# Out:
# -----------------------------------------------------------------------
# Case:id
# A1 P2 BPI 2020
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-11 16:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-11 17:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A2 P2 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-11 18:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-11 19:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A7 P2 BPI 2020
#  ***************************  Calculate throughput
# Fecha:
# 2021-10-11 20:03:47.889443
#  ***************************  Comparative of throughput
# Fecha:
# 2021-10-11 21:03:47.889443
#  ***************************  Comparative of throughput
# Fecha:
# 2021-10-11 22:03:47.889443
#  ***************************  Represent scatterplot
# Fecha:
# 2021-10-11 23:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A10 P2 BPI 2020
#  ***************************  Represent boxplots of cycle time
# Fecha:
# 2021-10-12 00:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-12 01:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A12 P2 BPI 2020
#  ***************************  Calculate throughput
# Fecha:
# 2021-10-12 02:03:47.889443
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-10-12 03:03:47.889443
#  ***************************  Calculate throughput
# Fecha:
# 2021-10-12 04:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A13 P2 BPI 2020
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# Fecha:
# 2021-10-12 05:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-12 06:03:47.889443
#  ***************************  Identify specific subprocesses
# Fecha:
# 2021-10-12 07:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A18 P2 BPI 2020
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-10-12 08:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A25 P2 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-12 09:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-12 10:03:47.889443
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-12 11:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A26 P2 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-12 12:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-12 13:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A28 P2 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-12 14:03:47.889443
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-12 15:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-12 16:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A35 P2 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-10-12 17:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-12 18:03:47.889443
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-12 19:03:47.889443
#  ***************************  Calculate average of activities per trace
# Fecha:
# 2021-10-12 20:03:47.889443
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-12 21:03:47.889443
#  ***************************  Calculate Statistics of attributes
# Fecha:
# 2021-10-12 22:03:47.889443
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-10-12 23:03:47.889443
#  ***************************  Represent histograms of attributes
# Fecha:
# 2021-10-13 00:03:47.889443
#  ***************************  Represent bar charts of traces
# Fecha:
# 2021-10-13 01:03:47.889443
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-13 02:03:47.889443
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-13 03:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-13 04:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A37 P2 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-13 05:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-13 06:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A2 P4 BPI 2020
#  ***************************  Filter activities by sub-processes
# Fecha:
# 2021-10-13 07:03:47.889443
#  ***************************  Group activities by sub-processes
# Fecha:
# 2021-10-13 08:03:47.889443
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-10-13 09:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A7 P4 BPI 2020
#  ***************************  Group activities by role
# Fecha:
# 2021-10-13 10:03:47.889443
#  ***************************  Calculate throughput
# Fecha:
# 2021-10-13 11:03:47.889443
#  ***************************  Group activities by time
# Fecha:
# 2021-10-13 12:03:47.889443
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-13 13:03:47.889443
#  ***************************  Represent scatterplot
# Fecha:
# 2021-10-13 14:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A10 P4 BPI 2020
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-13 15:03:47.889443
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-13 16:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A12 P4 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-13 17:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A13 P4 BPI 2020
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-13 18:03:47.889443
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-13 19:03:47.889443
#  ***************************  Group activities by sub-processes
# Fecha:
# 2021-10-13 20:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# Fecha:
# 2021-10-13 21:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A18 P4 BPI 2020
#  ***************************  Represent process map with frequency
# Fecha:
# 2021-10-13 22:03:47.889443
#  ***************************  Calculate cycle time of only a subset of pairs of events for a subset of traces
# Fecha:
# 2021-10-13 23:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A25 P4 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-14 00:03:47.889443
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-10-14 01:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-14 02:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A26 P4 BPI 2020
#  ***************************  Filter variants depending on frequency
# Fecha:
# 2021-10-14 03:03:47.889443
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-14 04:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A28 P4 BPI 2020
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-10-14 05:03:47.889443
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-14 06:03:47.889443
#  ***************************  Represent heatmaps
# Fecha:
# 2021-10-14 07:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-14 08:03:47.889443
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-10-14 09:03:47.889443
#  ***************************  Represent heatmaps
# Fecha:
# 2021-10-14 10:03:47.889443
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-14 11:03:47.889443
#  ***************************  Represent heatmaps
# Fecha:
# 2021-10-14 12:03:47.889443
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-10-14 13:03:47.889443
#  ***************************  Represent heatmaps
# Fecha:
# 2021-10-14 14:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A35 P4 BPI 2020
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-14 15:03:47.889443
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-14 16:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-10-14 17:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-14 18:03:47.889443
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-14 19:03:47.889443
#  ***************************  Calculate average of activities per trace
# Fecha:
# 2021-10-14 20:03:47.889443
#  ***************************  Group traces by roles
# Fecha:
# 2021-10-14 21:03:47.889443
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-14 22:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A37 P4 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-14 23:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A1 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-15 00:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 01:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A2 P5 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-15 02:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 03:03:47.889443
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-15 04:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A7 P5 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-15 05:03:47.889443
#  ***************************  Filter activities by cycle time
# Fecha:
# 2021-10-15 06:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 07:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A10 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-15 08:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 09:03:47.889443
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-15 10:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A12 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-15 11:03:47.889443
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-10-15 12:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 13:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A13 P5 BPI 2020
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-15 14:03:47.889443
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-15 15:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 16:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A18 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-15 17:03:47.889443
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 18:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A25 P5 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-15 19:03:47.889443
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-10-15 20:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 21:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A26 P5 BPI 2020
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-15 22:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 23:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A28 P5 BPI 2020
#  ***************************  Identify sub-processes with incorrect orders with respect to the happy path as bottlenecks
# Fecha:
# 2021-10-16 00:03:47.889443
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-16 01:03:47.889443
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-16 02:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A35 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-16 03:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-16 04:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A37 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-16 05:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-16 06:03:47.889443
#  ***************************  Identify sub-processes with incorrect orders with respect to the happy path as bottlenecks
# Fecha:
# 2021-10-16 07:03:47.889443
#  ***************************  Calculate frequency of attributes
# Fecha:
# 2021-10-16 08:03:47.889443
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-16 09:03:47.889443
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-16 10:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A1 P6 BPI 2020
#  ***************************  Filter traces depending on the order of activities
# Fecha:
# 2021-10-16 11:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-10-16 12:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A2 P6 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-16 13:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-16 14:03:47.889443
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-16 15:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A7 P6 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-16 16:03:47.889443
#  ***************************  Filter activities by cycle time
# Fecha:
# 2021-10-16 17:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-16 18:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A10 P6 BPI 2020
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-16 19:03:47.889443
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-16 20:03:47.889443
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-10-16 21:03:47.889443
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-16 22:03:47.889443
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-16 23:03:47.889443
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-10-17 00:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A12 P6 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-17 01:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-17 02:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A13 P6 BPI 2020
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-10-17 03:03:47.889443
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-17 04:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# Fecha:
# 2021-10-17 05:03:47.889443
#  ***************************  Calculate frequency of variants
# Fecha:
# 2021-10-17 06:03:47.889443
#  ***************************  Calculate intervals of time of the traces
# Fecha:
# 2021-10-17 07:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-17 08:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A25 P6 BPI 2020
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-17 09:03:47.889443
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-17 10:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-17 11:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A26 P6 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-17 12:03:47.889443
#  ***************************  Get process map from the previous question
# Fecha:
# 2021-10-17 13:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-17 14:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A28 P6 BPI 2020
#  ***************************  Identify sub-processes with incorrect orders with respect to the happy path as bottlenecks
# Fecha:
# 2021-10-17 15:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A35 P6 BPI 2020
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-17 16:03:47.889443
#  ***************************  Identify sub-processes with incorrect orders with respect to the happy path as bottlenecks
# Fecha:
# 2021-10-17 17:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A37 P6 BPI 2020
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-17 18:03:47.889443
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-10-17 19:03:47.889443
#  ***************************  Calculate number of variants
# Fecha:
# 2021-10-17 20:03:47.889443
#  ***************************  Calculate number of different organizational units
# Fecha:
# 2021-10-17 21:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-10-17 22:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-17 23:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A2 P5 BPI 2015
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-18 00:03:47.889443
#  ***************************  Filter events by cycle time
# Fecha:
# 2021-10-18 01:03:47.889443
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-18 02:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-18 03:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A3 P5 BPI 2015
#  ***************************  Group activities by sub-processes
# Fecha:
# 2021-10-18 04:03:47.889443
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-10-18 05:03:47.889443
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-18 06:03:47.889443
#  ***************************  Filter activities by frequency
# Fecha:
# 2021-10-18 07:03:47.889443
#  ***************************  Represent bar charts of traces
# Fecha:
# 2021-10-18 08:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-18 09:03:47.889443
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-18 10:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A4 P5 BPI 2015
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-10-18 11:03:47.889443
#  ***************************  Identify organizational units as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-18 12:03:47.889443
#  ***************************  Identify impact of bottlenecks by organizational unit
# Fecha:
# 2021-10-18 13:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-18 14:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A7 P5 BPI 2015
#  ***************************  Filter traces by attributes
# Fecha:
# 2021-10-18 15:03:47.889443
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-18 16:03:47.889443
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-18 17:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-18 18:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-18 19:03:47.889443
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-18 20:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A8 P5 BPI 2015
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-10-18 21:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-18 22:03:47.889443
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-10-18 23:03:47.889443
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-10-19 00:03:47.889443
#  ***************************  Group traces by cycle time
# Fecha:
# 2021-10-19 01:03:47.889443
#  ***************************  Group traces by organizational units
# Fecha:
# 2021-10-19 02:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-19 03:03:47.889443
#  ***************************  Analyze cycle time depending on the events
# Fecha:
# 2021-10-19 04:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-19 05:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-19 06:03:47.889443
#  ***************************  Filter activities by frequency
# Fecha:
# 2021-10-19 07:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-19 08:03:47.889443
#  ***************************  Calculate frequency of activities
# Fecha:
# 2021-10-19 09:03:47.889443
#  ***************************  Calculate cycle time of only a subset of pairs of events for each subset of traces
# Fecha:
# 2021-10-19 10:03:47.889443
#  ***************************  Identify organizational units as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-19 11:03:47.889443
#  ***************************  Identify resource associated with bottlenecks
# Fecha:
# 2021-10-19 12:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A9 P5 BPI 2015
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-19 13:03:47.889443
#  ***************************  Calculate cycle time for all pairs of events for a subset of traces
# Fecha:
# 2021-10-19 14:03:47.889443
#  ***************************  Grouping traces by cycle time
#  ***************************  Apply decision trees
# Fecha:
# 2021-10-19 15:03:47.889443
#  ***************************  Group organizational units
# Fecha:
# 2021-10-19 16:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-19 17:03:47.889443
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-10-19 18:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-19 19:03:47.889443
#  ***************************  Identify organizational units as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-19 20:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A1 P1 BPI 2020
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-19 21:03:47.889443
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-19 22:03:47.889443
#  ***************************  Calculate throughput
# Fecha:
# 2021-10-19 23:03:47.889443
#  ***************************  Filter traces by attributes
# Fecha:
# 2021-10-20 00:03:47.889443
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-20 01:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A2 P1 BPI 2020
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-20 02:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A7 P1 BPI 2020
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-20 03:03:47.889443
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-20 04:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-20 05:03:47.889443
#  ***************************  Calculate throughput
# Fecha:
# 2021-10-20 06:03:47.889443
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-10-20 07:03:47.889443
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-10-20 08:03:47.889443
#  ***************************  Calculate throughput
# Fecha:
# 2021-10-20 09:03:47.889443
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-10-20 10:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A10 P1 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-10-20 11:03:47.889443
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-20 12:03:47.889443
#  ***************************  Represent boxplots of cycle time
# Fecha:
# 2021-10-20 13:03:47.889443
#  ***************************  Represent density of cycle time
# Fecha:
# 2021-10-20 14:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A12 P1 BPI 2020
#  ***************************  Calculate processing time
# Fecha:
# 2021-10-20 15:03:47.889443
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-20 16:03:47.889443
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-20 17:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A13 P1 BPI 2020
#  ***************************  Represent bar charts of traces
# Fecha:
# 2021-10-20 18:03:47.889443
#  ***************************  Calculate throughput
# Fecha:
# 2021-10-20 19:03:47.889443
#  ***************************  Represent bar charts of traces
# Fecha:
# 2021-10-20 20:03:47.889443
#  ***************************  Group traces by year
# Fecha:
# 2021-10-20 21:03:47.889443
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-20 22:03:47.889443
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-10-20 23:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-21 00:03:47.889443
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-21 01:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A18 P1 BPI 2020
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-21 02:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-21 03:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-10-21 04:03:47.889443
#  ***************************  Represent boxplots of cycle time
# Fecha:
# 2021-10-21 05:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A25 P1 BPI 2020
#  ***************************  Filter traces by attributes
# Fecha:
# 2021-10-21 06:03:47.889443
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-21 07:03:47.889443
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-21 08:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-21 09:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-10-21 10:03:47.889443
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-21 11:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A26 P1 BPI 2020
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-21 12:03:47.889443
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-21 13:03:47.889443
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-21 14:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A28 P1 BPI 2020
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-21 15:03:47.889443
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-10-21 16:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-21 17:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A35 P1 BPI 2020
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-21 18:03:47.889443
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-21 19:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-10-21 20:03:47.889443
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-21 21:03:47.889443
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-21 22:03:47.889443
#  ***************************  Group traces by year
# Fecha:
# 2021-10-21 23:03:47.889443
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-22 00:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A37 P1 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-10-22 01:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-10-22 02:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-22 03:03:47.889443
#  ***************************  Calculate number of events
# Fecha:
# 2021-10-22 04:03:47.889443
#  ***************************  Calculate number of variants
# Fecha:
# 2021-10-22 05:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A1 P1 BPI 2017
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-22 06:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-10-22 07:03:47.889443
#  ***************************  Filter events by attributes
# Fecha:
# 2021-10-22 08:03:47.889443
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# Fecha:
# 2021-10-22 09:03:47.889443
#  ***************************  Calculate frequency of events
# Fecha:
# 2021-10-22 10:03:47.889443
#  ***************************  Filter events by activities
# Fecha:
# 2021-10-22 11:03:47.889443
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# Fecha:
# 2021-10-22 12:03:47.889443
#  ***************************  Calculate frequency of events
# Fecha:
# 2021-10-22 13:03:47.889443
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-22 14:03:47.889443
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-22 15:03:47.889443
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-22 16:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-10-22 17:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A2 P1 BPI 2017
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-22 18:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-22 19:03:47.889443
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-22 20:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-22 21:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A5 P1 BPI 2017
#  ***************************  Filter events by activities
# Fecha:
# 2021-10-22 22:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-10-22 23:03:47.889443
#  ***************************  Calculate processing time
# Fecha:
# 2021-10-23 00:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-23 01:03:47.889443
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-23 02:03:47.889443
#  ***************************  Filter events by activities
# Fecha:
# 2021-10-23 03:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-10-23 04:03:47.889443
#  ***************************  Calculate processing time
# Fecha:
# 2021-10-23 05:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-23 06:03:47.889443
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-23 07:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A6 P1 BPI 2017
#  ***************************  Discover process maps
# Fecha:
# 2021-10-23 08:03:47.889443
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-23 09:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-23 10:03:47.889443
#  ***************************  Calculate frequency of events
# Fecha:
# 2021-10-23 11:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-23 12:03:47.889443
#  ***************************  Calculate frequency of activities
# Fecha:
# 2021-10-23 13:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-23 14:03:47.889443
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# Fecha:
# 2021-10-23 15:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-23 16:03:47.889443
#  ***************************  Calculate processing time
# Fecha:
# 2021-10-23 17:03:47.889443
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-23 18:03:47.889443
#  ***************************  Grouping traces by cycle time
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-23 19:03:47.889443
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-23 20:03:47.889443
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-23 21:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A7 P1 BPI 2017
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-23 22:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-23 23:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-24 00:03:47.889443
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2021-10-24 01:03:47.889443
#  ***************************  Group traces by waiting
# Fecha:
# 2021-10-24 02:03:47.889443
#  ***************************  Calculate percentage of events
# Fecha:
# 2021-10-24 03:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 04:03:47.889443
#  ***************************  Identify resources by activities
# Fecha:
# 2021-10-24 05:03:47.889443
#  ***************************  Calculate frequency of resources
# Fecha:
# 2021-10-24 06:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 07:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A8 P1 BPI 2017
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-24 08:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 09:03:47.889443
#  ***************************  Represent bar charts of waiting time
# Fecha:
# 2021-10-24 10:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 11:03:47.889443
#  ***************************  Represent bar charts of waiting time
# Fecha:
# 2021-10-24 12:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 13:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-24 14:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A9 P1 BPI 2017
#  ***************************  Calculate processing time
# Fecha:
# 2021-10-24 15:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 16:03:47.889443
#  ***************************  Compare waiting time with processing time
# Fecha:
# 2021-10-24 17:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 18:03:47.889443
#  ***************************  Group activities by role
# Fecha:
# 2021-10-24 19:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 20:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-24 21:03:47.889443
#  ***************************  Represent histograms of waiting time
# Fecha:
# 2021-10-24 22:03:47.889443
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2021-10-24 23:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A10 P1 BPI 2017
#  ***************************  Filter traces by attributes
# Fecha:
# 2021-10-25 00:03:47.889443
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-25 01:03:47.889443
#  ***************************  Calculate cycle time for all pairs of events for a subset of traces
# Fecha:
# 2021-10-25 02:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-25 03:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-25 04:03:47.889443
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2021-10-25 05:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A11 P1 BPI 2017
#  ***************************  Group traces by activities
# Fecha:
# 2021-10-25 06:03:47.889443
#  ***************************  Calculate number of events
# Fecha:
# 2021-10-25 07:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-25 08:03:47.889443
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-25 09:03:47.889443
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-10-25 10:03:47.889443
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-25 11:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-25 12:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-25 13:03:47.889443
#  ***************************  Filter traces by cycle time
# Fecha:
# 2021-10-25 14:03:47.889443
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-25 15:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-25 16:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A13 P1 BPI 2017
#  ***************************  Represent process map with frequency
# Fecha:
# 2021-10-25 17:03:47.889443
#  ***************************  Represent histograms of waiting time
# Fecha:
# 2021-10-25 18:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-25 19:03:47.889443
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-25 20:03:47.889443
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-25 21:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-25 22:03:47.889443
#  ***************************  Represent process map with frequency
# Fecha:
# 2021-10-25 23:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A14 P1 BPI 2017
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-10-26 00:03:47.889443
#  ***************************  Group traces by activities
# Fecha:
# 2021-10-26 01:03:47.889443
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-26 02:03:47.889443
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-26 03:03:47.889443
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-10-26 04:03:47.889443
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-26 05:03:47.889443
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-10-26 06:03:47.889443
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-26 07:03:47.889443
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-10-26 08:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A15 P1 BPI 2017
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-26 09:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-26 10:03:47.889443
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2021-10-26 11:03:47.889443
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-26 12:03:47.889443
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-26 13:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A16 P1 BPI 2017
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-26 14:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-26 15:03:47.889443
#  ***************************  Group traces by activities
# Fecha:
# 2021-10-26 16:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-26 17:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-26 18:03:47.889443
#  ***************************  Group traces by activities
# Fecha:
# 2021-10-26 19:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-26 20:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# Fecha:
# 2021-10-26 21:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A17 P1 BPI 2017
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-26 22:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# Fecha:
# 2021-10-26 23:03:47.889443
#  ***************************  Filter traces by attributes
# Fecha:
# 2021-10-27 00:03:47.889443
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-27 01:03:47.889443
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-27 02:03:47.889443
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-27 03:03:47.889443
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2021-10-27 04:03:47.889443
#  ***************************  Calculate processing time
# Fecha:
# 2021-10-27 05:03:47.889443
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-27 06:03:47.889443
#  ***************************  Compare waiting time with processing time
# Fecha:
# 2021-10-27 07:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A21 P1 BPI 2017
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-27 08:03:47.889443
#  ***************************  Calculate processing time
# Fecha:
# 2021-10-27 09:03:47.889443
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-27 10:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-27 11:03:47.889443
# ...
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-11-14 15:03:47.889443
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-11-14 16:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-11-14 17:03:47.889443
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-11-14 18:03:47.889443
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-11-14 19:03:47.889443
#  ***************************  Identify attributes by traces
# Fecha:
# 2021-11-14 20:03:47.889443
#  ***************************  Filter traces by cycle time
# Fecha:
# 2021-11-14 21:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-11-14 22:03:47.889443
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-11-14 23:03:47.889443
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-11-15 00:03:47.889443
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-11-15 01:03:47.889443
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-11-15 02:03:47.889443
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-11-15 03:03:47.889443
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-11-15 04:03:47.889443
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-11-15 05:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-11-15 06:03:47.889443
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-11-15 07:03:47.889443
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# Fecha:
# 2021-11-15 08:03:47.889443
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-11-15 09:03:47.889443
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-11-15 10:03:47.889443
#  ***************************  Group events by attributes
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-11-15 11:03:47.889443
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-11-15 12:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-11-15 13:03:47.889443
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-11-15 14:03:47.889443
#  ***************************  Identify attributes by cycle time
# Fecha:
# 2021-11-15 15:03:47.889443
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-11-15 16:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A30 P1 BPI 2020
#  ***************************  Filter traces by activities
# Fecha:
# 2021-11-15 17:03:47.889443
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-11-15 18:03:47.889443
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-11-15 19:03:47.889443
#  ***************************  Filter traces by activities
# Fecha:
# 2021-11-15 20:03:47.889443
#  ***************************  Represent temporal series of traces
# Fecha:
# 2021-11-15 21:03:47.889443
#  ***************************  Represent temporal series of traces
# Fecha:
# 2021-11-15 22:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A31 P1 BPI 2020
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-11-15 23:03:47.889443
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-11-16 00:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-11-16 01:03:47.889443
#  ***************************  Calculate throughput
# Fecha:
# 2021-11-16 02:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A34 P1 BPI 2020
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-11-16 03:03:47.889443
#  ***************************  Filter traces by subprocesses
# Fecha:
# 2021-11-16 04:03:47.889443
#  ***************************  Group traces by sub-processes
# Fecha:
# 2021-11-16 05:03:47.889443
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-11-16 06:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A27 P2 BPI 2020
#  ***************************  Calculate frequency of activities
# Fecha:
# 2021-11-16 07:03:47.889443
#  ***************************  Represent bart charts of activities
# Fecha:
# 2021-11-16 08:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A30 P2 BPI 2020
#  ***************************  Group traces by month
# Fecha:
# 2021-11-16 09:03:47.889443
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-11-16 10:03:47.889443
#  ***************************  Identify values of attributes
# Fecha:
# 2021-11-16 11:03:47.889443
#  ***************************  Group traces by month
# Fecha:
# 2021-11-16 12:03:47.889443
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-11-16 13:03:47.889443
#  ***************************  Identify values of attributes
# Fecha:
# 2021-11-16 14:03:47.889443
#  ***************************  Identify values of attributes
# Fecha:
# 2021-11-16 15:03:47.889443
#  ***************************  Identify values of attributes
# Fecha:
# 2021-11-16 16:03:47.889443
#  ***************************  Calculate number of events
# Fecha:
# 2021-11-16 17:03:47.889443
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-11-16 18:03:47.889443
#  ***************************  Identify values of attributes
# Fecha:
# 2021-11-16 19:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A31 P2 BPI 2020
#  ***************************  Compare cycle time
# Fecha:
# 2021-11-16 20:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A19 P4 BPI 2020
#  ***************************  Filter traces by frequency
# Fecha:
# 2021-11-16 21:03:47.889443
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-16 22:03:47.889443
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-16 23:03:47.889443
#  ***************************  Identify activities with cycle time
# Fecha:
# 2021-11-17 00:03:47.889443
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-11-17 01:03:47.889443
#  ***************************  Identify transitions by cycle time
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-17 02:03:47.889443
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-17 03:03:47.889443
#  ***************************  Filter traces by frequency
# Fecha:
# 2021-11-17 04:03:47.889443
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-17 05:03:47.889443
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-17 06:03:47.889443
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-17 07:03:47.889443
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-17 08:03:47.889443
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-11-17 09:03:47.889443
#  ***************************  Identify roles by organizational units
# Fecha:
# 2021-11-17 10:03:47.889443
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-11-17 11:03:47.889443
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-17 12:03:47.889443
#  ***************************  Identify activities with traces
# Fecha:
# 2021-11-17 13:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A27 P4 BPI 2020
#  ***************************  Group activities by role
# Fecha:
# 2021-11-17 14:03:47.889443
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-11-17 15:03:47.889443
#  ***************************  Calculate number of events
# Fecha:
# 2021-11-17 16:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A31 P4 BPI 2020
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-11-17 17:03:47.889443
#  ***************************  Identify activities with cycle time
# Fecha:
# 2021-11-17 18:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A19 P5 BPI 2020
#  ***************************  Filter traces by frequency
# Fecha:
# 2021-11-17 19:03:47.889443
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-17 20:03:47.889443
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-17 21:03:47.889443
#  ***************************  Identify activities with cycle time
# Fecha:
# 2021-11-17 22:03:47.889443
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-11-17 23:03:47.889443
#  ***************************  Identify transitions by cycle time
# Fecha:
# 2021-11-18 00:03:47.889443
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-18 01:03:47.889443
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-18 02:03:47.889443
#  ***************************  Filter traces by frequency
# Fecha:
# 2021-11-18 03:03:47.889443
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-18 04:03:47.889443
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-18 05:03:47.889443
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-18 06:03:47.889443
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-18 07:03:47.889443
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-11-18 08:03:47.889443
#  ***************************  Identify roles by organizational units
# Fecha:
# 2021-11-18 09:03:47.889443
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-11-18 10:03:47.889443
#  ***************************  Identify transitions by cycle time
# Fecha:
# 2021-11-18 11:03:47.889443
#  ***************************  Identify activities with traces
# Fecha:
# 2021-11-18 12:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A30 P5 BPI 2020
#  ***************************  Filter activities by frequency
# Fecha:
# 2021-11-18 13:03:47.889443
#  ***************************  Calculate cycle time for all pairs of events for a subset of traces
# Fecha:
# 2021-11-18 14:03:47.889443
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-11-18 15:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-11-18 16:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-11-18 17:03:47.889443
#  ***************************  Represent bar charts of traces
# Fecha:
# 2021-11-18 18:03:47.889443
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-11-18 19:03:47.889443
#  ***************************  Filter traces by activities
# Fecha:
# 2021-11-18 20:03:47.889443
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-11-18 21:03:47.889443
#  ***************************  Filter traces by activities
# Fecha:
# 2021-11-18 22:03:47.889443
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-11-18 23:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A34 P5 BPI 2020
#  ***************************  Calculate frequency of activities
# Fecha:
# 2021-11-19 00:03:47.889443
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-11-19 01:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria and statistical measures
# Fecha:
# 2021-11-19 02:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A30 P6 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-11-19 03:03:47.889443
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-11-19 04:03:47.889443
#  ***************************  Identify transitions by cycle time
# Fecha:
# 2021-11-19 05:03:47.889443
# -----------------------------------------------------------------------
# Case:id
# A19 P1 BPI 2020
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-11-19 06:03:47.889443
#  ***************************  Group traces by year
# Fecha:
# 2021-11-19 07:03:47.889443
#  ***************************  Calculate number of traces
# Fecha:
# 2021-11-19 08:03:47.889443
#  ***************************  Represent temporal series of traces
# Fecha:
# 2021-11-19 09:03:47.889443
#  ***************************  Filter events by activities
# Fecha:
# 2021-11-19 10:03:47.889443
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-19 11:03:47.889443
#  ***************************  Group traces by year
# Fecha:
# 2021-11-19 12:03:47.889443
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-19 13:03:47.889443
#  ***************************  Calculate Statistics of activities
# Fecha:
# 2021-11-19 14:03:47.889443
#  ***************************  Calculate throughput
# Fecha:
# 2021-11-19 15:03:47.889443
#  ***************************  Represent temporal series of throughput
# Fecha:
# 2021-11-19 16:03:47.889443
#              case:id case:concept:name               concept:name  \
# 0     A1 P2 BPI 2020    A1 P2 BPI 2020       Calculate cycle time
# 1     A1 P2 BPI 2020    A1 P2 BPI 2020         Compare cycle time
# 2     A2 P2 BPI 2020    A2 P2 BPI 2020       Calculate cycle time
# 3     A2 P2 BPI 2020    A2 P2 BPI 2020         Compare cycle time
# 4     A7 P2 BPI 2020    A7 P2 BPI 2020       Calculate throughput
# ..               ...               ...                        ...
# 932  A19 P1 BPI 2020   A19 P1 BPI 2020               Group traces
# 933  A19 P1 BPI 2020   A19 P1 BPI 2020               Group traces
# 934  A19 P1 BPI 2020   A19 P1 BPI 2020       Calculate statistics
# 935  A19 P1 BPI 2020   A19 P1 BPI 2020       Calculate throughput
# 936  A19 P1 BPI 2020   A19 P1 BPI 2020  Represent temporal series
#
#                                     Specific operation  \
# 0    Calculate cycle time of the whole process for ...
# 1
# 2            Get cycle time from the previous question
# 3
# 4
# ..                                                 ...
# 932                               Group traces by year
# 933                         Group traces by activities
# 934                 Calculate Statistics of activities
# 935
# 936            Represent temporal series of throughput
#
#                  time:timestamp Question  Year
# 0    2021-10-11 16:03:47.889443       P2  2020
# 1    2021-10-11 17:03:47.889443       P2  2020
# 2    2021-10-11 18:03:47.889443       P2  2020
# 3    2021-10-11 19:03:47.889443       P2  2020
# 4    2021-10-11 20:03:47.889443       P2  2020
# ..                          ...      ...   ...
# 932  2021-11-19 12:03:47.889443       P1  2020
# 933  2021-11-19 13:03:47.889443       P1  2020
# 934  2021-11-19 14:03:47.889443       P1  2020
# 935  2021-11-19 15:03:47.889443       P1  2020
# 936  2021-11-19 16:03:47.889443       P1  2020
#
# [937 rows x 7 columns]

# %%
df_prueba
# Out:
#              case:id case:concept:name               concept:name  \
# 0     A1 P2 BPI 2020    A1 P2 BPI 2020       Calculate cycle time
# 1     A1 P2 BPI 2020    A1 P2 BPI 2020         Compare cycle time
# 2     A2 P2 BPI 2020    A2 P2 BPI 2020       Calculate cycle time
# 3     A2 P2 BPI 2020    A2 P2 BPI 2020         Compare cycle time
# 4     A7 P2 BPI 2020    A7 P2 BPI 2020       Calculate throughput
# ..               ...               ...                        ...
# 930  A19 P1 BPI 2020   A19 P1 BPI 2020               Group traces
# 931  A19 P1 BPI 2020   A19 P1 BPI 2020               Group traces
# 932  A19 P1 BPI 2020   A19 P1 BPI 2020       Calculate statistics
# 933  A19 P1 BPI 2020   A19 P1 BPI 2020       Calculate throughput
# 934  A19 P1 BPI 2020   A19 P1 BPI 2020  Represent temporal series
#
#                                     Specific operation  \
# 0    Calculate cycle time of the whole process for ...
# 1
# 2            Get cycle time from the previous question
# 3
# 4
# ..                                                 ...
# 930                               Group traces by year
# 931                         Group traces by activities
# 932                 Calculate Statistics of activities
# 933
# 934            Represent temporal series of throughput
#
#                  time:timestamp Question  Year
# 0    2021-10-11 15:21:39.334273       P2  2020
# 1    2021-10-11 16:21:39.334273       P2  2020
# 2    2021-10-11 17:21:39.334273       P2  2020
# 3    2021-10-11 18:21:39.334273       P2  2020
# 4    2021-10-11 19:21:39.334273       P2  2020
# ..                          ...      ...   ...
# 930  2021-11-19 09:21:39.334273       P1  2020
# 931  2021-11-19 10:21:39.334273       P1  2020
# 932  2021-11-19 11:21:39.334273       P1  2020
# 933  2021-11-19 12:21:39.334273       P1  2020
# 934  2021-11-19 13:21:39.334273       P1  2020
#
# [935 rows x 7 columns]

# %%
type(df_prueba.iloc[2]['time:timestamp'])
# Out:
# str

# %%
for i in range(len(df_prueba)):   
    df_prueba.iloc[i]['time:timestamp'] = datetime.datetime.strptime(df_prueba.iloc[i]['time:timestamp'], '%Y-%m-%d %H:%M:%S.%f')

# %%
type(df_prueba.iloc[2]['time:timestamp'])
# Out:
# datetime.datetime

# %%
log = log_converter.apply(df_prueba)
xes_exporter.apply(log, './Log of analysis of time spects.xes')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='exporting log, completed traces :: ', max=90.0, style=Pro…
