# %%
import pandas as pd
import datetime
from os import listdir
import os, os.path
from os.path import isfile, join
import numpy as np
import csv
import re
import pandas as pd
from pm4py.objects.conversion.log import converter as log_converter
from pm4py.objects.log.importer.xes import importer as xes_importer
from pm4py.objects.log.exporter.xes import exporter as xes_exporter
from pm4py.objects.log.util import dataframe_utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d267f8a7b9fa> in <module>
#       8 import re
#       9 import pandas as pd
# ---> 10 from pm4py.objects.conversion.log import converter as log_converter
#      11 from pm4py.objects.log.importer.xes import importer as xes_importer
#      12 from pm4py.objects.log.exporter.xes import exporter as xes_exporter
#
# ModuleNotFoundError: No module named 'pm4py'

# %%
datos_raw = pd.read_excel("./grouped table of annotations.xlsx")
datos_raw=datos_raw.drop(['Unnamed: 0'], axis='columns')
glosario = pd.read_excel("./OperationCoding (solo cycle time).xlsx")
glosario['General operations'] = glosario['General operations'].fillna(method='pad')
glosario['Specific operations'] =  glosario['Specific operations'].str.split().str.join(' ')
glosario['General operations'] =  glosario['General operations'].str.split().str.join(' ')

columns=['case:concept:name','General operation','Specific operation','Time','Question','Year']
#columna es el case_ID
cont = 0
df_prueba= pd.DataFrame(columns=columns)
for columna in datos_raw.columns:
    acciones_analisis=datos_raw[columna].dropna()
    for accion in acciones_analisis:
        
        accion = re.sub('[\xa0]', ' ', accion)
        print(' *************************** ', accion)
        string_dividido=accion.split(' ')
        accion = ' '.join(string_dividido)
        for fila in range(len(glosario)):
                       
            if(accion == glosario['Specific operations'][fila]):
                #print('si', accion)
                accionGeneral=glosario['General operations'][fila]
                accionEspecifica=accion
                columnaSeparada=columna.split()
                pregunta=columnaSeparada[1]
                año=columnaSeparada[3]
                ct=datetime.datetime.now() + datetime.timedelta(minutes=1)
                new_row={'case:concept:name':columna, 'General operation':accionGeneral,'Specific operation':accionEspecifica,'Time':str(ct),'Question':pregunta,'Year':año} 
                print(cont, new_row['case:concept:name'])
                cont = cont +1
                df_prueba = df_prueba.append(new_row, ignore_index=True)
                
            elif(accion == glosario['General operations'][fila]):
                #print('no', accion)
                accionGeneral=accion
                accionEspecifica=" "
                columnaSeparada=columna.split()
                pregunta=columnaSeparada[1]
                año=columnaSeparada[3]
                ct=datetime.datetime.now() + datetime.timedelta(minutes=1)
                new_row={'case:concept:name':columna, 'General operation':accionGeneral,'Specific operation':accionEspecifica,'Time':str(ct),'Question':pregunta,'Year':año} 
                print(cont, new_row['case:concept:name'])
                cont = cont +1
                df_prueba = df_prueba.append(new_row, ignore_index=True)
            
                
            
df_prueba
# Out:
#  ***************************  Calculate cycle time of the whole process for all traces
# 0 A1 P2 BPI 2020
#  ***************************  Compare cycle time
# 1 A1 P2 BPI 2020
#  ***************************  Get cycle time from the previous question
# 2 A2 P2 BPI 2020
#  ***************************  Compare cycle time
# 3 A2 P2 BPI 2020
#  ***************************  Calculate throughput
# 4 A7 P2 BPI 2020
#  ***************************  Comparative of throughput
# 5 A7 P2 BPI 2020
#  ***************************  Comparative of throughput
# 6 A7 P2 BPI 2020
#  ***************************  Represent scatterplot
# 7 A7 P2 BPI 2020
#  ***************************  Represent boxplots of cycle time
# 8 A10 P2 BPI 2020
#  ***************************  Compare cycle time
# 9 A10 P2 BPI 2020
#  ***************************  Calculate throughput
# 10 A12 P2 BPI 2020
#  ***************************  Preprocess the traces of the logs
# 11 A12 P2 BPI 2020
#  ***************************  Calculate throughput
# 12 A12 P2 BPI 2020
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# 13 A13 P2 BPI 2020
#  ***************************  Compare cycle time
# 14 A13 P2 BPI 2020
#  ***************************  Identify specific subprocesses
# 15 A13 P2 BPI 2020
#  ***************************  Calculate Statistics of cycle time
# 16 A18 P2 BPI 2020
#  ***************************  Get cycle time from the previous question
# 17 A25 P2 BPI 2020
#  ***************************  Compare cycle time
# 18 A25 P2 BPI 2020
#  ***************************  Calculate cycle time of the whole process for all traces
# 19 A25 P2 BPI 2020
#  ***************************  Get cycle time from the previous question
# 20 A26 P2 BPI 2020
#  ***************************  Compare cycle time
# 21 A26 P2 BPI 2020
#  ***************************  Get cycle time from the previous question
# 22 A28 P2 BPI 2020
#  ***************************  Represent histograms of cycle time
# 23 A28 P2 BPI 2020
#  ***************************  Compare cycle time
# 24 A28 P2 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# 25 A35 P2 BPI 2020
#  ***************************  Calculate number of traces
# 26 A35 P2 BPI 2020
#  ***************************  Calculate number of activities
# 27 A35 P2 BPI 2020
#  ***************************  Calculate average of activities per trace
# 28 A35 P2 BPI 2020
#  ***************************  Calculate percentage of traces
# 29 A35 P2 BPI 2020
#  ***************************  Calculate Statistics of attributes
# 30 A35 P2 BPI 2020
#  ***************************  Group traces depending on attributes
# 31 A35 P2 BPI 2020
#  ***************************  Represent histograms of attributes
# 32 A35 P2 BPI 2020
#  ***************************  Represent bar charts of traces
# 33 A35 P2 BPI 2020
#  ***************************  Represent histograms of cycle time
# 34 A35 P2 BPI 2020
#  ***************************  Filter traces by activities
# 35 A35 P2 BPI 2020
#  ***************************  Compare cycle time
# 36 A35 P2 BPI 2020
#  ***************************  Get cycle time from the previous question
# 37 A37 P2 BPI 2020
#  ***************************  Compare cycle time
# 38 A37 P2 BPI 2020
#  ***************************  Filter activities by sub-processes
# 39 A2 P4 BPI 2020
#  ***************************  Group activities by sub-processes
# 40 A2 P4 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# 41 A2 P4 BPI 2020
#  ***************************  Group activities by role
# 42 A7 P4 BPI 2020
#  ***************************  Calculate throughput
# 43 A7 P4 BPI 2020
#  ***************************  Group activities by time
# 44 A7 P4 BPI 2020
#  ***************************  Calculate number of activities
# 45 A7 P4 BPI 2020
#  ***************************  Represent scatterplot
# 46 A7 P4 BPI 2020
#  ***************************  Represent process map with cycle time
# 47 A10 P4 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# 48 A10 P4 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# 49 A12 P4 BPI 2020
#  ***************************  Represent process map with cycle time
# 50 A13 P4 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# 51 A13 P4 BPI 2020
#  ***************************  Group activities by sub-processes
# 52 A13 P4 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# 53 A13 P4 BPI 2020
#  ***************************  Represent process map with frequency
# 54 A18 P4 BPI 2020
#  ***************************  Calculate cycle time of only a subset of pairs of events for a subset of traces
# 55 A18 P4 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# 56 A25 P4 BPI 2020
#  ***************************  Represent bar charts of cycle time
# 57 A25 P4 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 58 A25 P4 BPI 2020
#  ***************************  Filter variants depending on frequency
# 59 A26 P4 BPI 2020
#  ***************************  Represent histograms of cycle time
# 60 A26 P4 BPI 2020
#  ***************************  Preprocess the traces of the logs
# 61 A28 P4 BPI 2020
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# 62 A28 P4 BPI 2020
#  ***************************  Represent heatmaps
# 63 A28 P4 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 64 A28 P4 BPI 2020
#  ***************************  Preprocess the traces of the logs
# 65 A28 P4 BPI 2020
#  ***************************  Represent heatmaps
# 66 A28 P4 BPI 2020
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# 67 A28 P4 BPI 2020
#  ***************************  Represent heatmaps
# 68 A28 P4 BPI 2020
#  ***************************  Preprocess the traces of the logs
# 69 A28 P4 BPI 2020
#  ***************************  Represent heatmaps
# 70 A28 P4 BPI 2020
#  ***************************  Filter traces by activities
# 71 A35 P4 BPI 2020
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# 72 A35 P4 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# 73 A35 P4 BPI 2020
#  ***************************  Calculate number of traces
# 74 A35 P4 BPI 2020
#  ***************************  Calculate number of activities
# 75 A35 P4 BPI 2020
#  ***************************  Calculate average of activities per trace
# 76 A35 P4 BPI 2020
#  ***************************  Group traces by roles
# 77 A35 P4 BPI 2020
#  ***************************  Represent histograms of cycle time
# 78 A35 P4 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# 79 A37 P4 BPI 2020
#  ***************************  Get cycle time from the previous question
# 80 A1 P5 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 81 A1 P5 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# 82 A2 P5 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 83 A2 P5 BPI 2020
#  ***************************  Represent process map with cycle time
# 84 A2 P5 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# 85 A7 P5 BPI 2020
#  ***************************  Filter activities by cycle time
# 86 A7 P5 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 87 A7 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# 88 A10 P5 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 89 A10 P5 BPI 2020
#  ***************************  Calculate number of activities
# 90 A10 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# 91 A12 P5 BPI 2020
#  ***************************  Represent bar charts of cycle time
# 92 A12 P5 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 93 A12 P5 BPI 2020
#  ***************************  Represent process map with cycle time
# 94 A13 P5 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# 95 A13 P5 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 96 A13 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# 97 A18 P5 BPI 2020
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# 98 A18 P5 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# 99 A25 P5 BPI 2020
#  ***************************  Represent bar charts of cycle time
# 100 A25 P5 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 101 A25 P5 BPI 2020
#  ***************************  Represent process map with cycle time
# 102 A26 P5 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 103 A26 P5 BPI 2020
#  ***************************  Identify sub-processes with incorrect orders with respect to the happy path as bottlenecks
# 104 A28 P5 BPI 2020
#  ***************************  Calculate number of activities
# 105 A28 P5 BPI 2020
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# 106 A28 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# 107 A35 P5 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 108 A35 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# 109 A37 P5 BPI 2020
#  ***************************  Compare cycle time
# 110 A37 P5 BPI 2020
#  ***************************  Identify sub-processes with incorrect orders with respect to the happy path as bottlenecks
# 111 A37 P5 BPI 2020
#  ***************************  Calculate frequency of attributes
# 112 A37 P5 BPI 2020
#  ***************************  Calculate percentage of traces
# 113 A37 P5 BPI 2020
#  ***************************  Calculate number of activities
# 114 A37 P5 BPI 2020
#  ***************************  Filter traces depending on the order of activities
# 115 A1 P6 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# 116 A1 P6 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# 117 A2 P6 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 118 A2 P6 BPI 2020
#  ***************************  Represent process map with cycle time
# 119 A2 P6 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# 120 A7 P6 BPI 2020
#  ***************************  Filter activities by cycle time
# 121 A7 P6 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 122 A7 P6 BPI 2020
#  ***************************  Filter traces by activities
# 123 A10 P6 BPI 2020
#  ***************************  Calculate number of activities
# 124 A10 P6 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# 125 A10 P6 BPI 2020
#  ***************************  Filter traces by activities
# 126 A10 P6 BPI 2020
#  ***************************  Calculate number of activities
# 127 A10 P6 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# 128 A10 P6 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# 129 A12 P6 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 130 A12 P6 BPI 2020
#  ***************************  Preprocess the traces of the logs
# 131 A13 P6 BPI 2020
#  ***************************  Represent process map with cycle time
# 132 A13 P6 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# 133 A13 P6 BPI 2020
#  ***************************  Calculate frequency of variants
# 134 A13 P6 BPI 2020
#  ***************************  Calculate intervals of time of the traces
# 135 A13 P6 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 136 A13 P6 BPI 2020
#  ***************************  Represent histograms of cycle time
# 137 A25 P6 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# 138 A25 P6 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 139 A25 P6 BPI 2020
#  ***************************  Get cycle time from the previous question
# 140 A26 P6 BPI 2020
#  ***************************  Get process map from the previous question
# 141 A26 P6 BPI 2020
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 142 A26 P6 BPI 2020
#  ***************************  Identify sub-processes with incorrect orders with respect to the happy path as bottlenecks
# 143 A28 P6 BPI 2020
#  ***************************  Represent process map with cycle time
# 144 A35 P6 BPI 2020
#  ***************************  Identify sub-processes with incorrect orders with respect to the happy path as bottlenecks
# 145 A35 P6 BPI 2020
#  ***************************  Filter traces by activities
# 146 A37 P6 BPI 2020
#  ***************************  Preprocess the traces of the logs
# 147 A37 P6 BPI 2020
#  ***************************  Calculate number of variants
# 148 A37 P6 BPI 2020
#  ***************************  Calculate number of different organizational units
# 149 A37 P6 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# 150 A37 P6 BPI 2020
#  ***************************  Compare cycle time
# 151 A37 P6 BPI 2020
#  ***************************  Calculate cycle time of the whole process for all traces
# 152 A2 P5 BPI 2015
#  ***************************  Filter events by cycle time
# 153 A2 P5 BPI 2015
#  ***************************  Represent histograms of cycle time
# 154 A2 P5 BPI 2015
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 155 A2 P5 BPI 2015
#  ***************************  Group activities by sub-processes
# 156 A3 P5 BPI 2015
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# 157 A3 P5 BPI 2015
#  ***************************  Represent process map with cycle time
# 158 A3 P5 BPI 2015
#  ***************************  Filter activities by frequency
# 159 A3 P5 BPI 2015
#  ***************************  Represent bar charts of traces
# 160 A3 P5 BPI 2015
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 161 A3 P5 BPI 2015
#  ***************************  Represent process map with cycle time
# 162 A3 P5 BPI 2015
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# 163 A4 P5 BPI 2015
#  ***************************  Identify organizational units as bottlenecks applying temporal performance criteria
# 164 A4 P5 BPI 2015
#  ***************************  Identify impact of bottlenecks by organizational unit
# 165 A4 P5 BPI 2015
#  ***************************  Compare cycle time
# 166 A4 P5 BPI 2015
#  ***************************  Filter traces by attributes
# 167 A7 P5 BPI 2015
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# 168 A7 P5 BPI 2015
#  ***************************  Represent histograms of cycle time
# 169 A7 P5 BPI 2015
#  ***************************  Compare cycle time
# 170 A7 P5 BPI 2015
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 171 A7 P5 BPI 2015
#  ***************************  Represent process map with cycle time
# 172 A7 P5 BPI 2015
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# 173 A8 P5 BPI 2015
#  ***************************  Compare cycle time
# 174 A8 P5 BPI 2015
#  ***************************  Group traces depending on attributes
# 175 A8 P5 BPI 2015
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# 176 A8 P5 BPI 2015
#  ***************************  Grouping traces by cycle time
# 177 A8 P5 BPI 2015
#  ***************************  Grouping by organizational units
# 178 A8 P5 BPI 2015
#  ***************************  Compare cycle time
# 179 A8 P5 BPI 2015
#  ***************************  Analyze cycle time depending on the events
# 180 A8 P5 BPI 2015
#  ***************************  Calculate number of traces
# 181 A8 P5 BPI 2015
#  ***************************  Compare cycle time
# 182 A8 P5 BPI 2015
#  ***************************  Filter activities by frequency
# 183 A8 P5 BPI 2015
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 184 A8 P5 BPI 2015
#  ***************************  Calculate frequency of activities
# 185 A8 P5 BPI 2015
#  ***************************  Calculate cycle time of only a subset of pairs of events for each subset of traces
# 186 A8 P5 BPI 2015
#  ***************************  Identify organizational units as bottlenecks applying temporal performance criteria
# 187 A8 P5 BPI 2015
#  ***************************  Identify resource associated with bottlenecks
# 188 A8 P5 BPI 2015
#  ***************************  Filter traces by activities
# 189 A9 P5 BPI 2015
#  ***************************  Calculate cycle time for all pairs of events for a subset of traces
# 190 A9 P5 BPI 2015
#  ***************************  Grouping traces by cycle time
# 191 A9 P5 BPI 2015
#  ***************************  Aplicar árboles de decisión
#  ***************************  Group organizational units
# 192 A9 P5 BPI 2015
#  ***************************  Calculate number of traces
# 193 A9 P5 BPI 2015
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# 194 A9 P5 BPI 2015
#  ***************************  Compare cycle time
# 195 A9 P5 BPI 2015
#  ***************************  Identify organizational units as bottlenecks applying temporal performance criteria
# 196 A9 P5 BPI 2015
#  ***************************  Filter traces by activities
# 197 A1 P1 BPI 2020
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# 198 A1 P1 BPI 2020
#  ***************************  Calculate throughput
# 199 A1 P1 BPI 2020
#  ***************************  Filter traces by attributes
# 200 A1 P1 BPI 2020
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# 201 A1 P1 BPI 2020
#  ***************************  Calculate cycle time of the whole process for all traces
# 202 A2 P1 BPI 2020
#  ***************************  Filter traces by activities
# 203 A7 P1 BPI 2020
#  ***************************  Calculate percentage of traces
# 204 A7 P1 BPI 2020
#  ***************************  Calculate number of traces
# 205 A7 P1 BPI 2020
#  ***************************  Calculate throughput
# 206 A7 P1 BPI 2020
#  ***************************  Calculate Statistics of throughput
# 207 A7 P1 BPI 2020
#  ***************************  Calculate Statistics of throughput
# 208 A7 P1 BPI 2020
#  ***************************  Calculate throughput
# 209 A7 P1 BPI 2020
#  ***************************  Calculate Statistics of throughput
# 210 A7 P1 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# 211 A10 P1 BPI 2020
#  ***************************  Represent histograms of cycle time
# 212 A10 P1 BPI 2020
#  ***************************  Represent boxplots of cycle time
# 213 A10 P1 BPI 2020
#  ***************************  Represent density of cycle time
# 214 A10 P1 BPI 2020
#  ***************************  Calculate processing time
# 215 A12 P1 BPI 2020
#  ***************************  Filter traces by activities
# 216 A12 P1 BPI 2020
#  ***************************  Represent process map with cycle time
# 217 A12 P1 BPI 2020
#  ***************************  Represent bar charts of traces
# 218 A13 P1 BPI 2020
#  ***************************  Calculate throughput
# 219 A13 P1 BPI 2020
#  ***************************  Represent bar charts of traces
# 220 A13 P1 BPI 2020
#  ***************************  Group traces by year
# 221 A13 P1 BPI 2020
#  ***************************  Filter traces by activities
# 222 A13 P1 BPI 2020
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# 223 A13 P1 BPI 2020
#  ***************************  Calculate number of traces
# 224 A13 P1 BPI 2020
#  ***************************  Calculate percentage of traces
# 225 A13 P1 BPI 2020
#  ***************************  Filter traces by activities
# 226 A18 P1 BPI 2020
#  ***************************  Calculate number of traces
# 227 A18 P1 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# 228 A18 P1 BPI 2020
#  ***************************  Represent boxplots of cycle time
# 229 A18 P1 BPI 2020
#  ***************************  Filter traces by attributes
# 230 A25 P1 BPI 2020
#  ***************************  Calculate cycle time of the whole process for all traces
# 231 A25 P1 BPI 2020
#  ***************************  Represent histograms of cycle time
# 232 A25 P1 BPI 2020
#  ***************************  Compare cycle time
# 233 A25 P1 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# 234 A25 P1 BPI 2020
#  ***************************  Represent histograms of cycle time
# 235 A25 P1 BPI 2020
#  ***************************  Represent process map with cycle time
# 236 A26 P1 BPI 2020
#  ***************************  Filter traces by activities
# 237 A26 P1 BPI 2020
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# 238 A26 P1 BPI 2020
#  ***************************  Calculate cycle time of the whole process for all traces
# 239 A28 P1 BPI 2020
#  ***************************  Represent bar charts of cycle time
# 240 A28 P1 BPI 2020
#  ***************************  Compare cycle time
# 241 A28 P1 BPI 2020
#  ***************************  Filter traces by activities
# 242 A35 P1 BPI 2020
#  ***************************  Calculate percentage of traces
# 243 A35 P1 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# 244 A35 P1 BPI 2020
#  ***************************  Represent histograms of cycle time
# 245 A35 P1 BPI 2020
#  ***************************  Compare cycle time
# 246 A35 P1 BPI 2020
#  ***************************  Group traces by year
# 247 A35 P1 BPI 2020
#  ***************************  Calculate percentage of traces
# 248 A35 P1 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# 249 A37 P1 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# 250 A37 P1 BPI 2020
#  ***************************  Calculate number of traces
# 251 A37 P1 BPI 2020
#  ***************************  Calculate number of events
# 252 A37 P1 BPI 2020
#  ***************************  Calculate number of variants
# 253 A37 P1 BPI 2020
#  ***************************  Calculate cycle time of the whole process for all traces
# 254 A1 P1 BPI 2017
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# 255 A1 P1 BPI 2017
#  ***************************  Filter events by attributes
# 256 A1 P1 BPI 2017
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# 257 A1 P1 BPI 2017
#  ***************************  Calculate frequency of events
# 258 A1 P1 BPI 2017
#  ***************************  Filter events by activities
# 259 A1 P1 BPI 2017
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# 260 A1 P1 BPI 2017
#  ***************************  Calculate frequency of events
# 261 A1 P1 BPI 2017
#  ***************************  Represent histograms of cycle time
# 262 A1 P1 BPI 2017
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# 263 A1 P1 BPI 2017
#  ***************************  Calculate percentage of traces
# 264 A1 P1 BPI 2017
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# 265 A1 P1 BPI 2017
#  ***************************  Filter traces by activities
# 266 A2 P1 BPI 2017
#  ***************************  Calculate waiting time
# 267 A2 P1 BPI 2017
#  ***************************  Filter traces by activities
# 268 A2 P1 BPI 2017
#  ***************************  Calculate waiting time
# 269 A2 P1 BPI 2017
#  ***************************  Filter events by activities
# 270 A5 P1 BPI 2017
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# 271 A5 P1 BPI 2017
#  ***************************  Calculate processing time
# 272 A5 P1 BPI 2017
#  ***************************  Calculate waiting time
# 273 A5 P1 BPI 2017
#  ***************************  Represent process map with cycle time
# 274 A5 P1 BPI 2017
#  ***************************  Filter events by activities
# 275 A5 P1 BPI 2017
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# 276 A5 P1 BPI 2017
#  ***************************  Calculate processing time
# 277 A5 P1 BPI 2017
#  ***************************  Calculate waiting time
# 278 A5 P1 BPI 2017
#  ***************************  Represent process map with cycle time
# 279 A5 P1 BPI 2017
#  ***************************  Discover process maps
# 280 A6 P1 BPI 2017
#  ***************************  Represent process map with cycle time
# 281 A6 P1 BPI 2017
#  ***************************  Calculate waiting time
# 282 A6 P1 BPI 2017
#  ***************************  Calculate frequency of events
# 283 A6 P1 BPI 2017
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 284 A6 P1 BPI 2017
#  ***************************  Calculate frequency of activities
# 285 A6 P1 BPI 2017
#  ***************************  Calculate number of traces
# 286 A6 P1 BPI 2017
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# 287 A6 P1 BPI 2017
#  ***************************  Calculate waiting time
# 288 A6 P1 BPI 2017
#  ***************************  Calculate processing time
# 289 A6 P1 BPI 2017
#  ***************************  Represent histograms of cycle time
# 290 A6 P1 BPI 2017
#  ***************************  Grouping traces by cycle time
# 291 A6 P1 BPI 2017
#  ***************************  Calculate number of traces
# 292 A6 P1 BPI 2017
#  ***************************  Calculate percentage of traces
# 293 A6 P1 BPI 2017
#  ***************************  Filter traces by activities
# 294 A6 P1 BPI 2017
#  ***************************  Calculate number of activities
# 295 A7 P1 BPI 2017
#  ***************************  Calculate waiting time
# 296 A7 P1 BPI 2017
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 297 A7 P1 BPI 2017
#  ***************************  Identify rol associated with bottlenecks
# 298 A7 P1 BPI 2017
#  ***************************  Group traces by waiting
# 299 A7 P1 BPI 2017
#  ***************************  Calculate percentage of events
# 300 A7 P1 BPI 2017
#  ***************************  Calculate waiting time
# 301 A7 P1 BPI 2017
#  ***************************  Identify resources by activities
# 302 A7 P1 BPI 2017
#  ***************************  Calculate frequency of resources
# 303 A7 P1 BPI 2017
#  ***************************  Calculate waiting time
# 304 A7 P1 BPI 2017
#  ***************************  Filter traces by activities
# 305 A8 P1 BPI 2017
#  ***************************  Calculate waiting time
# 306 A8 P1 BPI 2017
#  ***************************  Represent bar charts of waiting time
# 307 A8 P1 BPI 2017
#  ***************************  Calculate waiting time
# 308 A8 P1 BPI 2017
#  ***************************  Represent bar charts of waiting time
# 309 A8 P1 BPI 2017
#  ***************************  Calculate waiting time
# 310 A8 P1 BPI 2017
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 311 A8 P1 BPI 2017
#  ***************************  Calculate processing time
# 312 A9 P1 BPI 2017
#  ***************************  Calculate waiting time
# 313 A9 P1 BPI 2017
#  ***************************  Compare waiting time with processing time
# 314 A9 P1 BPI 2017
#  ***************************  Calculate waiting time
# 315 A9 P1 BPI 2017
#  ***************************  Group activities by rol
#  ***************************  Calculate waiting time
# 316 A9 P1 BPI 2017
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 317 A9 P1 BPI 2017
#  ***************************  Represent histograms of waiting time
# 318 A9 P1 BPI 2017
#  ***************************  Identify rol associated with bottlenecks
# 319 A9 P1 BPI 2017
#  ***************************  Filter traces by attributes
# 320 A10 P1 BPI 2017
#  ***************************  Represent process map with cycle time
# 321 A10 P1 BPI 2017
#  ***************************  Calculate cycle time for all pairs of events for a subset of traces
# 322 A10 P1 BPI 2017
#  ***************************  Calculate waiting time
# 323 A10 P1 BPI 2017
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 324 A10 P1 BPI 2017
#  ***************************  Identify rol associated with bottlenecks
# 325 A10 P1 BPI 2017
#  ***************************  Group traces by activities
# 326 A11 P1 BPI 2017
#  ***************************  Calculate number of events
# 327 A11 P1 BPI 2017
#  ***************************  Calculate number of traces
# 328 A11 P1 BPI 2017
#  ***************************  Calculate number of activities
# 329 A11 P1 BPI 2017
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# 330 A11 P1 BPI 2017
#  ***************************  Represent process map with cycle time
# 331 A11 P1 BPI 2017
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 332 A11 P1 BPI 2017
#  ***************************  Calculate waiting time
# 333 A11 P1 BPI 2017
#  ***************************  Filter traces by cycle time
# 334 A11 P1 BPI 2017
#  ***************************  Represent histograms of cycle time
# 335 A11 P1 BPI 2017
#  ***************************  Calculate waiting time
# 336 A11 P1 BPI 2017
#  ***************************  Represent process map with frequency
# 337 A13 P1 BPI 2017
#  ***************************  Represent histograms of waiting time
# 338 A13 P1 BPI 2017
#  ***************************  Calculate waiting time
# 339 A13 P1 BPI 2017
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# 340 A13 P1 BPI 2017
#  ***************************  Filter traces by activities
# 341 A13 P1 BPI 2017
#  ***************************  Calculate number of traces
# 342 A13 P1 BPI 2017
#  ***************************  Represent process map with frequency
# 343 A13 P1 BPI 2017
#  ***************************  Preprocess the traces of the logs
# 344 A14 P1 BPI 2017
#  ***************************  Group traces by activities
# 345 A14 P1 BPI 2017
#  ***************************  Calculate percentage of traces
# 346 A14 P1 BPI 2017
#  ***************************  Calculate cycle time of the whole process for all traces
# 347 A14 P1 BPI 2017
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# 348 A14 P1 BPI 2017
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# 349 A14 P1 BPI 2017
#  ***************************  Group traces depending on attributes
# 350 A14 P1 BPI 2017
#  ***************************  Calculate percentage of traces
# 351 A14 P1 BPI 2017
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# 352 A14 P1 BPI 2017
#  ***************************  Represent process map with cycle time
# 353 A15 P1 BPI 2017
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 354 A15 P1 BPI 2017
#  ***************************  Identify rol associated with bottlenecks
# 355 A15 P1 BPI 2017
#  ***************************  Represent histograms of cycle time
# 356 A15 P1 BPI 2017
#  ***************************  Calculate cycle time of the whole process for all traces
# 357 A15 P1 BPI 2017
#  ***************************  Represent process map with cycle time
# 358 A16 P1 BPI 2017
#  ***************************  Calculate waiting time
# 359 A16 P1 BPI 2017
#  ***************************  Group traces by activities
# 360 A16 P1 BPI 2017
#  ***************************  Calculate number of traces
# 361 A16 P1 BPI 2017
#  ***************************  Calculate waiting time
# 362 A16 P1 BPI 2017
#  ***************************  Group traces by activities
# 363 A16 P1 BPI 2017
#  ***************************  Calculate number of traces
# 364 A16 P1 BPI 2017
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# 365 A16 P1 BPI 2017
#  ***************************  Calculate cycle time of the whole process for all traces
# 366 A17 P1 BPI 2017
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# 367 A17 P1 BPI 2017
#  ***************************  Filter traces by attributes
# 368 A17 P1 BPI 2017
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# 369 A17 P1 BPI 2017
#  ***************************  Represent process map with cycle time
# 370 A17 P1 BPI 2017
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# 371 A17 P1 BPI 2017
#  ***************************  Identify rol associated with bottlenecks
# 372 A17 P1 BPI 2017
#  ***************************  Calculate processing time
# 373 A17 P1 BPI 2017
#  ***************************  Calculate waiting time
# 374 A17 P1 BPI 2017
#  ***************************  Compare waiting time with processing time
# 375 A17 P1 BPI 2017
#  ***************************  Calculate waiting time
# 376 A21 P1 BPI 2017
#  ***************************  Calculate processing time
# 377 A21 P1 BPI 2017
#  ***************************  Calculate cycle time of the whole process for all traces
# 378 A21 P1 BPI 2017
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 379 A21 P1 BPI 2017
#  ***************************  Calculate waiting time
# 380 A22 P1 BPI 2017
#  ***************************  Assign resource to each activity
# 381 A22 P1 BPI 2017
#  ***************************  Calculate frequency of activities
# 382 A22 P1 BPI 2017
#  ***************************  Calculate frequency of activities
# 383 A22 P1 BPI 2017
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 384 A22 P1 BPI 2017
#  ***************************  Group activities using clustering
# 385 A23 P1 BPI 2017
#  ***************************  Represent heatmaps
# 386 A23 P1 BPI 2017
#  ***************************  Represent process map with frequency
# 387 A23 P1 BPI 2017
#  ***************************  Calculate cycle time of only a subset of pairs of events for a subset of traces
# 388 A23 P1 BPI 2017
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# 389 A23 P1 BPI 2017
#  ***************************  Group events by time
# 390 A1 P2 BPI 2019
#  ***************************  Calculate cycle time of only a subset of pairs of events for each subset of traces
# 391 A1 P2 BPI 2019
#  ***************************  Represent bar charts of cycle time
# 392 A1 P2 BPI 2019
#  ***************************  Compare cycle time
# 393 A1 P2 BPI 2019
#  ***************************  Filter traces by activities
# 394 A1 P2 BPI 2019
#  ***************************  Calculate number of traces
# 395 A1 P2 BPI 2019
#  ***************************  Calculate throughput
# 396 A1 P2 BPI 2019
#  ***************************  Calculate frequency of attributes
# 397 A1 P2 BPI 2019
#  ***************************  Represent circular charts of attributes of the traces
# 398 A1 P2 BPI 2019
#  ***************************  Group traces depending on attributes
# 399 A3 P2 BPI 2019
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# 400 A3 P2 BPI 2019
#  ***************************  Calculate percentage of events
# 401 A3 P2 BPI 2019
#  ***************************  Represent circular charts of attributes of the traces
# 402 A3 P2 BPI 2019
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# 403 A3 P2 BPI 2019
#  ***************************  Apply machine learning techniques
# 404 A3 P2 BPI 2019
#  ***************************  Represent histograms of cycle time
# 405 A3 P2 BPI 2019
#  ***************************  Preprocess the events of the logs
# 406 A4 P2 BPI 2019
#  ***************************  Calculate cycle time of only a subset of pairs of events for a subset of traces
# 407 A4 P2 BPI 2019
#  ***************************  Filter traces by activities
# 408 A4 P2 BPI 2019
#  ***************************  Filter traces depending on the order of activities
# 409 A4 P2 BPI 2019
#  ***************************  Filter traces by attributes
# 410 A4 P2 BPI 2019
#  ***************************  Group traces by activities
# 411 A4 P2 BPI 2019
#  ***************************  Calculate cycle time of only a subset of pairs of events for each subset of traces
# 412 A4 P2 BPI 2019
#  ***************************  Filter traces by attributes
# 413 A4 P2 BPI 2019
#  ***************************  Calculate cycle time of only a subset of pairs of events for a subset of traces
# 414 A4 P2 BPI 2019
#  ***************************  Filter traces by attributes
# 415 A4 P2 BPI 2019
#  ***************************  Represent bar charts of cycle time
# 416 A4 P2 BPI 2019
#  ***************************  Filter traces by activities
# 417 A5 P2 BPI 2019
#  ***************************  Calculate percentage of traces
# 418 A5 P2 BPI 2019
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# 419 A5 P2 BPI 2019
#  ***************************  Represent histograms of cycle time
# 420 A5 P2 BPI 2019
#  ***************************  Discover happy path of the process
# 421 A5 P2 BPI 2019
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# 422 A5 P2 BPI 2019
#  ***************************  Calculate percentage of traces
# 423 A5 P2 BPI 2019
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# 424 A5 P2 BPI 2019
#  ***************************  Represent bar charts of attributes
# 425 A5 P2 BPI 2019
#  ***************************  Identify recurso asociado a bottlenecks
#  ***************************  Represent bar charts of attributes
# 426 A5 P2 BPI 2019
#  ***************************  Identify values of attributes
# 427 A5 P2 BPI 2019
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# 428 A5 P2 BPI 2019
#  ***************************  Represent bar charts of cycle time
# 429 A5 P2 BPI 2019
#  ***************************  Identify resources by cycle time
# 430 A5 P2 BPI 2019
#  ***************************  Represent bar charts of attributes
# 431 A5 P2 BPI 2019
#  ***************************  Identify resources by activities
# 432 A5 P2 BPI 2019
#  ***************************  Represent bar charts of attributes
# 433 A5 P2 BPI 2019
#  ***************************  Identify values of attributes
# 434 A5 P2 BPI 2019
#  ***************************  Preprocess the traces of the logs
# 435 A10 P2 BPI 2019
#  ***************************  Calculate cycle time for all pairs of events for a subset of traces
# 436 A10 P2 BPI 2019
#  ***************************  Calculate cycle time of only a subset of pairs of events for a subset of traces
# 437 A10 P2 BPI 2019
#  ***************************  Calculate percentage of traces
# 438 A10 P2 BPI 2019
#  ***************************  Identify values of attributes
# 439 A10 P2 BPI 2019
#  ***************************  Filter traces by activities
# 440 A11 P2 BPI 2019
#  ***************************  Filter traces by attributes
# 441 A11 P2 BPI 2019
#  ***************************  Calculate number of events
# 442 A11 P2 BPI 2019
#  ***************************  Calculate percentage of events
# 443 A11 P2 BPI 2019
#  ***************************  Represent circular charts of attributes of the traces
# 444 A11 P2 BPI 2019
#  ***************************  Calculate dates of the development of activities of resources
#  ***************************  Calculate number of events
# 445 A11 P2 BPI 2019
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# 446 A11 P2 BPI 2019
#  ***************************  Calculate average of activities per trace
# 447 A11 P2 BPI 2019
#  ***************************  Calculate percentage of events
# 448 A11 P2 BPI 2019
#  ***************************  Identify values of attributes
# 449 A11 P2 BPI 2019
#  ***************************  Represent bar charts of attributes
# 450 A11 P2 BPI 2019
#  ***************************  Represent process map with frequency
# 451 A11 P2 BPI 2019
#  ***************************  Represent process map with cycle time
# 452 A11 P2 BPI 2019
#  ***************************  Represent bar charts of cycle time
# 453 A11 P2 BPI 2019
#  ***************************  Group traces by activities
# 454 A11 P2 BPI 2019
#  ***************************  Represent bar charts of cycle time
# 455 A11 P2 BPI 2019
#  ***************************  Group traces depending on attributes
# 456 A13 P2 BPI 2019
#  ***************************  Group traces depending on attributes
# 457 A13 P2 BPI 2019
#  ***************************  Calculate number of events
# 458 A13 P2 BPI 2019
#  ***************************  Filter traces by activities
# 459 A13 P2 BPI 2019
#  ***************************  Calculate cycle time of only a subset of pairs of events for each subset of traces
# 460 A13 P2 BPI 2019
#  ***************************  Calculate cycle time of only a subset of pairs of events for each subset of traces
# 461 A13 P2 BPI 2019
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# 462 A13 P2 BPI 2019
#  ***************************  Group traces depending on attributes
# 463 A14 P2 BPI 2019
#  ***************************  Calculate number of activities
# 464 A14 P2 BPI 2019
#  ***************************  Identify activity with biggest backlog
# 465 A14 P2 BPI 2019
#  ***************************  Calculate waiting time
# 466 A14 P2 BPI 2019
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# 467 A14 P2 BPI 2019
#  ***************************  Calculate cycle time of only a subset of pairs of events for a subset of traces
# 468 A14 P2 BPI 2019
#  ***************************  Calculate cycle time of only a subset of pairs of events for a subset of traces
# 469 A14 P2 BPI 2019
#  ***************************  Represent heatmaps
# 470 A14 P2 BPI 2019
#  ***************************  Calculate dates of the development of activities of resources
#  ***************************  Filter traces by attributes
# 471 A14 P2 BPI 2019
#  ***************************  Calculate number of traces
# 472 A14 P2 BPI 2019
#  ***************************  Calculate Statistics of attributes
# 473 A14 P2 BPI 2019
#  ***************************  Represent bar charts of cycle time
# 474 A14 P2 BPI 2019
#  ***************************  Represent temporal series of subprocesses
# 475 A14 P2 BPI 2019
#  ***************************  Represent bar charts of waiting time
# 476 A14 P2 BPI 2019
#  ***************************  Calculate Statistics of attributes
# 477 A14 P2 BPI 2019
#  ***************************  Filter traces by attributes
# 478 A14 P2 BPI 2019
#  ***************************  Group traces depending on attributes
# 479 A14 P2 BPI 2019
#  ***************************  Calculate number of variants
# 480 A14 P2 BPI 2019
#  ***************************  Calculate number of traces
# 481 A14 P2 BPI 2019
#  ***************************  Calculate number of traces
# 482 A14 P2 BPI 2019
#  ***************************  Filter traces by frequency
# 483 A14 P2 BPI 2019
#  ***************************  Represent scatterplot
# 484 A14 P2 BPI 2019
#  ***************************  Calculate number of traces
# 485 A15 P2 BPI 2019
#  ***************************  Calculate number of events
# 486 A15 P2 BPI 2019
#  ***************************  Calculate number of activities
# 487 A15 P2 BPI 2019
#  ***************************  Calculate number of variants
# 488 A15 P2 BPI 2019
#  ***************************  Calcute number of values of an attribute
# 489 A15 P2 BPI 2019
#  ***************************  Calculate Statistics of attributes
# 490 A15 P2 BPI 2019
#  ***************************  Filter traces by activities
# 491 A15 P2 BPI 2019
#  ***************************  Calculate percentage of traces
# 492 A15 P2 BPI 2019
#  ***************************  Filter traces by activities
# 493 A15 P2 BPI 2019
#  ***************************  Calculate percentage of traces
# 494 A15 P2 BPI 2019
#  ***************************  Filter events by activities
# 495 A15 P2 BPI 2019
#  ***************************  Preprocess the events of the logs
# 496 A15 P2 BPI 2019
#  ***************************  Group traces according to the repetition of activities
# 497 A15 P2 BPI 2019
#  ***************************  Calculate cycle time of only a subset of pairs of events for each subset of traces
# 498 A15 P2 BPI 2019
#  ***************************  Calculate number of traces
# 499 A15 P2 BPI 2019
#  ***************************  Calculate Statistics of attributes
# 500 A15 P2 BPI 2019
#  ***************************  Represent process map with cycle time
# 501 A15 P2 BPI 2019
#     case:concept:name             General operation  \
# 0      A1 P2 BPI 2020          Calculate cycle time
# 1      A1 P2 BPI 2020            Compare cycle time
# 2      A2 P2 BPI 2020          Calculate cycle time
# 3      A2 P2 BPI 2020            Compare cycle time
# 4      A7 P2 BPI 2020          Calculate throughput
# ..                ...                           ...
# 497   A15 P2 BPI 2019                  Group traces
# 498   A15 P2 BPI 2019          Calculate cycle time
# 499   A15 P2 BPI 2019  Calculate number of elements
# 500   A15 P2 BPI 2019          Calculate statistics
# 501   A15 P2 BPI 2019         Represent process map
#
#                                     Specific operation  \
# 0    Calculate cycle time of the whole process for ...
# 1
# 2            Get cycle time from the previous question
# 3
# 4
# ..                                                 ...
# 497  Group traces according to the repetition of ac...
# 498  Calculate cycle time of only a subset of pairs...
# 499                         Calculate number of traces
# 500                 Calculate Statistics of attributes
# 501              Represent process map with cycle time
#
#                            Time Question  Year
# 0    2021-07-09 13:14:11.517070       P2  2020
# 1    2021-07-09 13:14:11.523048       P2  2020
# 2    2021-07-09 13:14:11.528041       P2  2020
# 3    2021-07-09 13:14:11.533029       P2  2020
# 4    2021-07-09 13:14:11.540007       P2  2020
# ..                          ...      ...   ...
# 497  2021-07-09 13:14:14.469173       P2  2019
# 498  2021-07-09 13:14:14.474166       P2  2019
# 499  2021-07-09 13:14:14.480145       P2  2019
# 500  2021-07-09 13:14:14.485133       P2  2019
# 501  2021-07-09 13:14:14.492117       P2  2019
#
# [502 rows x 6 columns]

# %%
log = log_converter.apply(df_prueba)
xes_exporter.apply(log, './Log of analysis of time spects.xes')
