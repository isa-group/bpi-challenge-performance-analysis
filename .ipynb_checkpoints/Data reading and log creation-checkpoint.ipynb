# %%
import pandas as pd
import datetime
from os import listdir
import os, os.path
from os.path import isfile, join
import numpy as np
import csv
import re
import pandas as pd
import pm4py
from pm4py.objects.conversion.log import converter as log_converter
from pm4py.objects.log.importer.xes import importer as xes_importer
from pm4py.objects.log.exporter.xes import exporter as xes_exporter
from pm4py.objects.log.util import dataframe_utils

# %%
datos_raw = pd.read_excel("./grouped table of annotations.xlsx")
datos_raw=datos_raw.drop(['Unnamed: 0'], axis='columns')
glosario = pd.read_excel("./OperationCoding (solo cycle time).xlsx")
glosario['General operations'] = glosario['General operations'].fillna(method='pad')
glosario['Specific operations'] =  glosario['Specific operations'].str.split().str.join(' ')
glosario['General operations'] =  glosario['General operations'].str.split().str.join(' ')

columns=['case:id','case:concept:name','concept:name','Specific operation','time:timestamp','Question','Year']
#columna es el case_ID
cont = 0
df_prueba= pd.DataFrame(columns=columns)
ct=datetime.datetime.now()
for columna in datos_raw.columns:
    print("-----------------------------------------------------------------------")
    print("Case:id")
    print(columna)
    acciones_analisis=datos_raw[columna].dropna()
    for accion in acciones_analisis:
        
        accion = re.sub('[\xa0]', ' ', accion)
        print(' *************************** ', accion)
        string_dividido=accion.split(' ')
        accion = ' '.join(string_dividido)
        for fila in range(len(glosario)):
                     
            if(accion == glosario['Specific operations'][fila]):
                #print('si', accion)
                accionGeneral=glosario['General operations'][fila]
                accionEspecifica=accion
                columnaSeparada=columna.split()
                pregunta=columnaSeparada[1]
                año=columnaSeparada[3]
                ct=ct+datetime.timedelta(hours=1)
                print("Fecha:") 
                print(ct)
                new_row={'case:id':columna, 'case:concept:name':columna, 'concept:name':accionGeneral,'Specific operation':accionEspecifica,'time:timestamp':str(ct),'Question':pregunta,'Year':año} 
                #print(cont, new_row['case:concept:name'])
                cont = cont +1
                df_prueba = df_prueba.append(new_row, ignore_index=True)
                
            elif(accion == glosario['General operations'][fila]):
                #print('no', accion)
                accionGeneral=accion
                accionEspecifica=" "
                columnaSeparada=columna.split()
                pregunta=columnaSeparada[1]
                año=columnaSeparada[3]
                ct=ct+ datetime.timedelta(hours=1)
                print("Fecha:") 
                print(ct)
                new_row={'case:id':columna, 'case:concept:name':columna, 'concept:name':accionGeneral,'Specific operation':accionEspecifica,'time:timestamp':str(ct),'Question':pregunta,'Year':año} 
                #print(cont, new_row['case:concept:name'])
                cont = cont +1
                df_prueba = df_prueba.append(new_row, ignore_index=True)
            
                
            
df_prueba
# Out:
# -----------------------------------------------------------------------
# Case:id
# A1 P2 BPI 2020
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-11 17:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-11 18:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A2 P2 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-11 19:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-11 20:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A7 P2 BPI 2020
#  ***************************  Calculate throughput
# Fecha:
# 2021-10-11 21:19:56.835674
#  ***************************  Comparative of throughput
# Fecha:
# 2021-10-11 22:19:56.835674
#  ***************************  Comparative of throughput
# Fecha:
# 2021-10-11 23:19:56.835674
#  ***************************  Represent scatterplot
# Fecha:
# 2021-10-12 00:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A10 P2 BPI 2020
#  ***************************  Represent boxplots of cycle time
# Fecha:
# 2021-10-12 01:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-12 02:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A12 P2 BPI 2020
#  ***************************  Calculate throughput
# Fecha:
# 2021-10-12 03:19:56.835674
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-10-12 04:19:56.835674
#  ***************************  Calculate throughput
# Fecha:
# 2021-10-12 05:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A13 P2 BPI 2020
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# Fecha:
# 2021-10-12 06:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-12 07:19:56.835674
#  ***************************  Identify specific subprocesses
# Fecha:
# 2021-10-12 08:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A18 P2 BPI 2020
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-10-12 09:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A25 P2 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-12 10:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-12 11:19:56.835674
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-12 12:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A26 P2 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-12 13:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-12 14:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A28 P2 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-12 15:19:56.835674
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-12 16:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-12 17:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A35 P2 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-10-12 18:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-12 19:19:56.835674
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-12 20:19:56.835674
#  ***************************  Calculate average of activities per trace
# Fecha:
# 2021-10-12 21:19:56.835674
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-12 22:19:56.835674
#  ***************************  Calculate Statistics of attributes
# Fecha:
# 2021-10-12 23:19:56.835674
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-10-13 00:19:56.835674
#  ***************************  Represent histograms of attributes
# Fecha:
# 2021-10-13 01:19:56.835674
#  ***************************  Represent bar charts of traces
# Fecha:
# 2021-10-13 02:19:56.835674
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-13 03:19:56.835674
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-13 04:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-13 05:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A37 P2 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-13 06:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-13 07:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A2 P4 BPI 2020
#  ***************************  Filter activities by sub-processes
# Fecha:
# 2021-10-13 08:19:56.835674
#  ***************************  Group activities by sub-processes
# Fecha:
# 2021-10-13 09:19:56.835674
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-10-13 10:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A7 P4 BPI 2020
#  ***************************  Group activities by role
# Fecha:
# 2021-10-13 11:19:56.835674
#  ***************************  Calculate throughput
# Fecha:
# 2021-10-13 12:19:56.835674
#  ***************************  Group activities by time
# Fecha:
# 2021-10-13 13:19:56.835674
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-13 14:19:56.835674
#  ***************************  Represent scatterplot
# Fecha:
# 2021-10-13 15:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A10 P4 BPI 2020
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-13 16:19:56.835674
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-13 17:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A12 P4 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-13 18:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A13 P4 BPI 2020
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-13 19:19:56.835674
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-13 20:19:56.835674
#  ***************************  Group activities by sub-processes
# Fecha:
# 2021-10-13 21:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# Fecha:
# 2021-10-13 22:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A18 P4 BPI 2020
#  ***************************  Represent process map with frequency
# Fecha:
# 2021-10-13 23:19:56.835674
#  ***************************  Calculate cycle time of only a subset of pairs of events for a subset of traces
# Fecha:
# 2021-10-14 00:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A25 P4 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-14 01:19:56.835674
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-10-14 02:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-14 03:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A26 P4 BPI 2020
#  ***************************  Filter variants depending on frequency
# Fecha:
# 2021-10-14 04:19:56.835674
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-14 05:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A28 P4 BPI 2020
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-10-14 06:19:56.835674
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-14 07:19:56.835674
#  ***************************  Represent heatmaps
# Fecha:
# 2021-10-14 08:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-14 09:19:56.835674
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-10-14 10:19:56.835674
#  ***************************  Represent heatmaps
# Fecha:
# 2021-10-14 11:19:56.835674
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-14 12:19:56.835674
#  ***************************  Represent heatmaps
# Fecha:
# 2021-10-14 13:19:56.835674
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-10-14 14:19:56.835674
#  ***************************  Represent heatmaps
# Fecha:
# 2021-10-14 15:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A35 P4 BPI 2020
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-14 16:19:56.835674
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-14 17:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-10-14 18:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-14 19:19:56.835674
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-14 20:19:56.835674
#  ***************************  Calculate average of activities per trace
# Fecha:
# 2021-10-14 21:19:56.835674
#  ***************************  Group traces by roles
# Fecha:
# 2021-10-14 22:19:56.835674
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-14 23:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A37 P4 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-15 00:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A1 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-15 01:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 02:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A2 P5 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-15 03:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 04:19:56.835674
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-15 05:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A7 P5 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-15 06:19:56.835674
#  ***************************  Filter activities by cycle time
# Fecha:
# 2021-10-15 07:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 08:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A10 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-15 09:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 10:19:56.835674
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-15 11:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A12 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-15 12:19:56.835674
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-10-15 13:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 14:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A13 P5 BPI 2020
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-15 15:19:56.835674
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-15 16:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 17:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A18 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-15 18:19:56.835674
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 19:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A25 P5 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-15 20:19:56.835674
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-10-15 21:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-15 22:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A26 P5 BPI 2020
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-15 23:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-16 00:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A28 P5 BPI 2020
#  ***************************  Identify sub-processes with incorrect orders with respect to the happy path as bottlenecks
# Fecha:
# 2021-10-16 01:19:56.835674
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-16 02:19:56.835674
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-16 03:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A35 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-16 04:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-16 05:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A37 P5 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-16 06:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-16 07:19:56.835674
#  ***************************  Identify sub-processes with incorrect orders with respect to the happy path as bottlenecks
# Fecha:
# 2021-10-16 08:19:56.835674
#  ***************************  Calculate frequency of attributes
# Fecha:
# 2021-10-16 09:19:56.835674
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-16 10:19:56.835674
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-16 11:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A1 P6 BPI 2020
#  ***************************  Filter traces depending on the order of activities
# Fecha:
# 2021-10-16 12:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-10-16 13:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A2 P6 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-16 14:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-16 15:19:56.835674
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-16 16:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A7 P6 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-16 17:19:56.835674
#  ***************************  Filter activities by cycle time
# Fecha:
# 2021-10-16 18:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-16 19:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A10 P6 BPI 2020
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-16 20:19:56.835674
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-16 21:19:56.835674
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-10-16 22:19:56.835674
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-16 23:19:56.835674
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-17 00:19:56.835674
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-10-17 01:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A12 P6 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-17 02:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-17 03:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A13 P6 BPI 2020
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-10-17 04:19:56.835674
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-17 05:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# Fecha:
# 2021-10-17 06:19:56.835674
#  ***************************  Calculate frequency of variants
# Fecha:
# 2021-10-17 07:19:56.835674
#  ***************************  Calculate intervals of time of the traces
# Fecha:
# 2021-10-17 08:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-17 09:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A25 P6 BPI 2020
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-17 10:19:56.835674
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-10-17 11:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-17 12:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A26 P6 BPI 2020
#  ***************************  Get cycle time from the previous question
# Fecha:
# 2021-10-17 13:19:56.835674
#  ***************************  Get process map from the previous question
# Fecha:
# 2021-10-17 14:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-17 15:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A28 P6 BPI 2020
#  ***************************  Identify sub-processes with incorrect orders with respect to the happy path as bottlenecks
# Fecha:
# 2021-10-17 16:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A35 P6 BPI 2020
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-17 17:19:56.835674
#  ***************************  Identify sub-processes with incorrect orders with respect to the happy path as bottlenecks
# Fecha:
# 2021-10-17 18:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A37 P6 BPI 2020
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-17 19:19:56.835674
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-10-17 20:19:56.835674
#  ***************************  Calculate number of variants
# Fecha:
# 2021-10-17 21:19:56.835674
#  ***************************  Calculate number of different organizational units
# Fecha:
# 2021-10-17 22:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-10-17 23:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-18 00:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A2 P5 BPI 2015
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-18 01:19:56.835674
#  ***************************  Filter events by cycle time
# Fecha:
# 2021-10-18 02:19:56.835674
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-18 03:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-18 04:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A3 P5 BPI 2015
#  ***************************  Group activities by sub-processes
# Fecha:
# 2021-10-18 05:19:56.835674
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-10-18 06:19:56.835674
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-18 07:19:56.835674
#  ***************************  Filter activities by frequency
# Fecha:
# 2021-10-18 08:19:56.835674
#  ***************************  Represent bar charts of traces
# Fecha:
# 2021-10-18 09:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-18 10:19:56.835674
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-18 11:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A4 P5 BPI 2015
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-10-18 12:19:56.835674
#  ***************************  Identify organizational units as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-18 13:19:56.835674
#  ***************************  Identify impact of bottlenecks by organizational unit
# Fecha:
# 2021-10-18 14:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-18 15:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A7 P5 BPI 2015
#  ***************************  Filter traces by attributes
# Fecha:
# 2021-10-18 16:19:56.835674
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-18 17:19:56.835674
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-18 18:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-18 19:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-18 20:19:56.835674
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-18 21:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A8 P5 BPI 2015
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-10-18 22:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-18 23:19:56.835674
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-10-19 00:19:56.835674
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-10-19 01:19:56.835674
#  ***************************  Group traces by cycle time
# Fecha:
# 2021-10-19 02:19:56.835674
#  ***************************  Group traces by organizational units
# Fecha:
# 2021-10-19 03:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-19 04:19:56.835674
#  ***************************  Analyze cycle time depending on the events
# Fecha:
# 2021-10-19 05:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-19 06:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-19 07:19:56.835674
#  ***************************  Filter activities by frequency
# Fecha:
# 2021-10-19 08:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-19 09:19:56.835674
#  ***************************  Calculate frequency of activities
# Fecha:
# 2021-10-19 10:19:56.835674
#  ***************************  Calculate cycle time of only a subset of pairs of events for each subset of traces
# Fecha:
# 2021-10-19 11:19:56.835674
#  ***************************  Identify organizational units as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-19 12:19:56.835674
#  ***************************  Identify resource associated with bottlenecks
# Fecha:
# 2021-10-19 13:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A9 P5 BPI 2015
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-19 14:19:56.835674
#  ***************************  Calculate cycle time for all pairs of events for a subset of traces
# Fecha:
# 2021-10-19 15:19:56.835674
#  ***************************  Group traces by cycle time
# Fecha:
# 2021-10-19 16:19:56.835674
#  ***************************  Apply decision trees
# Fecha:
# 2021-10-19 17:19:56.835674
#  ***************************  Group organizational units
# Fecha:
# 2021-10-19 18:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-19 19:19:56.835674
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-10-19 20:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-19 21:19:56.835674
#  ***************************  Identify organizational units as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-19 22:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A1 P1 BPI 2020
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-19 23:19:56.835674
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-20 00:19:56.835674
#  ***************************  Calculate throughput
# Fecha:
# 2021-10-20 01:19:56.835674
#  ***************************  Filter traces by attributes
# Fecha:
# 2021-10-20 02:19:56.835674
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-20 03:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A2 P1 BPI 2020
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-20 04:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A7 P1 BPI 2020
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-20 05:19:56.835674
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-20 06:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-20 07:19:56.835674
#  ***************************  Calculate throughput
# Fecha:
# 2021-10-20 08:19:56.835674
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-10-20 09:19:56.835674
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-10-20 10:19:56.835674
#  ***************************  Calculate throughput
# Fecha:
# 2021-10-20 11:19:56.835674
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-10-20 12:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A10 P1 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-10-20 13:19:56.835674
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-20 14:19:56.835674
#  ***************************  Represent boxplots of cycle time
# Fecha:
# 2021-10-20 15:19:56.835674
#  ***************************  Represent density of cycle time
# Fecha:
# 2021-10-20 16:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A12 P1 BPI 2020
#  ***************************  Calculate processing time
# Fecha:
# 2021-10-20 17:19:56.835674
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-20 18:19:56.835674
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-20 19:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A13 P1 BPI 2020
#  ***************************  Represent bar charts of traces
# Fecha:
# 2021-10-20 20:19:56.835674
#  ***************************  Calculate throughput
# Fecha:
# 2021-10-20 21:19:56.835674
#  ***************************  Represent bar charts of traces
# Fecha:
# 2021-10-20 22:19:56.835674
#  ***************************  Group traces by year
# Fecha:
# 2021-10-20 23:19:56.835674
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-21 00:19:56.835674
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-10-21 01:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-21 02:19:56.835674
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-21 03:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A18 P1 BPI 2020
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-21 04:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-21 05:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-10-21 06:19:56.835674
#  ***************************  Represent boxplots of cycle time
# Fecha:
# 2021-10-21 07:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A25 P1 BPI 2020
#  ***************************  Filter traces by attributes
# Fecha:
# 2021-10-21 08:19:56.835674
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-21 09:19:56.835674
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-21 10:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-21 11:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-10-21 12:19:56.835674
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-21 13:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A26 P1 BPI 2020
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-21 14:19:56.835674
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-21 15:19:56.835674
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-21 16:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A28 P1 BPI 2020
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-21 17:19:56.835674
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-10-21 18:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-21 19:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A35 P1 BPI 2020
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-21 20:19:56.835674
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-21 21:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-10-21 22:19:56.835674
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-21 23:19:56.835674
#  ***************************  Compare cycle time
# Fecha:
# 2021-10-22 00:19:56.835674
#  ***************************  Group traces by year
# Fecha:
# 2021-10-22 01:19:56.835674
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-22 02:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A37 P1 BPI 2020
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-10-22 03:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-10-22 04:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-22 05:19:56.835674
#  ***************************  Calculate number of events
# Fecha:
# 2021-10-22 06:19:56.835674
#  ***************************  Calculate number of variants
# Fecha:
# 2021-10-22 07:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A1 P1 BPI 2017
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-22 08:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for all traces
# Fecha:
# 2021-10-22 09:19:56.835674
#  ***************************  Filter events by attributes
# Fecha:
# 2021-10-22 10:19:56.835674
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# Fecha:
# 2021-10-22 11:19:56.835674
#  ***************************  Calculate frequency of events
# Fecha:
# 2021-10-22 12:19:56.835674
#  ***************************  Filter events by activities
# Fecha:
# 2021-10-22 13:19:56.835674
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# Fecha:
# 2021-10-22 14:19:56.835674
#  ***************************  Calculate frequency of events
# Fecha:
# 2021-10-22 15:19:56.835674
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-22 16:19:56.835674
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-22 17:19:56.835674
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-22 18:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-10-22 19:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A2 P1 BPI 2017
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-22 20:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-22 21:19:56.835674
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-22 22:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-22 23:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A5 P1 BPI 2017
#  ***************************  Filter events by activities
# Fecha:
# 2021-10-23 00:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-10-23 01:19:56.835674
#  ***************************  Calculate processing time
# Fecha:
# 2021-10-23 02:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-23 03:19:56.835674
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-23 04:19:56.835674
#  ***************************  Filter events by activities
# Fecha:
# 2021-10-23 05:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-10-23 06:19:56.835674
#  ***************************  Calculate processing time
# Fecha:
# 2021-10-23 07:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-23 08:19:56.835674
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-23 09:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A6 P1 BPI 2017
#  ***************************  Discover process maps
# Fecha:
# 2021-10-23 10:19:56.835674
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-23 11:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-23 12:19:56.835674
#  ***************************  Calculate frequency of events
# Fecha:
# 2021-10-23 13:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-23 14:19:56.835674
#  ***************************  Calculate frequency of activities
# Fecha:
# 2021-10-23 15:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-23 16:19:56.835674
#  ***************************  Calculate cycle time of only a subset of pairs of events for all traces
# Fecha:
# 2021-10-23 17:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-23 18:19:56.835674
#  ***************************  Calculate processing time
# Fecha:
# 2021-10-23 19:19:56.835674
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-23 20:19:56.835674
#  ***************************  Group traces by cycle time
# Fecha:
# 2021-10-23 21:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-23 22:19:56.835674
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-23 23:19:56.835674
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-24 00:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A7 P1 BPI 2017
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-24 01:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 02:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-24 03:19:56.835674
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2021-10-24 04:19:56.835674
#  ***************************  Group traces by waiting
# Fecha:
# 2021-10-24 05:19:56.835674
#  ***************************  Calculate percentage of events
# Fecha:
# 2021-10-24 06:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 07:19:56.835674
#  ***************************  Identify resources by activities
# Fecha:
# 2021-10-24 08:19:56.835674
#  ***************************  Calculate frequency of resources
# Fecha:
# 2021-10-24 09:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 10:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A8 P1 BPI 2017
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-24 11:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 12:19:56.835674
#  ***************************  Represent bar charts of waiting time
# Fecha:
# 2021-10-24 13:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 14:19:56.835674
#  ***************************  Represent bar charts of waiting time
# Fecha:
# 2021-10-24 15:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 16:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-24 17:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A9 P1 BPI 2017
#  ***************************  Calculate processing time
# Fecha:
# 2021-10-24 18:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 19:19:56.835674
#  ***************************  Compare waiting time with processing time
# Fecha:
# 2021-10-24 20:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 21:19:56.835674
#  ***************************  Group activities by role
# Fecha:
# 2021-10-24 22:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-24 23:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-25 00:19:56.835674
#  ***************************  Represent histograms of waiting time
# Fecha:
# 2021-10-25 01:19:56.835674
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2021-10-25 02:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A10 P1 BPI 2017
#  ***************************  Filter traces by attributes
# Fecha:
# 2021-10-25 03:19:56.835674
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-25 04:19:56.835674
#  ***************************  Calculate cycle time for all pairs of events for a subset of traces
# Fecha:
# 2021-10-25 05:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-25 06:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-25 07:19:56.835674
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2021-10-25 08:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A11 P1 BPI 2017
#  ***************************  Group traces by activities
# Fecha:
# 2021-10-25 09:19:56.835674
#  ***************************  Calculate number of events
# Fecha:
# 2021-10-25 10:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-25 11:19:56.835674
#  ***************************  Calculate number of activities
# Fecha:
# 2021-10-25 12:19:56.835674
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-10-25 13:19:56.835674
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-25 14:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-25 15:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-25 16:19:56.835674
#  ***************************  Filter traces by cycle time
# Fecha:
# 2021-10-25 17:19:56.835674
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-25 18:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-25 19:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A13 P1 BPI 2017
#  ***************************  Represent process map with frequency
# Fecha:
# 2021-10-25 20:19:56.835674
#  ***************************  Represent histograms of waiting time
# Fecha:
# 2021-10-25 21:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-25 22:19:56.835674
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-25 23:19:56.835674
#  ***************************  Filter traces by activities
# Fecha:
# 2021-10-26 00:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-26 01:19:56.835674
#  ***************************  Represent process map with frequency
# Fecha:
# 2021-10-26 02:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A14 P1 BPI 2017
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-10-26 03:19:56.835674
#  ***************************  Group traces by activities
# Fecha:
# 2021-10-26 04:19:56.835674
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-26 05:19:56.835674
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-26 06:19:56.835674
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-10-26 07:19:56.835674
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-26 08:19:56.835674
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-10-26 09:19:56.835674
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-10-26 10:19:56.835674
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-10-26 11:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A15 P1 BPI 2017
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-26 12:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-26 13:19:56.835674
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2021-10-26 14:19:56.835674
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-10-26 15:19:56.835674
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-26 16:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A16 P1 BPI 2017
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-26 17:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-26 18:19:56.835674
#  ***************************  Group traces by activities
# Fecha:
# 2021-10-26 19:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-26 20:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-26 21:19:56.835674
#  ***************************  Group traces by activities
# Fecha:
# 2021-10-26 22:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-10-26 23:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# Fecha:
# 2021-10-27 00:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A17 P1 BPI 2017
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-27 01:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# Fecha:
# 2021-10-27 02:19:56.835674
#  ***************************  Filter traces by attributes
# Fecha:
# 2021-10-27 03:19:56.835674
#  ***************************  Calculate cycle time of the whole process for a subset of traces
# Fecha:
# 2021-10-27 04:19:56.835674
#  ***************************  Represent process map with cycle time
# Fecha:
# 2021-10-27 05:19:56.835674
#  ***************************  Identify sub-processes as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-10-27 06:19:56.835674
#  ***************************  Identify role associated with bottlenecks
# Fecha:
# 2021-10-27 07:19:56.835674
#  ***************************  Calculate processing time
# Fecha:
# 2021-10-27 08:19:56.835674
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-27 09:19:56.835674
#  ***************************  Compare waiting time with processing time
# Fecha:
# 2021-10-27 10:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A21 P1 BPI 2017
#  ***************************  Calculate waiting time
# Fecha:
# 2021-10-27 11:19:56.835674
#  ***************************  Calculate processing time
# Fecha:
# 2021-10-27 12:19:56.835674
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-10-27 13:19:56.835674
# ...
# Fecha:
# 2021-11-15 01:19:56.835674
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-11-15 02:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-11-15 03:19:56.835674
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-11-15 04:19:56.835674
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-11-15 05:19:56.835674
#  ***************************  Identify attributes by traces
# Fecha:
# 2021-11-15 06:19:56.835674
#  ***************************  Filter traces by cycle time
# Fecha:
# 2021-11-15 07:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-11-15 08:19:56.835674
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-11-15 09:19:56.835674
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-11-15 10:19:56.835674
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-11-15 11:19:56.835674
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-11-15 12:19:56.835674
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-11-15 13:19:56.835674
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-11-15 14:19:56.835674
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-11-15 15:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for a subset of traces
# Fecha:
# 2021-11-15 16:19:56.835674
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-11-15 17:19:56.835674
#  ***************************  Calculate cycle time of a fragment of the process for each subset of traces
# Fecha:
# 2021-11-15 18:19:56.835674
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-11-15 19:19:56.835674
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-11-15 20:19:56.835674
#  ***************************  Group events by attributes
# Fecha:
# 2021-11-15 21:19:56.835674
#  ***************************  Calculate cycle time for all pairs of events for each subset of traces
# Fecha:
# 2021-11-15 22:19:56.835674
#  ***************************  Group traces depending on attributes
# Fecha:
# 2021-11-15 23:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-11-16 00:19:56.835674
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-11-16 01:19:56.835674
#  ***************************  Identify attributes by cycle time
# Fecha:
# 2021-11-16 02:19:56.835674
#  ***************************  Represent bar charts of cycle time
# Fecha:
# 2021-11-16 03:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A30 P1 BPI 2020
#  ***************************  Filter traces by activities
# Fecha:
# 2021-11-16 04:19:56.835674
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-11-16 05:19:56.835674
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-11-16 06:19:56.835674
#  ***************************  Filter traces by activities
# Fecha:
# 2021-11-16 07:19:56.835674
#  ***************************  Represent temporal series of traces
# Fecha:
# 2021-11-16 08:19:56.835674
#  ***************************  Represent temporal series of traces
# Fecha:
# 2021-11-16 09:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A31 P1 BPI 2020
#  ***************************  Calculate cycle time of the whole process for all traces
# Fecha:
# 2021-11-16 10:19:56.835674
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-11-16 11:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-11-16 12:19:56.835674
#  ***************************  Calculate throughput
# Fecha:
# 2021-11-16 13:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A34 P1 BPI 2020
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-11-16 14:19:56.835674
#  ***************************  Filter traces by subprocesses
# Fecha:
# 2021-11-16 15:19:56.835674
#  ***************************  Group traces by sub-processes
# Fecha:
# 2021-11-16 16:19:56.835674
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-11-16 17:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A27 P2 BPI 2020
#  ***************************  Calculate frequency of activities
# Fecha:
# 2021-11-16 18:19:56.835674
#  ***************************  Represent bart charts of activities
# Fecha:
# 2021-11-16 19:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A30 P2 BPI 2020
#  ***************************  Group traces by month
# Fecha:
# 2021-11-16 20:19:56.835674
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-11-16 21:19:56.835674
#  ***************************  Identify values of attributes
# Fecha:
# 2021-11-16 22:19:56.835674
#  ***************************  Group traces by month
# Fecha:
# 2021-11-16 23:19:56.835674
#  ***************************  Calculate cycle time of the whole process for each subset of traces
# Fecha:
# 2021-11-17 00:19:56.835674
#  ***************************  Identify values of attributes
# Fecha:
# 2021-11-17 01:19:56.835674
#  ***************************  Identify values of attributes
# Fecha:
# 2021-11-17 02:19:56.835674
#  ***************************  Identify values of attributes
# Fecha:
# 2021-11-17 03:19:56.835674
#  ***************************  Calculate number of events
# Fecha:
# 2021-11-17 04:19:56.835674
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-11-17 05:19:56.835674
#  ***************************  Identify values of attributes
# Fecha:
# 2021-11-17 06:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A31 P2 BPI 2020
#  ***************************  Compare cycle time
# Fecha:
# 2021-11-17 07:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A19 P4 BPI 2020
#  ***************************  Filter traces by frequency
# Fecha:
# 2021-11-17 08:19:56.835674
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-17 09:19:56.835674
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-17 10:19:56.835674
#  ***************************  Identify activities with cycle time
# Fecha:
# 2021-11-17 11:19:56.835674
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-11-17 12:19:56.835674
#  ***************************  Identify transitions by cycle time
# Fecha:
# 2021-11-17 13:19:56.835674
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-17 14:19:56.835674
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-17 15:19:56.835674
#  ***************************  Filter traces by frequency
# Fecha:
# 2021-11-17 16:19:56.835674
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-17 17:19:56.835674
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-17 18:19:56.835674
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-17 19:19:56.835674
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-17 20:19:56.835674
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-11-17 21:19:56.835674
#  ***************************  Identify roles by organizational units
# Fecha:
# 2021-11-17 22:19:56.835674
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-11-17 23:19:56.835674
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-18 00:19:56.835674
#  ***************************  Identify activities with traces
# Fecha:
# 2021-11-18 01:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A27 P4 BPI 2020
#  ***************************  Group activities by role
# Fecha:
# 2021-11-18 02:19:56.835674
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-11-18 03:19:56.835674
#  ***************************  Calculate number of events
# Fecha:
# 2021-11-18 04:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A31 P4 BPI 2020
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-11-18 05:19:56.835674
#  ***************************  Identify activities with cycle time
# Fecha:
# 2021-11-18 06:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A19 P5 BPI 2020
#  ***************************  Filter traces by frequency
# Fecha:
# 2021-11-18 07:19:56.835674
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-18 08:19:56.835674
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-18 09:19:56.835674
#  ***************************  Identify activities with cycle time
# Fecha:
# 2021-11-18 10:19:56.835674
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-11-18 11:19:56.835674
#  ***************************  Identify transitions by cycle time
# Fecha:
# 2021-11-18 12:19:56.835674
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-18 13:19:56.835674
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-18 14:19:56.835674
#  ***************************  Filter traces by frequency
# Fecha:
# 2021-11-18 15:19:56.835674
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-18 16:19:56.835674
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-18 17:19:56.835674
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-18 18:19:56.835674
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-18 19:19:56.835674
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-11-18 20:19:56.835674
#  ***************************  Identify roles by organizational units
# Fecha:
# 2021-11-18 21:19:56.835674
#  ***************************  Calculate Statistics of throughput
# Fecha:
# 2021-11-18 22:19:56.835674
#  ***************************  Identify transitions by cycle time
# Fecha:
# 2021-11-18 23:19:56.835674
#  ***************************  Identify activities with traces
# Fecha:
# 2021-11-19 00:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A30 P5 BPI 2020
#  ***************************  Filter activities by frequency
# Fecha:
# 2021-11-19 01:19:56.835674
#  ***************************  Calculate cycle time for all pairs of events for a subset of traces
# Fecha:
# 2021-11-19 02:19:56.835674
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-11-19 03:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-11-19 04:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-11-19 05:19:56.835674
#  ***************************  Represent bar charts of traces
# Fecha:
# 2021-11-19 06:19:56.835674
#  ***************************  Represent histograms of cycle time
# Fecha:
# 2021-11-19 07:19:56.835674
#  ***************************  Filter traces by activities
# Fecha:
# 2021-11-19 08:19:56.835674
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-11-19 09:19:56.835674
#  ***************************  Filter traces by activities
# Fecha:
# 2021-11-19 10:19:56.835674
#  ***************************  Calculate percentage of traces
# Fecha:
# 2021-11-19 11:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A34 P5 BPI 2020
#  ***************************  Calculate frequency of activities
# Fecha:
# 2021-11-19 12:19:56.835674
#  ***************************  Calculate Statistics of cycle time
# Fecha:
# 2021-11-19 13:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria and statistical measures
# Fecha:
# 2021-11-19 14:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A30 P6 BPI 2020
#  ***************************  Calculate cycle time for all pairs of events for all traces
# Fecha:
# 2021-11-19 15:19:56.835674
#  ***************************  Identify activities as bottlenecks applying temporal performance criteria
# Fecha:
# 2021-11-19 16:19:56.835674
#  ***************************  Identify transitions by cycle time
# Fecha:
# 2021-11-19 17:19:56.835674
# -----------------------------------------------------------------------
# Case:id
# A19 P1 BPI 2020
#  ***************************  Preprocess the traces of the logs
# Fecha:
# 2021-11-19 18:19:56.835674
#  ***************************  Group traces by year
# Fecha:
# 2021-11-19 19:19:56.835674
#  ***************************  Calculate number of traces
# Fecha:
# 2021-11-19 20:19:56.835674
#  ***************************  Represent temporal series of traces
# Fecha:
# 2021-11-19 21:19:56.835674
#  ***************************  Filter events by activities
# Fecha:
# 2021-11-19 22:19:56.835674
#  ***************************  Represent temporal series of activities
# Fecha:
# 2021-11-19 23:19:56.835674
#  ***************************  Group traces by year
# Fecha:
# 2021-11-20 00:19:56.835674
#  ***************************  Group traces by activities
# Fecha:
# 2021-11-20 01:19:56.835674
#  ***************************  Calculate Statistics of activities
# Fecha:
# 2021-11-20 02:19:56.835674
#  ***************************  Calculate throughput
# Fecha:
# 2021-11-20 03:19:56.835674
#  ***************************  Represent temporal series of throughput
# Fecha:
# 2021-11-20 04:19:56.835674
#              case:id case:concept:name               concept:name  \
# 0     A1 P2 BPI 2020    A1 P2 BPI 2020       Calculate cycle time
# 1     A1 P2 BPI 2020    A1 P2 BPI 2020         Compare cycle time
# 2     A2 P2 BPI 2020    A2 P2 BPI 2020       Calculate cycle time
# 3     A2 P2 BPI 2020    A2 P2 BPI 2020         Compare cycle time
# 4     A7 P2 BPI 2020    A7 P2 BPI 2020       Calculate throughput
# ..               ...               ...                        ...
# 943  A19 P1 BPI 2020   A19 P1 BPI 2020               Group traces
# 944  A19 P1 BPI 2020   A19 P1 BPI 2020               Group traces
# 945  A19 P1 BPI 2020   A19 P1 BPI 2020       Calculate statistics
# 946  A19 P1 BPI 2020   A19 P1 BPI 2020       Calculate throughput
# 947  A19 P1 BPI 2020   A19 P1 BPI 2020  Represent temporal series
#
#                                     Specific operation  \
# 0    Calculate cycle time of the whole process for ...
# 1
# 2            Get cycle time from the previous question
# 3
# 4
# ..                                                 ...
# 943                               Group traces by year
# 944                         Group traces by activities
# 945                 Calculate Statistics of activities
# 946
# 947            Represent temporal series of throughput
#
#                  time:timestamp Question  Year
# 0    2021-10-11 17:19:56.835674       P2  2020
# 1    2021-10-11 18:19:56.835674       P2  2020
# 2    2021-10-11 19:19:56.835674       P2  2020
# 3    2021-10-11 20:19:56.835674       P2  2020
# 4    2021-10-11 21:19:56.835674       P2  2020
# ..                          ...      ...   ...
# 943  2021-11-20 00:19:56.835674       P1  2020
# 944  2021-11-20 01:19:56.835674       P1  2020
# 945  2021-11-20 02:19:56.835674       P1  2020
# 946  2021-11-20 03:19:56.835674       P1  2020
# 947  2021-11-20 04:19:56.835674       P1  2020
#
# [948 rows x 7 columns]

# %%
df_prueba
# Out:
#              case:id case:concept:name               concept:name  \
# 0     A1 P2 BPI 2020    A1 P2 BPI 2020       Calculate cycle time
# 1     A1 P2 BPI 2020    A1 P2 BPI 2020         Compare cycle time
# 2     A2 P2 BPI 2020    A2 P2 BPI 2020       Calculate cycle time
# 3     A2 P2 BPI 2020    A2 P2 BPI 2020         Compare cycle time
# 4     A7 P2 BPI 2020    A7 P2 BPI 2020       Calculate throughput
# ..               ...               ...                        ...
# 943  A19 P1 BPI 2020   A19 P1 BPI 2020               Group traces
# 944  A19 P1 BPI 2020   A19 P1 BPI 2020               Group traces
# 945  A19 P1 BPI 2020   A19 P1 BPI 2020       Calculate statistics
# 946  A19 P1 BPI 2020   A19 P1 BPI 2020       Calculate throughput
# 947  A19 P1 BPI 2020   A19 P1 BPI 2020  Represent temporal series
#
#                                     Specific operation  \
# 0    Calculate cycle time of the whole process for ...
# 1
# 2            Get cycle time from the previous question
# 3
# 4
# ..                                                 ...
# 943                               Group traces by year
# 944                         Group traces by activities
# 945                 Calculate Statistics of activities
# 946
# 947            Represent temporal series of throughput
#
#                  time:timestamp Question  Year
# 0    2021-10-11 17:19:56.835674       P2  2020
# 1    2021-10-11 18:19:56.835674       P2  2020
# 2    2021-10-11 19:19:56.835674       P2  2020
# 3    2021-10-11 20:19:56.835674       P2  2020
# 4    2021-10-11 21:19:56.835674       P2  2020
# ..                          ...      ...   ...
# 943  2021-11-20 00:19:56.835674       P1  2020
# 944  2021-11-20 01:19:56.835674       P1  2020
# 945  2021-11-20 02:19:56.835674       P1  2020
# 946  2021-11-20 03:19:56.835674       P1  2020
# 947  2021-11-20 04:19:56.835674       P1  2020
#
# [948 rows x 7 columns]

# %%
type(df_prueba.iloc[2]['time:timestamp'])
# Out:
# str

# %%
for i in range(len(df_prueba)):   
    df_prueba.iloc[i]['time:timestamp'] = datetime.datetime.strptime(df_prueba.iloc[i]['time:timestamp'], '%Y-%m-%d %H:%M:%S.%f')

# %%
type(df_prueba.iloc[2]['time:timestamp'])
# Out:
# datetime.datetime

# %%
log = log_converter.apply(df_prueba)
xes_exporter.apply(log, './Log of analysis of time spects.xes')
# Out:
# HBox(children=(IntProgress(value=0, description='exporting log, completed traces :: ', max=126, style=Progress…

# %%
log2=xes_importer.apply('./Log of analysis of time spects.xes')
log2_df= log_converter.apply(log2,variant=log_converter.Variants.TO_DATA_FRAME)
# Out:
# HBox(children=(IntProgress(value=0, description='parsing log, completed traces :: ', max=126, style=ProgressSt…

# %%
log2_df=log2_df.rename({'concept:name': 'General operation', 'Specific operation': 'concept:name'},axis='columns')

# %%
log2_df
# Out:
#              General operation  \
# 0         Calculate cycle time
# 1           Compare cycle time
# 2         Calculate cycle time
# 3           Compare cycle time
# 4         Calculate throughput
# ..                         ...
# 943               Group traces
# 944               Group traces
# 945       Calculate statistics
# 946       Calculate throughput
# 947  Represent temporal series
#
#                                           concept:name  \
# 0    Calculate cycle time of the whole process for ...
# 1
# 2            Get cycle time from the previous question
# 3
# 4
# ..                                                 ...
# 943                               Group traces by year
# 944                         Group traces by activities
# 945                 Calculate Statistics of activities
# 946
# 947            Represent temporal series of throughput
#
#                 time:timestamp Question  Year          case:id  \
# 0   2021-10-13 12:57:26.198786       P2  2020   A1 P2 BPI 2020
# 1   2021-10-13 13:57:26.198786       P2  2020   A1 P2 BPI 2020
# 2   2021-10-13 14:57:26.198786       P2  2020   A2 P2 BPI 2020
# 3   2021-10-13 15:57:26.198786       P2  2020   A2 P2 BPI 2020
# 4   2021-10-13 16:57:26.198786       P2  2020   A7 P2 BPI 2020
# ..                         ...      ...   ...              ...
# 943 2021-11-21 19:57:26.198786       P1  2020  A19 P1 BPI 2020
# 944 2021-11-21 20:57:26.198786       P1  2020  A19 P1 BPI 2020
# 945 2021-11-21 21:57:26.198786       P1  2020  A19 P1 BPI 2020
# 946 2021-11-21 22:57:26.198786       P1  2020  A19 P1 BPI 2020
# 947 2021-11-21 23:57:26.198786       P1  2020  A19 P1 BPI 2020
#
#     case:concept:name
# 0      A1 P2 BPI 2020
# 1      A1 P2 BPI 2020
# 2      A2 P2 BPI 2020
# 3      A2 P2 BPI 2020
# 4      A7 P2 BPI 2020
# ..                ...
# 943   A19 P1 BPI 2020
# 944   A19 P1 BPI 2020
# 945   A19 P1 BPI 2020
# 946   A19 P1 BPI 2020
# 947   A19 P1 BPI 2020
#
# [948 rows x 7 columns]

# %%
log2 = log_converter.apply(log2_df)
xes_exporter.apply(log2, './Log of analysis of specific time aspects.xes')
# Out:
# HBox(children=(IntProgress(value=0, description='exporting log, completed traces :: ', max=126, style=Progress…

# %%
df_categorias_autores=pd.read_csv("Log CT.csv",index_col=0)
df_categorias_autores
# Out:
#     case:concept:name               concept:name  \
# 0      A1 P2 BPI 2020       Calculate cycle time
# 1      A1 P2 BPI 2020         Compare cycle time
# 2      A2 P2 BPI 2020       Calculate cycle time
# 3      A2 P2 BPI 2020         Compare cycle time
# 4      A7 P2 BPI 2020       Calculate throughput
# ..                ...                        ...
# 943   A19 P1 BPI 2020               Group traces
# 944   A19 P1 BPI 2020               Group traces
# 945   A19 P1 BPI 2020       Calculate statistics
# 946   A19 P1 BPI 2020       Calculate throughput
# 947   A19 P1 BPI 2020  Represent temporal series
#
#                                     Specific operation  \
# 0    Calculate cycle time of the whole process for ...
# 1
# 2            Get cycle time from the previous question
# 3
# 4
# ..                                                 ...
# 943                               Group traces by year
# 944                         Group traces by activities
# 945                 Calculate Statistics of activities
# 946
# 947            Represent temporal series of throughput
#
#                  time:timestamp Report Question  Year      Category
# 0    2021-10-19 12:47:13.651481     A1       P2  2020      Academic
# 1    2021-10-19 12:47:13.659459     A1       P2  2020      Academic
# 2    2021-10-19 12:47:13.666495     A2       P2  2020       Student
# 3    2021-10-19 12:47:13.666495     A2       P2  2020       Student
# 4    2021-10-19 12:47:13.682150     A7       P2  2020      Academic
# ..                          ...    ...      ...   ...           ...
# 943  2021-10-19 12:47:20.534786    A19       P1  2020  Professional
# 944  2021-10-19 12:47:20.534786    A19       P1  2020  Professional
# 945  2021-10-19 12:47:20.557196    A19       P1  2020  Professional
# 946  2021-10-19 12:47:20.567144    A19       P1  2020  Professional
# 947  2021-10-19 12:47:20.576118    A19       P1  2020  Professional
#
# [948 rows x 8 columns]

# %%
cycleTimeOperations=["Calculate cycle time","Identify bottlenecks","Compare cycle time", "Calculate waiting time",
                     "Calculate throughput","Calculate processing time", "Compare waiting time with processing time", 
                     "Analyze cycle time depending on the events",
                     "Calculate intervals of time of the traces",
                     'Comparative of throughput','Compare processing time',]

# %%
manipulationOperations=[
    "Filter traces","Group traces", "Group activities","Preprocess the traces of the logs", "Filter activities",
    "Filter events","Preprocess the events of the logs", "Group organizational units", "Group events by time",
    "Filter variants depending on frequency", 'Group events by attributes','Group sub-processes', 'Filter sub-processes'
]

# %%
statisticOperations=[
    "Calculate number of elements", "Calculate percentages","Calculate frequency", "Calculate statistics",
    "Calculate average of activities per trace"
]

# %%
representationOperations=[
    "Represent process map", "Represent histograms", "Represent bar charts", "Represent scatter plot",
    "Represent heat maps", "Represent circular charts of attributes of the traces","Represent box plots of cycle time", 
    "Represent temporal series of sub-processes", "Represent density of cycle time","Discover and Replay a Log on Petri Net",
    "Represent temporal series", 'Represent boxplots of cycle time','Represent correlation graph of variables',
    'Represent heatmaps', 'Represent lineal distribution of an attribute by traces', 'Represent linear tendency of cycle time',
    'Represent scatterplot'
]

# %%
identificationOperations=[
    "Identify roles", "Identify resources", "Identify values of attributes", "Identify dates", 
    "Identify specific sub-processes", "Identify impact of bottlenecks by organizational unit",
    "Identify activity with biggest backlog","Identify attributes", 'Identify activities',
    'Identify attributes','Identify organizational units', 'Identify specific subprocesses',
    'Identify traces by cycle time','Identify transitions by cycle time',
]

# %%
otherOperations=[
    "Assign resource to each activity", "Apply machine learning techniques", "Apply decision trees",
    "Discover happy path of the process",'Discover process maps','Calculate dates of the development of activities of resources'
]

# %%
listTypesOperations=[]
listOthers=[]
for index, row in df_categorias_autores.iterrows():
    if row['concept:name'] in cycleTimeOperations:
        listTypesOperations.append("Analyze Cycle Time")
    elif row['concept:name'] in manipulationOperations:
        listTypesOperations.append("Manipulation")
    elif row['concept:name'] in statisticOperations:
        listTypesOperations.append("Calculate statistics")
    elif row['concept:name'] in representationOperations:
        listTypesOperations.append("Representation")
    elif row['concept:name'] in identificationOperations:
        listTypesOperations.append("Identification")
    else:
        listTypesOperations.append("Others")

# %%
df_categorias_autores['Type']=listTypesOperations

# %%
df_categorias_autores
# Out:
#     case:concept:name               concept:name  \
# 0      A1 P2 BPI 2020       Calculate cycle time
# 1      A1 P2 BPI 2020         Compare cycle time
# 2      A2 P2 BPI 2020       Calculate cycle time
# 3      A2 P2 BPI 2020         Compare cycle time
# 4      A7 P2 BPI 2020       Calculate throughput
# ..                ...                        ...
# 943   A19 P1 BPI 2020               Group traces
# 944   A19 P1 BPI 2020               Group traces
# 945   A19 P1 BPI 2020       Calculate statistics
# 946   A19 P1 BPI 2020       Calculate throughput
# 947   A19 P1 BPI 2020  Represent temporal series
#
#                                     Specific operation  \
# 0    Calculate cycle time of the whole process for ...
# 1
# 2            Get cycle time from the previous question
# 3
# 4
# ..                                                 ...
# 943                               Group traces by year
# 944                         Group traces by activities
# 945                 Calculate Statistics of activities
# 946
# 947            Represent temporal series of throughput
#
#                  time:timestamp Report Question  Year      Category  \
# 0    2021-10-19 12:47:13.651481     A1       P2  2020      Academic
# 1    2021-10-19 12:47:13.659459     A1       P2  2020      Academic
# 2    2021-10-19 12:47:13.666495     A2       P2  2020       Student
# 3    2021-10-19 12:47:13.666495     A2       P2  2020       Student
# 4    2021-10-19 12:47:13.682150     A7       P2  2020      Academic
# ..                          ...    ...      ...   ...           ...
# 943  2021-10-19 12:47:20.534786    A19       P1  2020  Professional
# 944  2021-10-19 12:47:20.534786    A19       P1  2020  Professional
# 945  2021-10-19 12:47:20.557196    A19       P1  2020  Professional
# 946  2021-10-19 12:47:20.567144    A19       P1  2020  Professional
# 947  2021-10-19 12:47:20.576118    A19       P1  2020  Professional
#
#                      Type
# 0      Analyze Cycle Time
# 1      Analyze Cycle Time
# 2      Analyze Cycle Time
# 3      Analyze Cycle Time
# 4      Analyze Cycle Time
# ..                    ...
# 943          Manipulation
# 944          Manipulation
# 945  Calculate statistics
# 946    Analyze Cycle Time
# 947        Representation
#
# [948 rows x 9 columns]

# %%
tipos_op_agrupado_años=df_categorias_autores.groupby("Year")['Type'].value_counts()

# %%
sumAños=[tipos_op_agrupado_años[tipos_op_agrupado_años.index.get_level_values('Year')==val].sum() for val in [2015,2017,2019,2020]]

# %%
for index,value in tipos_op_agrupado_años.items():
    if 2015 in index:
        tipos_op_agrupado_años[index]=(value/sumAños[0])*100
    elif 2017 in index:
        tipos_op_agrupado_años[index]=(value/sumAños[1])*100
    elif 2019 in index:
        tipos_op_agrupado_años[index]=(value/sumAños[2])*100
    elif 2020 in index:
        tipos_op_agrupado_años[index]=(value/sumAños[3])*100

# %%
tipos_op_agrupado_años.unstack().plot(kind='bar', stacked=True)
plt.legend(["Analyze Cycle time","Calculate statistics","Identification","Manipulation","Others","Representation"],bbox_to_anchor = (1.05, 0.6))
plt.show()

# %%
import matplotlib.pyplot as plt
tipos_op_agrupado_años.unstack().plot(kind='bar')
plt.legend(["Analyze Cycle time","Calculate statistics","Identification","Manipulation","Others","Representation"],bbox_to_anchor = (1.05, 0.6))
plt.ylabel("Percentage of operations")
plt.show()
